# %% [markdown]
# **FULLY REFACTORED VERSION** - A template of the RL training, with H-network trained along side the DDQN agent
#
# This notebook uses the refactored environment factory pattern for creating discrete environments.
# It uses the unified factory pattern for environments, H-network modules, and callbacks.

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from datetime import datetime
import sys

from utils import print_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the created dataset
dataset_folder_path = Path("dataset", "20250707_downsampled_1min", "split")

# %%
from utils_data_split import load_split_data_from_folder, convert_to_naive_datetimes, convert_to_naive_datetimes_df

# %%
aggregate_load_segments_test, aggregate_load_df_test = load_split_data_from_folder(dataset_folder_path, 'test')

# %%
aggregate_load_segments_test, aggregate_load_df_test = convert_to_naive_datetimes(aggregate_load_segments_test), convert_to_naive_datetimes_df(aggregate_load_df_test)

# %% [markdown]
# ---

# %% [markdown]
# Experiment start

# %%
# initialize experiment folder to store related information/data for future analysis

# rl_datetime = datetime(2025, 8, 11, 2, 46, 31)
# rl_datetime = datetime(2025, 8, 11, 4, 45, 55)
rl_datetime = datetime(2025, 8, 11, 6, 42, 39)
ACTION_TYPE = "continuous"
REWARD_LAMBDA = "1.0"  # between 0 and 1

experiment_folder = Path(
    "experiments", rl_datetime.strftime('%Y%m%d_%H%M%S') + f"_action_{ACTION_TYPE}_reward_lambda_{REWARD_LAMBDA}", 
)

if not experiment_folder.exists():
    raise FileNotFoundError(f"Experiment folder {experiment_folder} does not exist. Please check the path.")
else:
    print_log(f"Experiment folder: {experiment_folder}")
# Out:
# [2025-08-12 12:10:07:207] Experiment folder: experiments/20250811_064239_action_continuous_reward_lambda_1.0

# %%
# find the selected checkpoint

selected_ckpt_folder = experiment_folder / "selected_ckpt"

# search for any sub-folders under selected_ckpt_folder
sub_folders = [f for f in selected_ckpt_folder.iterdir() if f.is_dir()]
# assert len(sub_folders) == 1, "There should be exactly one sub-folder in selected_ckpt_folder."

selected_ckpt_folder = sub_folders[0]
selected_ckpt_episode_number = int(selected_ckpt_folder.name.split('_')[-1])

print_log(f"Selected checkpoint folder: {selected_ckpt_folder}")
# Out:
# [2025-08-12 12:10:07:222] Selected checkpoint folder: experiments/20250811_064239_action_continuous_reward_lambda_1.0/selected_ckpt/episode_0703

# %% [markdown]
# TODO: read the experiment_details under the experiment_folder, find the seed element, and use it to set the action_space and RL model for reproducibility

# %% [markdown]
# Create data loader

# %%
sys.path.append(str(Path('rl_env')))
sys.path.append(str(Path('model', 'H_network')))

from rl_env.data_loader import SimpleSmartMeterDataLoader

sm_dl_test = SimpleSmartMeterDataLoader(
    aggregate_load_segments=aggregate_load_segments_test,
    aggregate_load_df=aggregate_load_df_test,
    registry_path=experiment_folder / "simple_episode_registry_test.json"
)

sm_dl_test.get_divided_segments_length()
# Out:
# [SimpleDataLoader] Generated 80 episodes (1 day each)
# 80

# %%
sm_dl_test.divided_segments[7]
# Out:
# array([datetime.datetime(2013, 2, 15, 0, 0),
#        datetime.datetime(2013, 2, 15, 23, 59, 59, 999000)], dtype=object)

# %%
# sample segment

sm_dl_test.get_aggregate_load_segment(13)
# Out:
#         timestamp   aggregate            datetime  segment_index  \
# 18720  1362355201  144.000000 2013-03-04 00:00:01             13
# 18721  1362355261  146.640530 2013-03-04 00:01:01             13
# 18722  1362355321  144.977225 2013-03-04 00:02:01             13
# 18723  1362355381  145.282810 2013-03-04 00:03:01             13
# 18724  1362355441  144.273479 2013-03-04 00:04:01             13
# ...           ...         ...                 ...            ...
# 20155  1362441301  259.357749 2013-03-04 23:55:01             13
# 20156  1362441361  250.485841 2013-03-04 23:56:01             13
# 20157  1362441421  309.990317 2013-03-04 23:57:01             13
# 20158  1362441481  285.959002 2013-03-04 23:58:01             13
# 20159  1362441541  281.678576 2013-03-04 23:59:01             13
#
#       episode_content_id  episode_length_days
# 18720       9eafa9c7f9a1                    1
# 18721       9eafa9c7f9a1                    1
# 18722       9eafa9c7f9a1                    1
# 18723       9eafa9c7f9a1                    1
# 18724       9eafa9c7f9a1                    1
# ...                  ...                  ...
# 20155       9eafa9c7f9a1                    1
# 20156       9eafa9c7f9a1                    1
# 20157       9eafa9c7f9a1                    1
# 20158       9eafa9c7f9a1                    1
# 20159       9eafa9c7f9a1                    1
#
# [1440 rows x 6 columns]

# %% [markdown]
# Create the environment

# %%
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from model.H_network.common.factories import create_h_network_module_with_defaults
from model.H_network.h_network_arch import HNetworkType

# the optimizer class and optimizer kwargs does not matter for the testing loop, but they are required to create the module

h_network_kwargs = {
    "h_network_type": HNetworkType.H_NETWORK,
    "optimizer_class": torch.optim.Adam,
    "optimizer_kwargs": {"lr": 0.001},
}

h_network_rl_module = create_h_network_module_with_defaults(
    action_type=ACTION_TYPE,
    **h_network_kwargs,
    device=DEVICE
)

# %%
from rl_env.base.env_module import SmartMeterEnvFactory
from rl_env.training_mode import TrainingMode
from decimal import Decimal

env_test = SmartMeterEnvFactory.create(
    action_type=ACTION_TYPE,
    smart_meter_data_loader=sm_dl_test,
    h_network_rl_module=h_network_rl_module,
    mode=TrainingMode.TEST,
    reward_lambda=float(REWARD_LAMBDA),
    render_mode=None,
)
# Out:
# [2025-08-12 12:10:08:398] [SmartMeterContinuousEnv Test] Using data loader: SimpleSmartMeterDataLoader
# [2025-08-12 12:10:08:398] [SmartMeterContinuousEnv Test] Curriculum enabled: False
# [2025-08-12 12:10:08:403] [SmartMeterContinuousEnv Test]] Render mode set to 'None'. Render server at 127.0.0.1:50007. render_connected: False. render_client_socket: None

# %%
h_network_rl_module.set_h_network(
    h_network_rl_module.initialize_h_network()
)
h_network_rl_module.initialize_h_network_training()

# %%
# load the h_network from the selected checkpoint

h_network_rl_module.load_h_network(
    selected_ckpt_folder / ("h_network" + f"_{selected_ckpt_episode_number:04d}" + ".pth")
)

# %%
h_network_rl_module.h_network
# Out:
# HNetwork(
#   (LSTM_1): LSTM(2, 44, batch_first=True, bidirectional=True)
#   (ac1): Tanh()
#   (LSTM_2): LSTM(88, 44, batch_first=True, bidirectional=True)
#   (ac2): Tanh()
#   (fc): Linear(in_features=88, out_features=1, bias=True)
# )

# %%
import torchinfo

torchinfo.summary(h_network_rl_module.h_network, input_size=(1, 1, 2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HNetwork                                 [1, 1]                    --
# ├─LSTM: 1-1                              [1, 1, 88]                16,896
# ├─Tanh: 1-2                              [1, 1, 88]                --
# ├─LSTM: 1-3                              [1, 1, 88]                47,168
# ├─Tanh: 1-4                              [1, 1, 88]                --
# ├─Linear: 1-5                            [1, 1, 1]                 89
# ==========================================================================================
# Total params: 64,153
# Trainable params: 64,153
# Non-trainable params: 0
# Total mult-adds (M): 0.06
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.26
# Estimated Total Size (MB): 0.26
# ==========================================================================================

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env_test)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# [2025-08-12 12:10:09:405] [SmartMeterContinuousEnv Test] Resetting environment with episode 21. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-23 00:00:05'), Timestamp('2013-04-23 23:59:05'))}
# [2025-08-12 12:10:09:409] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:10:09:411] [SmartMeterContinuousEnv Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-08-12 12:10:09:414] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:10:09:416] [SmartMeterContinuousEnv Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-08-12 12:10:09:419] [SmartMeterContinuousEnv Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-08-12 12:10:09:423] [SmartMeterContinuousEnv Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-08-12 12:10:09:425] [SmartMeterContinuousEnv Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-08-12 12:10:09:478] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:10:09:484] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# Environment passes all checks!
# /root/miniforge3/envs/smartmeter/lib/python3.9/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
env_test.reset_render_window()

# %% [markdown]
# Also initiate a validation environment for time-to-time validation

# %%
# initialize a DQN agent
from stable_baselines3 import PPO

# rl_lr = 2.5e-4
# rl_batch_size=64
# n_updates_btw_h_network_training = 2

# rl_gamma = 1
# policy_kwargs = {
#     "net_arch": [64, 64],
#     "activation_fn": torch.nn.ReLU,
# }
# n_epochs = 15
# gae_lambda = 1 - 2.9011e-3


# # n_steps is automatically computed from n_updates_between_h_network_training
# # Target timesteps per environment per PPO update
# target_steps_per_env = 24 * 60 // n_updates_btw_h_network_training
# # Quantize n_steps to be a multiple of batch_size, close to target_steps_per_env
# n_steps = max(1, target_steps_per_env // rl_batch_size) * rl_batch_size
# # If n_steps is 0 (when target_steps_per_env < batch_size), set it to batch_size
# if n_steps == 0:
#     n_steps = rl_batch_size

# agent_params = {
#     "learning_rate": rl_lr,
#     "n_steps": n_steps,
#     "batch_size": rl_batch_size,
#     "gamma": rl_gamma,
#     "gae_lambda": gae_lambda,
#     "n_epochs": n_epochs,
#     "policy_kwargs": policy_kwargs,
# }


rl_model = PPO(
    "MultiInputPolicy",
    env_test,
    verbose=2,
)
# Out:
# 2025-08-12 12:10:09.721445: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-12 12:10:09.730430: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754997009.740943   75845 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754997009.744091   75845 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754997009.752396   75845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754997009.752424   75845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754997009.752425   75845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754997009.752426   75845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-12 12:10:09.755256: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
rl_model = rl_model.load(
    selected_ckpt_folder / ("rl_model" + f"_{selected_ckpt_episode_number:04d}")  # path to the saved RL model
)

# %%
rl_model.policy
# Out:
# MultiInputActorCriticPolicy(
#   (features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (pi_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (vf_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=1, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
rl_model.n_steps
# Out:
# 704

# %%
# we test the rl model and H-network

import json
from utils import print_log

total_episodes = env_test.smart_meter_data_loader.get_divided_segments_length()
episode_indices = list(range(total_episodes))

all_episode_rewards = []
all_episode_lengths = []
all_episode_infos = []
per_episode_reward_stats = []

for i, episode_idx in enumerate(episode_indices):
    obs, info = env_test.reset(episode_idx=episode_idx)

    # Initialize episode tracking variables
    episode_reward = 0.0
    episode_length = 0
    done = False
    state = None  # For recurrent policies

    while not done:
        # Get action from the RL model
        action, state = rl_model.predict(obs, state=state, deterministic=True)

        # Step the environment
        obs, reward, done, truncated, info = env_test.step(action)

        # Update episode tracking variables
        episode_reward += reward
        episode_length += 1

    # Store results for this episode
    all_episode_rewards.append(episode_reward)
    all_episode_lengths.append(episode_length)
    all_episode_infos.append({
        "episode_idx": episode_idx,
        "episode_info": env_test.episode.get_episode_info() if hasattr(env_test, 'episode') else {}
    })

    per_episode_reward_stats.append(env_test.prev_episode_reward_stats)

    env_test.save_episode_info(
        log_folder=experiment_folder / "logs_test",
        episode_training_idx=episode_idx
    )

    if (i + 1) % 10 == 0:
        print_log(f"Episode {i + 1}/{total_episodes} completed.")


# Calculate comprehensive statistics
mean_reward = np.mean(all_episode_rewards)
std_reward = np.std(all_episode_rewards)
min_reward = np.min(all_episode_rewards)
max_reward = np.max(all_episode_rewards)
median_reward = np.median(all_episode_rewards)

# we need to recover the true sum f_signal and g_signal from the per_episode_reward_stats, with length of each episode
f_signal_sums = np.array([item['f_signal_sum'] for item in per_episode_reward_stats])
g_signal_sums = np.array([item['g_signal_sum'] for item in per_episode_reward_stats])

# get the length of each episode
_episode_lengths = np.array(all_episode_lengths)
sum_episode_lengths = np.sum(_episode_lengths)

# calculate the (true) mean of rewards, f_signal and g_signal

f_signal_mean = f_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0
g_signal_mean = g_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0

mean_length = np.mean(all_episode_lengths)
std_length = np.std(all_episode_lengths)

# Prepare validation data
test_data = {
    'evaluated_episodes': len(episode_indices),
    'total_available_episodes': total_episodes,
    'episode_indices': episode_indices,
    'episode_rewards': all_episode_rewards,
    'episode_lengths': all_episode_lengths,
    'episode_infos': all_episode_infos,
    'summary_stats': {
        'mean_reward': mean_reward,
        'std_reward': std_reward,
        'min_reward': min_reward,
        'max_reward': max_reward,
        'median_reward': median_reward,
        'mean_f_signal': f_signal_mean,
        'mean_g_signal': g_signal_mean,
        'mean_length': mean_length,
        'std_length': std_length
    }
}

test_stats_file_path = experiment_folder / "logs_test" / "test_stats_file.json"
with open(test_stats_file_path, 'w') as f:
    # Convert numpy types to Python native types for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        return obj

    json.dump(convert_numpy(test_data), f, indent=2, default=str)

sm_dl_test._save_registry()
print_log(f"Validation results saved to {test_stats_file_path}")
# Out:
# [2025-08-12 12:10:10:835] [SmartMeterContinuousEnv Test] Resetting environment with episode 0. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-01 00:00:01'), Timestamp('2013-01-01 23:59:01'))}
# [2025-08-12 12:10:15:669] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:15:669] [SmartMeterContinuousEnv Test] Episode f_signal sum: -54.52307310271354. Mean: -0.03788955740285861. Std: 0.07402099787859324
# [2025-08-12 12:10:15:669] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:15:684] [SmartMeterContinuousEnv Test] Episode 0000 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0000_info.json
# [2025-08-12 12:10:15:688] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:10:20:625] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:20:625] [SmartMeterContinuousEnv Test] Episode f_signal sum: -43.571768780918035. Mean: -0.030279199986739426. Std: 0.05563303100638299
# [2025-08-12 12:10:20:626] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:20:641] [SmartMeterContinuousEnv Test] Episode 0001 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0001_info.json
# [2025-08-12 12:10:20:644] [SmartMeterContinuousEnv Test] Resetting environment with episode 2. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-03 00:00:00'), Timestamp('2013-01-03 23:59:00'))}
# [2025-08-12 12:10:25:723] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:25:723] [SmartMeterContinuousEnv Test] Episode f_signal sum: -39.412732151344684. Mean: -0.027388973003019238. Std: 0.05319929412893511
# [2025-08-12 12:10:25:723] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:25:738] [SmartMeterContinuousEnv Test] Episode 0002 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0002_info.json
# [2025-08-12 12:10:25:741] [SmartMeterContinuousEnv Test] Resetting environment with episode 3. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-04 00:00:05'), Timestamp('2013-01-04 23:59:05'))}
# [2025-08-12 12:10:30:682] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:30:682] [SmartMeterContinuousEnv Test] Episode f_signal sum: -39.78071820245805. Mean: -0.027644696457580296. Std: 0.05628465761902662
# [2025-08-12 12:10:30:682] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:30:697] [SmartMeterContinuousEnv Test] Episode 0003 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0003_info.json
# [2025-08-12 12:10:30:700] [SmartMeterContinuousEnv Test] Resetting environment with episode 4. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-05 00:00:04'), Timestamp('2013-01-05 23:59:04'))}
# [2025-08-12 12:10:35:701] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:35:701] [SmartMeterContinuousEnv Test] Episode f_signal sum: -51.66038360430152. Mean: -0.035900197084295704. Std: 0.07244337031511597
# [2025-08-12 12:10:35:701] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:35:716] [SmartMeterContinuousEnv Test] Episode 0004 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0004_info.json
# [2025-08-12 12:10:35:719] [SmartMeterContinuousEnv Test] Resetting environment with episode 5. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-06 00:00:01'), Timestamp('2013-01-06 23:59:01'))}
# [2025-08-12 12:10:43:997] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:43:998] [SmartMeterContinuousEnv Test] Episode f_signal sum: -49.24102215858426. Mean: -0.0342189174138876. Std: 0.06451404867663436
# [2025-08-12 12:10:43:998] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:44:012] [SmartMeterContinuousEnv Test] Episode 0005 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0005_info.json
# [2025-08-12 12:10:44:015] [SmartMeterContinuousEnv Test] Resetting environment with episode 6. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-14 00:00:03'), Timestamp('2013-02-14 23:59:03'))}
# [2025-08-12 12:10:48:556] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:48:556] [SmartMeterContinuousEnv Test] Episode f_signal sum: -47.86429284855558. Mean: -0.03326219099969116. Std: 0.06497422361781685
# [2025-08-12 12:10:48:556] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10:48:572] [SmartMeterContinuousEnv Test] Episode 0006 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0006_info.json
# [2025-08-12 12:10:48:575] [SmartMeterContinuousEnv Test] Resetting environment with episode 7. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-15 00:00:00'), Timestamp('2013-02-15 23:59:00'))}
# [2025-08-12 12:10:53:148] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:10:53:148] [SmartMeterContinuousEnv Test] Episode f_signal sum: -43.91823611712022. Mean: -0.03051996950460057. Std: 0.057472177653612795
# [2025-08-12 12:10:53:148] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:10
Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-20 00:00:02'), Timestamp('2013-08-20 23:59:02'))}
# [2025-08-12 12:14:31:884] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:14:31:884] [SmartMeterContinuousEnv Test] Episode f_signal sum: -27.674271397676502. Mean: -0.019231599303458306. Std: 0.03847859515203924
# [2025-08-12 12:14:31:884] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:14:31:900] [SmartMeterContinuousEnv Test] Episode 0050 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0050_info.json
# [2025-08-12 12:14:31:903] [SmartMeterContinuousEnv Test] Resetting environment with episode 51. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-21 00:00:00'), Timestamp('2013-08-21 23:59:00'))}
# [2025-08-12 12:14:36:926] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:14:36:926] [SmartMeterContinuousEnv Test] Episode f_signal sum: -32.26835209865652. Mean: -0.022424150172798137. Std: 0.04279987351633287
# [2025-08-12 12:14:36:926] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:14:36:942] [SmartMeterContinuousEnv Test] Episode 0051 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0051_info.json
# [2025-08-12 12:14:36:945] [SmartMeterContinuousEnv Test] Resetting environment with episode 52. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-15 00:00:00'), Timestamp('2013-09-15 23:59:00'))}
# [2025-08-12 12:14:41:812] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:14:41:812] [SmartMeterContinuousEnv Test] Episode f_signal sum: -26.278213869713454. Mean: -0.018261441188126098. Std: 0.03484264316457858
# ...
# [2025-08-12 12:15:37:935] [SmartMeterContinuousEnv Test] Episode 0062 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0062_info.json
# [2025-08-12 12:15:37:938] [SmartMeterContinuousEnv Test] Resetting environment with episode 63. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-19 00:00:04'), Timestamp('2013-10-19 23:59:04'))}
# [2025-08-12 12:15:42:502] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:15:42:502] [SmartMeterContinuousEnv Test] Episode f_signal sum: -36.79886480985282. Mean: -0.025572525927625312. Std: 0.05322546092390458
# [2025-08-12 12:15:42:502] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:15:42:517] [SmartMeterContinuousEnv Test] Episode 0063 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0063_info.json
# [2025-08-12 12:15:42:520] [SmartMeterContinuousEnv Test] Resetting environment with episode 64. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-20 00:00:04'), Timestamp('2013-10-20 23:59:04'))}
# [2025-08-12 12:15:46:919] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:15:46:919] [SmartMeterContinuousEnv Test] Episode f_signal sum: -43.21753582632033. Mean: -0.030033033930729904. Std: 0.05867984371319768
# [2025-08-12 12:15:46:919] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:15:46:935] [SmartMeterContinuousEnv Test] Episode 0064 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0064_info.json
# [2025-08-12 12:15:46:937] [SmartMeterContinuousEnv Test] Resetting environment with episode 65. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-21 00:00:04'), Timestamp('2013-10-21 23:59:04'))}
# [2025-08-12 12:15:51:306] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:15:51:306] [SmartMeterContinuousEnv Test] Episode f_signal sum: -42.28668114207751. Mean: -0.029386157847169917. Std: 0.05493787380993835
# [2025-08-12 12:15:51:306] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:15:51:322] [SmartMeterContinuousEnv Test] Episode 0065 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0065_info.json
# [2025-08-12 12:15:51:325] [SmartMeterContinuousEnv Test] Resetting environment with episode 66. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-15 00:00:04'), Timestamp('2013-11-15 23:59:04'))}
# [2025-08-12 12:15:55:729] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:15:55:729] [SmartMeterContinuousEnv Test] Episode f_signal sum: -23.05507416717446. Mean: -0.016021594278786976. Std: 0.02874360158158906
# [2025-08-12 12:15:55:729] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:15:55:744] [SmartMeterContinuousEnv Test] Episode 0066 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0066_info.json
# [2025-08-12 12:15:55:747] [SmartMeterContinuousEnv Test] Resetting environment with episode 67. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-16 00:00:03'), Timestamp('2013-11-16 23:59:03'))}
# [2025-08-12 12:16:03:697] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:03:697] [SmartMeterContinuousEnv Test] Episode f_signal sum: -49.8701690332272. Mean: -0.03465612858459152. Std: 0.0723017995790325
# [2025-08-12 12:16:03:697] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:03:712] [SmartMeterContinuousEnv Test] Episode 0067 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0067_info.json
# [2025-08-12 12:16:03:715] [SmartMeterContinuousEnv Test] Resetting environment with episode 68. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-17 00:00:03'), Timestamp('2013-11-17 23:59:03'))}
# [2025-08-12 12:16:08:096] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:08:096] [SmartMeterContinuousEnv Test] Episode f_signal sum: -60.06306362975886. Mean: -0.04173944658079142. Std: 0.07949920013161216
# [2025-08-12 12:16:08:096] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:08:111] [SmartMeterContinuousEnv Test] Episode 0068 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0068_info.json
# [2025-08-12 12:16:08:114] [SmartMeterContinuousEnv Test] Resetting environment with episode 69. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-18 00:00:04'), Timestamp('2013-11-18 23:59:04'))}
# [2025-08-12 12:16:13:044] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:13:044] [SmartMeterContinuousEnv Test] Episode f_signal sum: -24.999611694723015. Mean: -0.01737290597270536. Std: 0.030857396399604616
# [2025-08-12 12:16:13:044] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:13:059] [SmartMeterContinuousEnv Test] Episode 0069 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0069_info.json
# [2025-08-12 12:16:13:059] Episode 70/80 completed.
# [2025-08-12 12:16:13:062] [SmartMeterContinuousEnv Test] Resetting environment with episode 70. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-19 00:00:02'), Timestamp('2013-11-19 23:59:02'))}
# [2025-08-12 12:16:18:156] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:18:157] [SmartMeterContinuousEnv Test] Episode f_signal sum: -35.90373030823831. Mean: -0.024950472764585344. Std: 0.04884137890472894
# [2025-08-12 12:16:18:157] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:18:173] [SmartMeterContinuousEnv Test] Episode 0070 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0070_info.json
# [2025-08-12 12:16:18:176] [SmartMeterContinuousEnv Test] Resetting environment with episode 71. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-20 00:00:02'), Timestamp('2013-11-20 23:59:02'))}
# [2025-08-12 12:16:23:278] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:23:278] [SmartMeterContinuousEnv Test] Episode f_signal sum: -52.322125265082356. Mean: -0.03636005925301067. Std: 0.06782808867184935
# [2025-08-12 12:16:23:278] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:23:295] [SmartMeterContinuousEnv Test] Episode 0071 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0071_info.json
# [2025-08-12 12:16:23:298] [SmartMeterContinuousEnv Test] Resetting environment with episode 72. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-21 00:00:04'), Timestamp('2013-11-21 23:59:04'))}
# [2025-08-12 12:16:28:369] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:28:369] [SmartMeterContinuousEnv Test] Episode f_signal sum: -25.66217810570045. Mean: -0.017833341282627136. Std: 0.03701131778188025
# [2025-08-12 12:16:28:369] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:28:385] [SmartMeterContinuousEnv Test] Episode 0072 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0072_info.json
# [2025-08-12 12:16:28:388] [SmartMeterContinuousEnv Test] Resetting environment with episode 73. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-15 00:00:05'), Timestamp('2013-12-15 23:59:05'))}
# [2025-08-12 12:16:33:637] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:33:637] [SmartMeterContinuousEnv Test] Episode f_signal sum: -37.62333592340345. Mean: -0.026145473192080233. Std: 0.05735852826632385
# [2025-08-12 12:16:33:637] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:33:652] [SmartMeterContinuousEnv Test] Episode 0073 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0073_info.json
# [2025-08-12 12:16:33:655] [SmartMeterContinuousEnv Test] Resetting environment with episode 74. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-16 00:00:06'), Timestamp('2013-12-16 23:59:06'))}
# [2025-08-12 12:16:42:087] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:42:087] [SmartMeterContinuousEnv Test] Episode f_signal sum: -35.54434661827344. Mean: -0.02470072732333109. Std: 0.04738415132643213
# [2025-08-12 12:16:42:087] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:42:102] [SmartMeterContinuousEnv Test] Episode 0074 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0074_info.json
# [2025-08-12 12:16:42:105] [SmartMeterContinuousEnv Test] Resetting environment with episode 75. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-17 00:00:00'), Timestamp('2013-12-17 23:59:00'))}
# [2025-08-12 12:16:46:649] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:46:649] [SmartMeterContinuousEnv Test] Episode f_signal sum: -49.72799852352273. Mean: -0.03455733045415061. Std: 0.0712488209412738
# [2025-08-12 12:16:46:649] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:46:664] [SmartMeterContinuousEnv Test] Episode 0075 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0075_info.json
# [2025-08-12 12:16:46:667] [SmartMeterContinuousEnv Test] Resetting environment with episode 76. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-18 00:00:01'), Timestamp('2013-12-18 23:59:01'))}
# [2025-08-12 12:16:51:205] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:51:205] [SmartMeterContinuousEnv Test] Episode f_signal sum: -27.457834356857145. Mean: -0.01908119135292366. Std: 0.028380499999816653
# [2025-08-12 12:16:51:205] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:51:220] [SmartMeterContinuousEnv Test] Episode 0076 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0076_info.json
# [2025-08-12 12:16:51:224] [SmartMeterContinuousEnv Test] Resetting environment with episode 77. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-19 00:00:05'), Timestamp('2013-12-19 23:59:05'))}
# [2025-08-12 12:16:55:714] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:16:55:715] [SmartMeterContinuousEnv Test] Episode f_signal sum: -42.278161426422635. Mean: -0.029380237266450754. Std: 0.05956575458218722
# [2025-08-12 12:16:55:715] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:16:55:730] [SmartMeterContinuousEnv Test] Episode 0077 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0077_info.json
# [2025-08-12 12:16:55:733] [SmartMeterContinuousEnv Test] Resetting environment with episode 78. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-20 00:00:02'), Timestamp('2013-12-20 23:59:02'))}
# [2025-08-12 12:17:00:226] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:17:00:226] [SmartMeterContinuousEnv Test] Episode f_signal sum: -61.51986296435433. Mean: -0.042751815819565206. Std: 0.0822533583827134
# [2025-08-12 12:17:00:226] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:17:00:242] [SmartMeterContinuousEnv Test] Episode 0078 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0078_info.json
# [2025-08-12 12:17:00:246] [SmartMeterContinuousEnv Test] Resetting environment with episode 79. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-21 00:00:01'), Timestamp('2013-12-21 23:59:01'))}
# [2025-08-12 12:17:04:775] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: -1.3686312500000033. Mean of rewards: -0.0009510988533703983. Std of rewards: 0.0021914362508851436
# [2025-08-12 12:17:04:775] [SmartMeterContinuousEnv Test] Episode f_signal sum: -52.671062995879765. Mean: -0.03660254551485738. Std: 0.0641579717994883
# [2025-08-12 12:17:04:775] [SmartMeterContinuousEnv Test] Episode g_signal sum: 1.368631250000003. Mean: 0.0009510988533703983. Std: 0.0021914362508851436
# [2025-08-12 12:17:04:790] [SmartMeterContinuousEnv Test] Episode 0079 info saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/episode_info/episode_0079_info.json
# [2025-08-12 12:17:04:791] Episode 80/80 completed.
# [2025-08-12 12:17:04:793] Validation results saved to experiments/20250811_064239_action_continuous_reward_lambda_1.0/logs_test/test_stats_file.json
