# %% [markdown]
# # Model Evaluation
#
# This notebook is used to evaluate a trained RL model, which is trained after some number of training iterations, on the unseen testing dataset.
#
# This script is for evaluating trained PPO-MI models.

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from datetime import datetime
import sys

from utils import print_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the created dataset
dataset_folder_path = Path("dataset", "20250707_downsampled_1min", "split")

# %%
from utils_data_split import load_split_data_from_folder, convert_to_naive_datetimes, convert_to_naive_datetimes_df

# %%
aggregate_load_segments_test, aggregate_load_df_test = load_split_data_from_folder(dataset_folder_path, 'test')

# %%
aggregate_load_segments_test, aggregate_load_df_test = convert_to_naive_datetimes(aggregate_load_segments_test), convert_to_naive_datetimes_df(aggregate_load_df_test)

# %% [markdown]
# ---

# %% [markdown]
# Experiment start

# %%
# initialize experiment folder to store related information/data for future analysis

# Change the datetime to point to the correct folder
rl_datetime = datetime(2025, 8, 11, 2, 46, 31)        # 0.0
# rl_datetime = datetime(2025, 8, 11, 4, 45, 55)        # 0.5
# rl_datetime = datetime(2025, 8, 11, 6, 42, 39)          # 1.0

# Keep the action type un-changed
ACTION_TYPE = "continuous"

# Change the lambda according to your experiment
REWARD_LAMBDA = "0.0"  # between 0 and 1

experiment_folder = Path(
    "experiments", rl_datetime.strftime('%Y%m%d_%H%M%S') + f"_action_{ACTION_TYPE}_reward_lambda_{REWARD_LAMBDA}", 
)

if not experiment_folder.exists():
    raise FileNotFoundError(f"Experiment folder {experiment_folder} does not exist. Please check the path.")
else:
    print_log(f"Experiment folder: {experiment_folder}")
# Out:
# [2025-09-23 14:29:16:640] Experiment folder: experiments/20250811_024631_action_continuous_reward_lambda_0.0

# %%
# find the selected checkpoint

selected_ckpt_folder = experiment_folder / "selected_ckpt"

# search for any sub-folders under selected_ckpt_folder
sub_folders = [f for f in selected_ckpt_folder.iterdir() if f.is_dir()]
# assert len(sub_folders) == 1, "There should be exactly one sub-folder in selected_ckpt_folder."

# search for the first folder. Add sorted() to the sub_folders can find the smallest num of iteration checkpoint.
selected_ckpt_folder = sub_folders[0]
selected_ckpt_episode_number = int(selected_ckpt_folder.name.split('_')[-1])

print_log(f"Selected checkpoint folder: {selected_ckpt_folder}")
# Out:
# [2025-09-23 14:29:16:651] Selected checkpoint folder: experiments/20250811_024631_action_continuous_reward_lambda_0.0/selected_ckpt/episode_0602

# %% [markdown]
# TODO: read the experiment_details under the experiment_folder, find the seed element, and use it to set the action_space and RL model for reproducibility

# %% [markdown]
# Create data loader

# %%
sys.path.append(str(Path('rl_env')))
sys.path.append(str(Path('model', 'H_network')))

from rl_env.data_loader import SimpleSmartMeterDataLoader

sm_dl_test = SimpleSmartMeterDataLoader(
    aggregate_load_segments=aggregate_load_segments_test,
    aggregate_load_df=aggregate_load_df_test,
    registry_path=experiment_folder / "simple_episode_registry_test.json"
)

sm_dl_test.get_divided_segments_length()
# Out:
# [SimpleDataLoader] Generated 80 episodes (1 day each)
# 80

# %%
sm_dl_test.divided_segments[7]
# Out:
# array([datetime.datetime(2013, 2, 15, 0, 0),
#        datetime.datetime(2013, 2, 15, 23, 59, 59, 999000)], dtype=object)

# %%
# sample segment

sm_dl_test.get_aggregate_load_segment(13)
# Out:
#         timestamp   aggregate            datetime  segment_index  \
# 18720  1362355201  144.000000 2013-03-04 00:00:01             13
# 18721  1362355261  146.640530 2013-03-04 00:01:01             13
# 18722  1362355321  144.977225 2013-03-04 00:02:01             13
# 18723  1362355381  145.282810 2013-03-04 00:03:01             13
# 18724  1362355441  144.273479 2013-03-04 00:04:01             13
# ...           ...         ...                 ...            ...
# 20155  1362441301  259.357749 2013-03-04 23:55:01             13
# 20156  1362441361  250.485841 2013-03-04 23:56:01             13
# 20157  1362441421  309.990317 2013-03-04 23:57:01             13
# 20158  1362441481  285.959002 2013-03-04 23:58:01             13
# 20159  1362441541  281.678576 2013-03-04 23:59:01             13
#
#       episode_content_id  episode_length_days
# 18720       9eafa9c7f9a1                    1
# 18721       9eafa9c7f9a1                    1
# 18722       9eafa9c7f9a1                    1
# 18723       9eafa9c7f9a1                    1
# 18724       9eafa9c7f9a1                    1
# ...                  ...                  ...
# 20155       9eafa9c7f9a1                    1
# 20156       9eafa9c7f9a1                    1
# 20157       9eafa9c7f9a1                    1
# 20158       9eafa9c7f9a1                    1
# 20159       9eafa9c7f9a1                    1
#
# [1440 rows x 6 columns]

# %% [markdown]
# Create the environment

# %%
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from model.H_network.common.factories import create_h_network_module_with_defaults
from model.H_network.h_network_arch import HNetworkType

# the optimizer class and optimizer kwargs does not matter for the testing loop, but they are required to create the module

h_network_kwargs = {
    "h_network_type": HNetworkType.H_NETWORK,
    "optimizer_class": torch.optim.Adam,
    "optimizer_kwargs": {"lr": 0.001},
}

h_network_rl_module = create_h_network_module_with_defaults(
    action_type=ACTION_TYPE,
    **h_network_kwargs,
    device=DEVICE
)

# %%
from rl_env.base.env_module import SmartMeterEnvFactory
from rl_env.training_mode import TrainingMode
from decimal import Decimal

env_test = SmartMeterEnvFactory.create(
    action_type=ACTION_TYPE,
    smart_meter_data_loader=sm_dl_test,
    h_network_rl_module=h_network_rl_module,
    mode=TrainingMode.TEST,
    reward_lambda=float(REWARD_LAMBDA),
    render_mode=None,
)
# Out:
# [2025-09-23 14:29:18:702] [SmartMeterContinuousEnv Test] Using data loader: SimpleSmartMeterDataLoader
# [2025-09-23 14:29:18:702] [SmartMeterContinuousEnv Test] Curriculum enabled: False
# [2025-09-23 14:29:18:709] [SmartMeterContinuousEnv Test]] Render mode set to 'None'. Render server at 127.0.0.1:50007. render_connected: False. render_client_socket: None

# %%
h_network_rl_module.set_h_network(
    h_network_rl_module.initialize_h_network()
)
h_network_rl_module.initialize_h_network_training()

# %%
# load the h_network from the selected checkpoint

h_network_rl_module.load_h_network(
    selected_ckpt_folder / ("h_network" + f"_{selected_ckpt_episode_number:04d}" + ".pth")
)

# %%
h_network_rl_module.h_network
# Out:
# HNetwork(
#   (LSTM_1): LSTM(2, 44, batch_first=True, bidirectional=True)
#   (ac1): Tanh()
#   (LSTM_2): LSTM(88, 44, batch_first=True, bidirectional=True)
#   (ac2): Tanh()
#   (fc): Linear(in_features=88, out_features=1, bias=True)
# )

# %%
import torchinfo

torchinfo.summary(h_network_rl_module.h_network, input_size=(1, 1, 2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HNetwork                                 [1, 1]                    --
# ├─LSTM: 1-1                              [1, 1, 88]                16,896
# ├─Tanh: 1-2                              [1, 1, 88]                --
# ├─LSTM: 1-3                              [1, 1, 88]                47,168
# ├─Tanh: 1-4                              [1, 1, 88]                --
# ├─Linear: 1-5                            [1, 1, 1]                 89
# ==========================================================================================
# Total params: 64,153
# Trainable params: 64,153
# Non-trainable params: 0
# Total mult-adds (M): 0.06
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.26
# Estimated Total Size (MB): 0.26
# ==========================================================================================

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env_test)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# [2025-09-23 14:29:19:541] [SmartMeterContinuousEnv Test] Resetting environment with episode 38. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-15 00:00:03'), Timestamp('2013-07-15 23:59:03'))}
# [2025-09-23 14:29:19:545] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:29:19:548] [SmartMeterContinuousEnv Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-09-23 14:29:19:550] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:29:19:552] [SmartMeterContinuousEnv Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-09-23 14:29:19:556] [SmartMeterContinuousEnv Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-09-23 14:29:19:559] [SmartMeterContinuousEnv Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:29:19:562] [SmartMeterContinuousEnv Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:29:19:629] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:29:19:634] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# Environment passes all checks!
# /root/miniforge3/envs/smartmeter/lib/python3.9/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
env_test.reset_render_window()

# %% [markdown]
# Also initiate a validation environment for time-to-time validation

# %%
# initialize a DQN agent
from stable_baselines3 import PPO

rl_model = PPO.load(
    selected_ckpt_folder / ("rl_model" + f"_{selected_ckpt_episode_number:04d}"),  # path to the saved RL model
    env=env_test
)
# Out:
# 2025-09-23 14:29:19.891377: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 14:29:19.901133: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758608959.912906   96352 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758608959.916385   96352 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758608959.926409   96352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608959.926434   96352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608959.926435   96352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608959.926436   96352 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-23 14:29:19.929969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
rl_model.policy
# Out:
# MultiInputActorCriticPolicy(
#   (features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (pi_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (vf_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#       (battery_soc): Flatten(start_dim=1, end_dim=-1)
#       (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=1, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
rl_model.n_steps
# Out:
# 704

# %%
log_folder = experiment_folder / "logs_test" / selected_ckpt_folder.name
if not log_folder.exists():
    log_folder.mkdir(parents=True)

# %%
# we test the rl model and H-network

import json
from utils import print_log

total_episodes = env_test.smart_meter_data_loader.get_divided_segments_length()
episode_indices = list(range(total_episodes))

all_episode_rewards = []
all_episode_lengths = []
all_episode_infos = []
per_episode_reward_stats = []

for i, episode_idx in enumerate(episode_indices):
    obs, info = env_test.reset(episode_idx=episode_idx)

    # Initialize episode tracking variables
    episode_reward = 0.0
    episode_length = 0
    done = False
    state = None  # For recurrent policies

    while not done:
        # Get action from the RL model
        # no deterministic, as it will break the learned stochastic policy
        action, state = rl_model.predict(obs, state=state)

        # Step the environment
        obs, reward, done, truncated, info = env_test.step(action)

        # Update episode tracking variables
        episode_reward += reward
        episode_length += 1

    # Store results for this episode
    all_episode_rewards.append(episode_reward)
    all_episode_lengths.append(episode_length)
    all_episode_infos.append({
        "episode_idx": episode_idx,
        "episode_info": env_test.episode.get_episode_info() if hasattr(env_test, 'episode') else {}
    })

    per_episode_reward_stats.append(env_test.prev_episode_reward_stats)

    env_test.save_episode_info(
        log_folder=log_folder,
        episode_training_idx=episode_idx
    )

    if (i + 1) % 10 == 0:
        print_log(f"Episode {i + 1}/{total_episodes} completed.")


# Calculate comprehensive statistics
mean_reward = np.mean(all_episode_rewards)
std_reward = np.std(all_episode_rewards)
min_reward = np.min(all_episode_rewards)
max_reward = np.max(all_episode_rewards)
median_reward = np.median(all_episode_rewards)

# we need to recover the true sum f_signal and g_signal from the per_episode_reward_stats, with length of each episode
f_signal_sums = np.array([item['f_signal_sum'] for item in per_episode_reward_stats])
g_signal_sums = np.array([item['g_signal_sum'] for item in per_episode_reward_stats])

# get the length of each episode
_episode_lengths = np.array(all_episode_lengths)
sum_episode_lengths = np.sum(_episode_lengths)

# calculate the (true) mean of rewards, f_signal and g_signal

f_signal_mean = f_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0
g_signal_mean = g_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0

mean_length = np.mean(all_episode_lengths)
std_length = np.std(all_episode_lengths)

# Prepare validation data
test_data = {
    'evaluated_episodes': len(episode_indices),
    'total_available_episodes': total_episodes,
    'episode_indices': episode_indices,
    'episode_rewards': all_episode_rewards,
    'episode_lengths': all_episode_lengths,
    'episode_infos': all_episode_infos,
    'summary_stats': {
        'mean_reward': mean_reward,
        'std_reward': std_reward,
        'min_reward': min_reward,
        'max_reward': max_reward,
        'median_reward': median_reward,
        'mean_f_signal': f_signal_mean,
        'mean_g_signal': g_signal_mean,
        'mean_length': mean_length,
        'std_length': std_length
    }
}

test_stats_file_path = log_folder / "test_stats_file.json"
with open(test_stats_file_path, 'w') as f:
    # Convert numpy types to Python native types for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        return obj

    json.dump(convert_numpy(test_data), f, indent=2, default=str)

sm_dl_test._save_registry()
print_log(f"Validation results saved to {test_stats_file_path}")
# Out:
# [2025-09-23 14:29:21:054] [SmartMeterContinuousEnv Test] Resetting environment with episode 0. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-01 00:00:01'), Timestamp('2013-01-01 23:59:01'))}
# [2025-09-23 14:29:26:641] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 215.44474360099147. Mean of rewards: 0.1497183763731699. Std of rewards: 0.12786860012115014
# [2025-09-23 14:29:26:641] [SmartMeterContinuousEnv Test] Episode f_signal sum: -215.44474360099147. Mean: -0.1497183763731699. Std: 0.12786860012115014
# [2025-09-23 14:29:26:641] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.3514115106301863. Mean: 0.002328986456310067. Std: 0.0018353684027878235
# [2025-09-23 14:29:26:659] [SmartMeterContinuousEnv Test] Episode 0000 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0000_info.json
# [2025-09-23 14:29:26:663] [SmartMeterContinuousEnv Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:29:31:939] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 219.7265751960211. Mean of rewards: 0.15269393689786037. Std of rewards: 0.12693578327264216
# [2025-09-23 14:29:31:939] [SmartMeterContinuousEnv Test] Episode f_signal sum: -219.7265751960211. Mean: -0.15269393689786037. Std: 0.12693578327264216
# [2025-09-23 14:29:31:939] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.387377121580275. Mean: 0.0023539799316054724. Std: 0.0018420331767069586
# [2025-09-23 14:29:31:958] [SmartMeterContinuousEnv Test] Episode 0001 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0001_info.json
# [2025-09-23 14:29:31:961] [SmartMeterContinuousEnv Test] Resetting environment with episode 2. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-03 00:00:00'), Timestamp('2013-01-03 23:59:00'))}
# [2025-09-23 14:29:37:217] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 209.15990646999205. Mean of rewards: 0.1453508731549632. Std of rewards: 0.13160018088656505
# [2025-09-23 14:29:37:218] [SmartMeterContinuousEnv Test] Episode f_signal sum: -209.15990646999205. Mean: -0.1453508731549632. Std: 0.13160018088656505
# [2025-09-23 14:29:37:218] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.5231980245462293. Mean: 0.0024483655486770184. Std: 0.0018362411695965232
# [2025-09-23 14:29:37:235] [SmartMeterContinuousEnv Test] Episode 0002 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0002_info.json
# [2025-09-23 14:29:37:239] [SmartMeterContinuousEnv Test] Resetting environment with episode 3. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-04 00:00:05'), Timestamp('2013-01-04 23:59:05'))}
# [2025-09-23 14:29:42:475] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 207.49961992904747. Mean of rewards: 0.14419709515569665. Std of rewards: 0.13305591269385628
# [2025-09-23 14:29:42:475] [SmartMeterContinuousEnv Test] Episode f_signal sum: -207.49961992904747. Mean: -0.14419709515569665. Std: 0.13305591269385628
# [2025-09-23 14:29:42:475] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.376532809485508. Mean: 0.0023464439259802. Std: 0.0018896061930150933
# [2025-09-23 14:29:42:493] [SmartMeterContinuousEnv Test] Episode 0003 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0003_info.json
# [2025-09-23 14:29:42:496] [SmartMeterContinuousEnv Test] Resetting environment with episode 4. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-05 00:00:04'), Timestamp('2013-01-05 23:59:04'))}
# [2025-09-23 14:29:47:802] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 203.3261552540301. Mean of rewards: 0.14129684173316895. Std of rewards: 0.12800294802882853
# [2025-09-23 14:29:47:802] [SmartMeterContinuousEnv Test] Episode f_signal sum: -203.3261552540301. Mean: -0.14129684173316895. Std: 0.12800294802882853
# [2025-09-23 14:29:47:802] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.204727334839977. Mean: 0.002227051657289769. Std: 0.0018082818477736947
# [2025-09-23 14:29:47:821] [SmartMeterContinuousEnv Test] Episode 0004 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0004_info.json
# [2025-09-23 14:29:47:825] [SmartMeterContinuousEnv Test] Resetting environment with episode 5. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-06 00:00:01'), Timestamp('2013-01-06 23:59:01'))}
# [2025-09-23 14:29:53:980] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 205.1408536667738. Mean of rewards: 0.1425579247163126. Std of rewards: 0.13065232263453067
# [2025-09-23 14:29:53:980] [SmartMeterContinuousEnv Test] Episode f_signal sum: -205.1408536667738. Mean: -0.1425579247163126. Std: 0.13065232263453067
# [2025-09-23 14:29:53:980] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.4101764217467423. Mean: 0.0023698237816169162. Std: 0.0018785383385793153
# [2025-09-23 14:29:53:998] [SmartMeterContinuousEnv Test] Episode 0005 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0005_info.json
# [2025-09-23 14:29:54:002] [SmartMeterContinuousEnv Test] Resetting environment with episode 6. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-14 00:00:03'), Timestamp('2013-02-14 23:59:03'))}
# [2025-09-23 14:29:59:205] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 201.9722107572748. Mean of rewards: 0.1403559491016503. Std of rewards: 0.1346145852114295
# [2025-09-23 14:29:59:205] [SmartMeterContinuousEnv Test] Episode f_signal sum: -201.9722107572748. Mean: -0.1403559491016503. Std: 0.1346145852114295
# [2025-09-23 14:29:59:205] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.1341138450451176. Mean: 0.0021779804343607487. Std: 0.0018376121315226766
# [2025-09-23 14:29:59:223] [SmartMeterContinuousEnv Test] Episode 0006 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0006_info.json
# [2025-09-23 14:29:59:227] [SmartMeterContinuousEnv Test] Resetting environment with episode 7. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-15 00:00:00'), Timestamp('2013-02-15 23:59:00'))}
# [2025-09-23 14:30:04:468] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 196.59731576831828. Mean of rewards: 0.13662078927610719. Std of rewards: 0.1327110188230623
# [2025-09-23 14:30:04:468] [SmartMeterContinuousEnv Test] Episode f_signal sum: -196.59731576831825. Mean: -0.13662078927610719. Std: 0.1327110188230623
# [2025-09-23 14:30:04:468] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.164405173233229. Mean: 0.002199030697173891. Std: 0.0016625982020609304
# [2025-09-23 14:30:04:486] [SmartMeterContinuousEnv Test] Episode 0007 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0007_info.json
# [2025-09-23 14:30:04:489] [SmartMeterContinuousEnv Test] Resetting environment with episode 8. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-16 00:00:02'), Timestamp('2013-02-16 23:59:02'))}
# [2025-09-23 14:30:09:548] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 189.69318844706612. Mean of rewards: 0.13182292456363176. Std of rewards: 0.13474247810504644
# [2025-09-23 14:30:09:548] [SmartMeterContinuousEnv Test] Episode f_signal sum: -189.69318844706612. Mean: -0.13182292456363176. Std: 0.13474247810504644
# [2025-09-23 14:30:09:548] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.142807959784136. Mean: 0.0021840222097179542. Std: 0.0018174979188176998
# [2025-09-23 14:30:09:567] [SmartMeterContinuousEnv Test] Episode 0008 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0008_info.json
# [2025-09-23 14:30:09:571] [SmartMeterContinuousEnv Test] Resetting environment with episode 9. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-17 00:00:01'), Timestamp('2013-02-17 23:59:01'))}
# [2025-09-23 14:30:14:836] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 178.89049789195153. Mean of rewards: 0.12431584287140479. Std of rewards: 0.1299139272390425
# [2025-09-23 14:30:14:836] [SmartMeterContinuousEnv Test] Episode f_signal sum: -178.8904978919515. Mean: -0.12431584287140479. Std: 0.1299139272390425
# [2025-09-23 14:30:14:836] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.2127251041364446. Mean: 0.0022326095233748747. Std: 0.0019340698268369948
# [2025-09-23 14:30:14:855] [SmartMeterContinuousEnv Test] Episode 0009 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0009_info.json
# [2025-09-23 14:30:14:855] Episode 10/80 completed.
# [2025-09-23 14:30:14:859] [SmartMeterContinuousEnv Test] Resetting environment with episode 10. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-01 00:00:00'), Timestamp('2013-03-01 23:59:00'))}
# [2025-09-23 14:30:20:146] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 197.41445826602458. Mean of rewards: 0.1371886436872999. Std of rewards: 0.13230905519933467
# [2025-09-23 14:30:20:146] [SmartMeterContinuousEnv Test] Episode f_signal sum: -197.41445826602458. Mean: -0.1371886436872999. Std: 0.13230905519933467
# [2025-09-23 14:30:20:146] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.035543081462134. Mean: 0.002109480946116841. Std: 0.0018092977763220714
# [2025-09-23 14:30:20:164] [SmartMeterContinuousEnv Test] Episode 0010 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0010_info.json
# [2025-09-23 14:30:20:168] [SmartMeterContinuousEnv Test] Resetting environment with episode 11. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-02 00:00:02'), Timestamp('2013-03-02 23:59:02'))}
# [2025-09-23 14:30:26:342] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 195.4968028546238. Mean of rewards: 0.13585601310258777. Std of rewards: 0.13021358402392533
# [2025-09-23 14:30:26:342] [SmartMeterContinuousEnv Test] Episode f_signal sum: -195.4968028546238. Mean: -0.13585601310258777. Std: 0.13021358402392533
# [2025-09-23 14:30:26:342] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.2466112634338797. Mean: 0.0022561579315037387. Std: 0.0018962303951179052
# [2025-09-23 14:30:26:361] [SmartMeterContinuousEnv Test] Episode 0011 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0011_info.json
# [2025-09-23 14:30:26:364] [SmartMeterContinuousEnv Test] Resetting environment with episode 12. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-03 00:00:03'), Timestamp('2013-03-03 23:59:03'))}
# [2025-09-23 14:30:31:603] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 181.95438518148052. Mean of rewards: 0.1264450209739267. Std of rewards: 0.12465095465844063
# [2025-09-23 14:30:31:603] [SmartMeterContinuousEnv Test] Episode f_signal sum: -181.95438518148052. Mean: -0.1264450209739267. Std: 0.12465095465844063
# [2025-09-23 14:30:31:603] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0316003992763245. Mean: 0.0021067410696847286. Std: 0.0018640370940909883
# [2025-09-23 14:30:31:621] [SmartMeterContinuousEnv Test] Episode 0012 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0012_info.json
# [2025-09-23 14:30:31:624] [SmartMeterContinuousEnv Test] Resetting environment with episode 13. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-04 00:00:01'), Timestamp('2013-03-04 23:59:01'))}
# [2025-09-23 14:30:36:711] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 210.42977496020922. Mean of rewards: 0.14623333909674024. Std of rewards: 0.1385915083636766
# [2025-09-23 14:30:36:711] [SmartMeterContinuousEnv Test] Episode f_signal sum: -210.42977496020922. Mean: -0.14623333909674024. Std: 0.1385915083636766
# [2025-09-23 14:30:36:711] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9573585056732896. Mean: 0.0020551483708639955. Std: 0.0017933540648692506
# [2025-09-23 14:30:36:730] [SmartMeterContinuousEnv Test] Episode 0013 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0013_info.json
# [2025-09-23 14:30:36:733] [SmartMeterContinuousEnv Test] Resetting environment with episode 14. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-05 00:00:00'), Timestamp('2013-03-05 23:59:00'))}
# [2025-09-23 14:30:42:141] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 218.19212294961403. Mean of rewards: 0.15162760455150384. Std of rewards: 0.139028409417581
# [2025-09-23 14:30:42:141] [SmartMeterContinuousEnv Test] Episode f_signal sum: -218.19212294961403. Mean: -0.15162760455150384. Std: 0.139028409417581
# [2025-09-23 14:30:42:141] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.069377412267266. Mean: 0.002132993337225341. Std: 0.0017861598201268944
# [2025-09-23 14:30:42:159] [SmartMeterContinuousEnv Test] Episode 0014 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0014_info.json
# [2025-09-23 14:30:42:163] [SmartMeterContinuousEnv Test] Resetting environment with episode 15. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-06 00:00:02'), Timestamp('2013-03-06 23:59:02'))}
# [2025-09-23 14:30:47:422] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 202.385060174932. Mean of rewards: 0.14064284932239887. Std of rewards: 0.12393986974493662
# [2025-09-23 14:30:47:422] [SmartMeterContinuousEnv Test] Episode f_signal sum: -202.385060174932. Mean: -0.14064284932239887. Std: 0.12393986974493662
# [2025-09-23 14:30:47:422] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.168101391678931. Mean: 0.0022015992992904317. Std: 0.0018599860029365194
# [2025-09-23 14:30:47:440] [SmartMeterContinuousEnv Test] Episode 0015 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0015_info.json
# [2025-09-23 14:30:47:444] [SmartMeterContinuousEnv Test] Resetting environment with episode 16. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-07 00:00:02'), Timestamp('2013-03-07 23:59:02'))}
# [2025-09-23 14:30:52:846] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 204.62729973552624. Mean of rewards: 0.14220104220675903. Std of rewards: 0.13143508245941543
# [2025-09-23 14:30:52:846] [SmartMeterContinuousEnv Test] Episode f_signal sum: -204.62729973552624. Mean: -0.14220104220675903. Std: 0.13143508245941543
# [2025-09-23 14:30:52:846] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.1837669331090397. Mean: 0.002212485707511494. Std: 0.0018495542554287
# [2025-09-23 14:30:52:865] [SmartMeterContinuousEnv Test] Episode 0016 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0016_info.json
# [2025-09-23 14:30:52:869] [SmartMeterContinuousEnv Test] Resetting environment with episode 17. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-19 00:00:03'), Timestamp('2013-04-19 23:59:03'))}
# [2025-09-23 14:30:58:970] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 196.9498982389616. Mean of rewards: 0.13686580836619985. Std of rewards: 0.1299979885197091
# [2025-09-23 14:30:58:970] [SmartMeterContinuousEnv Test] Episode f_signal sum: -196.9498982389616. Mean: -0.13686580836619985. Std: 0.1299979885197091
# [2025-09-23 14:30:58:970] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.05173155650332. Mean: 0.0021207307550405283. Std: 0.0018305792665648615
# [2025-09-23 14:30:58:989] [SmartMeterContinuousEnv Test] Episode 0017 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0017_info.json
# [2025-09-23 14:30:58:992] [SmartMeterContinuousEnv Test] Resetting environment with episode 18. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-20 00:00:05'), Timestamp('2013-04-20 23:59:05'))}
# [2025-09-23 14:31:04:394] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 195.5114488239275. Mean of rewards: 0.13586619098257643. Std of rewards: 0.13594723081570556
# [2025-09-23 14:31:04:394] [SmartMeterContinuousEnv Test] Episode f_signal sum: -195.5114488239275. Mean: -0.13586619098257643. Std: 0.13594723081570556
# [2025-09-23 14:31:04:394] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.05760064354838. Mean: 0.002124809342285184. Std: 0.00175377937517446
# [2025-09-23 14:31:04:412] [SmartMeterContinuousEnv Test] Episode 0018 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0018_info.json
# [2025-09-23 14:31:04:416] [SmartMeterContinuousEnv Test] Resetting environment with episode 19. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-21 00:00:03'), Timestamp('2013-04-21 23:59:03'))}
# [2025-09-23 14:31:09:578] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 163.6044047443843. Mean of rewards: 0.11369312351937755. Std of rewards: 0.11803870753535131
# [2025-09-23 14:31:09:578] [SmartMeterContinuousEnv Test] Episode f_signal sum: -163.60440474438428. Mean: -0.11369312351937755. Std: 0.11803870753535131
# [2025-09-23 14:31:09:578] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.861342911638525. Mean: 0.0019884245390121786. Std: 0.0018028959910424687
# [2025-09-23 14:31:09:597] [SmartMeterContinuousEnv Test] Episode 0019 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0019_info.json
# [2025-09-23 14:31:09:597] Episode 20/80 completed.
# [2025-09-23 14:31:09:600] [SmartMeterContinuousEnv Test] Resetting environment with episode 20. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-22 00:00:00'), Timestamp('2013-04-22 23:59:00'))}
# [2025-09-23 14:31:14:607] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 207.03688856596267. Mean of rewards: 0.14387553062262867. Std of rewards: 0.12707847566930872
# [2025-09-23 14:31:14:607] [SmartMeterContinuousEnv Test] Episode f_signal sum: -207.03688856596267. Mean: -0.14387553062262867. Std: 0.12707847566930872
# [2025-09-23 14:31:14:607] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.300533661794454. Mean: 0.0022936300637904474. Std: 0.0019086833627953855
# [2025-09-23 14:31:14:625] [SmartMeterContinuousEnv Test] Episode 0020 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0020_info.json
# [2025-09-23 14:31:14:628] [SmartMeterContinuousEnv Test] Resetting environment with episode 21. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-23 00:00:05'), Timestamp('2013-04-23 23:59:05'))}
# [2025-09-23 14:31:19:819] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 209.6187243723747. Mean of rewards: 0.14566971811839796. Std of rewards: 0.13689889964225538
# [2025-09-23 14:31:19:819] [SmartMeterContinuousEnv Test] Episode f_signal sum: -209.6187243723747. Mean: -0.14566971811839796. Std: 0.13689889964225538
# [2025-09-23 14:31:19:819] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9931536461431447. Mean: 0.002080023381614416. Std: 0.0017552885438904277
# [2025-09-23 14:31:19:837] [SmartMeterContinuousEnv Test] Episode 0021 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0021_info.json
# [2025-09-23 14:31:19:841] [SmartMeterContinuousEnv Test] Resetting environment with episode 22. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-24 00:00:00'), Timestamp('2013-04-24 23:59:00'))}
# [2025-09-23 14:31:25:080] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 230.49963254046062. Mean of rewards: 0.1601804256709247. Std of rewards: 0.13100219968944923
# [2025-09-23 14:31:25:080] [SmartMeterContinuousEnv Test] Episode f_signal sum: -230.49963254046062. Mean: -0.1601804256709247. Std: 0.13100219968944923
# [2025-09-23 14:31:25:080] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.099194272636664. Mean: 0.0021537138795251314. Std: 0.001822176861906178
# [2025-09-23 14:31:25:098] [SmartMeterContinuousEnv Test] Episode 0022 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0022_info.json
# [2025-09-23 14:31:25:102] [SmartMeterContinuousEnv Test] Resetting environment with episode 23. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-25 00:00:03'), Timestamp('2013-04-25 23:59:03'))}
# [2025-09-23 14:31:31:092] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 198.53638175486458. Mean of rewards: 0.1379682986482728. Std of rewards: 0.13222489739894736
# [2025-09-23 14:31:31:093] [SmartMeterContinuousEnv Test] Episode f_signal sum: -198.53638175486458. Mean: -0.1379682986482728. Std: 0.13222489739894736
# [2025-09-23 14:31:31:093] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.1226556745339877. Mean: 0.002170017841927719. Std: 0.0018033232447070256
# [2025-09-23 14:31:31:111] [SmartMeterContinuousEnv Test] Episode 0023 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0023_info.json
# [2025-09-23 14:31:31:115] [SmartMeterContinuousEnv Test] Resetting environment with episode 24. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-18 00:00:03'), Timestamp('2013-05-18 23:59:03'))}
# [2025-09-23 14:31:36:311] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 146.35145227146774. Mean of rewards: 0.10170358045272254. Std of rewards: 0.11360551753142949
# [2025-09-23 14:31:36:311] [SmartMeterContinuousEnv Test] Episode f_signal sum: -146.35145227146774. Mean: -0.10170358045272254. Std: 0.11360551753142949
# [2025-09-23 14:31:36:311] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.087208996959867. Mean: 0.002145384987463424. Std: 0.0017840266734006193
# [2025-09-23 14:31:36:330] [SmartMeterContinuousEnv Test] Episode 0024 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0024_info.json
# [2025-09-23 14:31:36:333] [SmartMeterContinuousEnv Test] Resetting environment with episode 25. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-19 00:00:01'), Timestamp('2013-05-19 23:59:01'))}
# [2025-09-23 14:31:41:433] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 182.1387985995552. Mean of rewards: 0.1265731748433323. Std of rewards: 0.12373417966205923
# [2025-09-23 14:31:41:433] [SmartMeterContinuousEnv Test] Episode f_signal sum: -182.1387985995552. Mean: -0.1265731748433323. Std: 0.12373417966205923
# [2025-09-23 14:31:41:433] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.1626251179873175. Mean: 0.002197793688663876. Std: 0.0018531140854965544
# [2025-09-23 14:31:41:451] [SmartMeterContinuousEnv Test] Episode 0025 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0025_info.json
# [2025-09-23 14:31:41:455] [SmartMeterContinuousEnv Test] Resetting environment with episode 26. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-20 00:00:04'), Timestamp('2013-05-20 23:59:04'))}
# [2025-09-23 14:31:46:596] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 207.55718129358837. Mean of rewards: 0.144237096103953. Std of rewards: 0.12886090271408981
# [2025-09-23 14:31:46:596] [SmartMeterContinuousEnv Test] Episode f_signal sum: -207.55718129358837. Mean: -0.144237096103953. Std: 0.12886090271408981
# [2025-09-23 14:31:46:596] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.151003480736052. Mean: 0.002189717498774185. Std: 0.001812389384330193
# [2025-09-23 14:31:46:615] [SmartMeterContinuousEnv Test] Episode 0026 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0026_info.json
# [2025-09-23 14:31:46:618] [SmartMeterContinuousEnv Test] Resetting environment with episode 27. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-21 00:00:02'), Timestamp('2013-05-21 23:59:02'))}
# [2025-09-23 14:31:51:739] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 208.66733023214084. Mean of rewards: 0.14500856861163366. Std of rewards: 0.13818530591858863
# [2025-09-23 14:31:51:739] [SmartMeterContinuousEnv Test] Episode f_signal sum: -208.66733023214084. Mean: -0.14500856861163366. Std: 0.13818530591858863
# [2025-09-23 14:31:51:739] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.259720044145852. Mean: 0.0022652675775857206. Std: 0.0017440244371841496
# [2025-09-23 14:31:51:757] [SmartMeterContinuousEnv Test] Episode 0027 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0027_info.json
# [2025-09-23 14:31:51:761] [SmartMeterContinuousEnv Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-09-23 14:31:56:916] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 192.13318333444622. Mean of rewards: 0.13351854297042823. Std of rewards: 0.13530928793851052
# [2025-09-23 14:31:56:916] [SmartMeterContinuousEnv Test] Episode f_signal sum: -192.13318333444622. Mean: -0.13351854297042823. Std: 0.13530928793851052
# [2025-09-23 14:31:56:916] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.138906068814939. Mean: 0.002181310680204961. Std: 0.00192342409951732
# [2025-09-23 14:31:56:935] [SmartMeterContinuousEnv Test] Episode 0028 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0028_info.json
# [2025-09-23 14:31:56:938] [SmartMeterContinuousEnv Test] Resetting environment with episode 29. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-23 00:00:01'), Timestamp('2013-05-23 23:59:01'))}
# [2025-09-23 14:32:02:804] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 197.50328767369948. Mean of rewards: 0.1372503736439885. Std of rewards: 0.12206379585237259
# [2025-09-23 14:32:02:804] [SmartMeterContinuousEnv Test] Episode f_signal sum: -197.50328767369948. Mean: -0.1372503736439885. Std: 0.12206379585237259
# [2025-09-23 14:32:02:804] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.7824349768263286. Mean: 0.0019335892820196863. Std: 0.0018888958927693487
# [2025-09-23 14:32:02:822] [SmartMeterContinuousEnv Test] Episode 0029 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0029_info.json
# [2025-09-23 14:32:02:822] Episode 30/80 completed.
# [2025-09-23 14:32:02:826] [SmartMeterContinuousEnv Test] Resetting environment with episode 30. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-24 00:00:01'), Timestamp('2013-05-24 23:59:01'))}
# [2025-09-23 14:32:08:062] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 196.4927585327815. Mean of rewards: 0.13654812962667234. Std of rewards: 0.12878869538241605
# [2025-09-23 14:32:08:062] [SmartMeterContinuousEnv Test] Episode f_signal sum: -196.4927585327815. Mean: -0.13654812962667234. Std: 0.12878869538241605
# [2025-09-23 14:32:08:062] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.7109707076518728. Mean: 0.001883926829500954. Std: 0.001780516645591199
# [2025-09-23 14:32:08:081] [SmartMeterContinuousEnv Test] Episode 0030 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0030_info.json
# [2025-09-23 14:32:08:085] [SmartMeterContinuousEnv Test] Resetting environment with episode 31. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-18 00:00:04'), Timestamp('2013-06-18 23:59:04'))}
# [2025-09-23 14:32:13:383] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 209.21151432615588. Mean of rewards: 0.14538673684930917. Std of rewards: 0.13215347091709242
# [2025-09-23 14:32:13:383] [SmartMeterContinuousEnv Test] Episode f_signal sum: -209.21151432615588. Mean: -0.14538673684930917. Std: 0.13215347091709242
# [2025-09-23 14:32:13:383] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0635757248493505. Mean: 0.002128961587803579. Std: 0.0018149640258617638
# [2025-09-23 14:32:13:402] [SmartMeterContinuousEnv Test] Episode 0031 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0031_info.json
# [2025-09-23 14:32:13:406] [SmartMeterContinuousEnv Test] Resetting environment with episode 32. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-19 00:00:05'), Timestamp('2013-06-19 23:59:05'))}
# [2025-09-23 14:32:18:736] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 205.18790664958306. Mean of rewards: 0.1425906231060341. Std of rewards: 0.1274453721087091
# [2025-09-23 14:32:18:736] [SmartMeterContinuousEnv Test] Episode f_signal sum: -205.18790664958306. Mean: -0.1425906231060341. Std: 0.1274453721087091
# [2025-09-23 14:32:18:736] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.2175567408501373. Mean: 0.00223596715833922. Std: 0.001829245578797411
# [2025-09-23 14:32:18:755] [SmartMeterContinuousEnv Test] Episode 0032 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0032_info.json
# [2025-09-23 14:32:18:758] [SmartMeterContinuousEnv Test] Resetting environment with episode 33. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-20 00:00:00'), Timestamp('2013-06-20 23:59:00'))}
# [2025-09-23 14:32:24:149] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 214.92348438138603. Mean of rewards: 0.149356139250442. Std of rewards: 0.13908211828937025
# [2025-09-23 14:32:24:149] [SmartMeterContinuousEnv Test] Episode f_signal sum: -214.92348438138603. Mean: -0.149356139250442. Std: 0.13908211828937025
# [2025-09-23 14:32:24:149] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9985293856337174. Mean: 0.0020837591283069615. Std: 0.0018643687819856357
# [2025-09-23 14:32:24:167] [SmartMeterContinuousEnv Test] Episode 0033 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0033_info.json
# [2025-09-23 14:32:24:170] [SmartMeterContinuousEnv Test] Resetting environment with episode 34. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-21 00:00:03'), Timestamp('2013-06-21 23:59:03'))}
# [2025-09-23 14:32:29:546] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 202.42229817739414. Mean of rewards: 0.14066872701695216. Std of rewards: 0.1345492754114756
# [2025-09-23 14:32:29:546] [SmartMeterContinuousEnv Test] Episode f_signal sum: -202.42229817739414. Mean: -0.14066872701695216. Std: 0.1345492754114756
# [2025-09-23 14:32:29:546] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.837357032733707. Mean: 0.0019717561033590738. Std: 0.001774171229610601
# [2025-09-23 14:32:29:565] [SmartMeterContinuousEnv Test] Episode 0034 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0034_info.json
# [2025-09-23 14:32:29:569] [SmartMeterContinuousEnv Test] Resetting environment with episode 35. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-22 00:00:05'), Timestamp('2013-06-22 23:59:05'))}
# [2025-09-23 14:32:35:570] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 178.09789404492577. Mean of rewards: 0.12376504103191506. Std of rewards: 0.13546664897626992
# [2025-09-23 14:32:35:571] [SmartMeterContinuousEnv Test] Episode f_signal sum: -178.09789404492577. Mean: -0.12376504103191506. Std: 0.13546664897626992
# [2025-09-23 14:32:35:571] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.8122477417630702. Mean: 0.001954306978292613. Std: 0.0017836035384359232
# [2025-09-23 14:32:35:589] [SmartMeterContinuousEnv Test] Episode 0035 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0035_info.json
# [2025-09-23 14:32:35:592] [SmartMeterContinuousEnv Test] Resetting environment with episode 36. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-23 00:00:03'), Timestamp('2013-06-23 23:59:03'))}
# [2025-09-23 14:32:40:934] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 169.06916174666208. Mean of rewards: 0.11749073088718699. Std of rewards: 0.12191542591201121
# [2025-09-23 14:32:40:935] [SmartMeterContinuousEnv Test] Episode f_signal sum: -169.06916174666208. Mean: -0.11749073088718699. Std: 0.12191542591201121
# [2025-09-23 14:32:40:935] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9960385212288774. Mean: 0.0020820281592973436. Std: 0.0018058161291404373
# [2025-09-23 14:32:40:953] [SmartMeterContinuousEnv Test] Episode 0036 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0036_info.json
# [2025-09-23 14:32:40:957] [SmartMeterContinuousEnv Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:32:46:612] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 210.32248228802146. Mean of rewards: 0.14615877851843048. Std of rewards: 0.13833567558755494
# [2025-09-23 14:32:46:612] [SmartMeterContinuousEnv Test] Episode f_signal sum: -210.32248228802146. Mean: -0.14615877851843048. Std: 0.13833567558755494
# [2025-09-23 14:32:46:612] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0106137297800437. Mean: 0.002092156865726229. Std: 0.0018125754711440184
# [2025-09-23 14:32:46:631] [SmartMeterContinuousEnv Test] Episode 0037 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0037_info.json
# [2025-09-23 14:32:46:634] [SmartMeterContinuousEnv Test] Resetting environment with episode 38. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-15 00:00:03'), Timestamp('2013-07-15 23:59:03'))}
# [2025-09-23 14:32:52:267] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 212.68519552402842. Mean of rewards: 0.147800691816559. Std of rewards: 0.1392271296891106
# [2025-09-23 14:32:52:267] [SmartMeterContinuousEnv Test] Episode f_signal sum: -212.68519552402842. Mean: -0.147800691816559. Std: 0.1392271296891106
# [2025-09-23 14:32:52:267] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0488285807306. Mean: 0.0021187133987009034. Std: 0.001820757134807916
# [2025-09-23 14:32:52:286] [SmartMeterContinuousEnv Test] Episode 0038 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0038_info.json
# [2025-09-23 14:32:52:289] [SmartMeterContinuousEnv Test] Resetting environment with episode 39. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-16 00:00:05'), Timestamp('2013-07-16 23:59:05'))}
# [2025-09-23 14:32:57:936] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 205.20413984293882. Mean of rewards: 0.14260190399092343. Std of rewards: 0.12520656533693117
# [2025-09-23 14:32:57:936] [SmartMeterContinuousEnv Test] Episode f_signal sum: -205.20413984293882. Mean: -0.14260190399092343. Std: 0.12520656533693117
# [2025-09-23 14:32:57:936] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.3453676046043808. Mean: 0.0023247863826298685. Std: 0.0018268330322188462
# [2025-09-23 14:32:57:955] [SmartMeterContinuousEnv Test] Episode 0039 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0039_info.json
# [2025-09-23 14:32:57:955] Episode 40/80 completed.
# [2025-09-23 14:32:57:958] [SmartMeterContinuousEnv Test] Resetting environment with episode 40. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-17 00:00:02'), Timestamp('2013-07-17 23:59:02'))}
# [2025-09-23 14:33:03:553] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 203.8604426766999. Mean of rewards: 0.14166813250639326. Std of rewards: 0.13649200293562425
# [2025-09-23 14:33:03:553] [SmartMeterContinuousEnv Test] Episode f_signal sum: -203.8604426766999. Mean: -0.14166813250639326. Std: 0.13649200293562425
# [2025-09-23 14:33:03:553] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.348207103009156. Mean: 0.002326759626830546. Std: 0.00192770232339384
# [2025-09-23 14:33:03:571] [SmartMeterContinuousEnv Test] Episode 0040 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0040_info.json
# [2025-09-23 14:33:03:575] [SmartMeterContinuousEnv Test] Resetting environment with episode 41. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-18 00:00:01'), Timestamp('2013-07-18 23:59:01'))}
# [2025-09-23 14:33:09:894] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 237.1967187024117. Mean of rewards: 0.1648344118849282. Std of rewards: 0.1247895798756049
# [2025-09-23 14:33:09:895] [SmartMeterContinuousEnv Test] Episode f_signal sum: -237.1967187024117. Mean: -0.1648344118849282. Std: 0.1247895798756049
# [2025-09-23 14:33:09:895] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.7954220369290166. Mean: 0.0019426143411598448. Std: 0.0017727462341395725
# [2025-09-23 14:33:09:913] [SmartMeterContinuousEnv Test] Episode 0041 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0041_info.json
# [2025-09-23 14:33:09:916] [SmartMeterContinuousEnv Test] Resetting environment with episode 42. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-19 00:00:05'), Timestamp('2013-07-19 23:59:05'))}
# [2025-09-23 14:33:15:323] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 208.17915176075965. Mean of rewards: 0.14466932019510748. Std of rewards: 0.13367921133532865
# [2025-09-23 14:33:15:323] [SmartMeterContinuousEnv Test] Episode f_signal sum: -208.17915176075965. Mean: -0.14466932019510748. Std: 0.13367921133532865
# [2025-09-23 14:33:15:323] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.686588379723197. Mean: 0.0018669828907040978. Std: 0.0017644311340662892
# [2025-09-23 14:33:15:342] [SmartMeterContinuousEnv Test] Episode 0042 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0042_info.json
# [2025-09-23 14:33:15:346] [SmartMeterContinuousEnv Test] Resetting environment with episode 43. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-20 00:00:00'), Timestamp('2013-07-20 23:59:00'))}
# [2025-09-23 14:33:20:527] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 206.2136110039204. Mean of rewards: 0.14330341278938177. Std of rewards: 0.1313264652587408
# [2025-09-23 14:33:20:528] [SmartMeterContinuousEnv Test] Episode f_signal sum: -206.2136110039204. Mean: -0.14330341278938177. Std: 0.1313264652587408
# [2025-09-23 14:33:20:528] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.881319674670679. Mean: 0.0020023069316682965. Std: 0.0019637325241106634
# [2025-09-23 14:33:20:546] [SmartMeterContinuousEnv Test] Episode 0043 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0043_info.json
# [2025-09-23 14:33:20:549] [SmartMeterContinuousEnv Test] Resetting environment with episode 44. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-21 00:00:04'), Timestamp('2013-07-21 23:59:04'))}
# [2025-09-23 14:33:25:773] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 193.80029242262083. Mean of rewards: 0.13467706214219655. Std of rewards: 0.13043011950455108
# [2025-09-23 14:33:25:773] [SmartMeterContinuousEnv Test] Episode f_signal sum: -193.80029242262083. Mean: -0.13467706214219655. Std: 0.13043011950455108
# [2025-09-23 14:33:25:773] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.8037178364663458. Mean: 0.001948379316515876. Std: 0.0018411761066044524
# [2025-09-23 14:33:25:793] [SmartMeterContinuousEnv Test] Episode 0044 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0044_info.json
# [2025-09-23 14:33:25:796] [SmartMeterContinuousEnv Test] Resetting environment with episode 45. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-15 00:00:01'), Timestamp('2013-08-15 23:59:01'))}
# [2025-09-23 14:33:30:927] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 199.70620494939976. Mean of rewards: 0.13878124040958983. Std of rewards: 0.12893037615696673
# [2025-09-23 14:33:30:927] [SmartMeterContinuousEnv Test] Episode f_signal sum: -199.70620494939976. Mean: -0.13878124040958983. Std: 0.12893037615696673
# [2025-09-23 14:33:30:927] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.178930334824349. Mean: 0.0022091246246173377. Std: 0.001883161728830996
# [2025-09-23 14:33:30:945] [SmartMeterContinuousEnv Test] Episode 0045 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0045_info.json
# [2025-09-23 14:33:30:949] [SmartMeterContinuousEnv Test] Resetting environment with episode 46. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-16 00:00:05'), Timestamp('2013-08-16 23:59:05'))}
# [2025-09-23 14:33:36:088] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 203.54559750527991. Mean of rewards: 0.14144933808567053. Std of rewards: 0.13566287736614777
# [2025-09-23 14:33:36:088] [SmartMeterContinuousEnv Test] Episode f_signal sum: -203.54559750527991. Mean: -0.14144933808567053. Std: 0.13566287736614777
# [2025-09-23 14:33:36:088] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.043890485013329. Mean: 0.0021152817824971015. Std: 0.0018485815584276793
# [2025-09-23 14:33:36:106] [SmartMeterContinuousEnv Test] Episode 0046 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0046_info.json
# [2025-09-23 14:33:36:109] [SmartMeterContinuousEnv Test] Resetting environment with episode 47. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-17 00:00:02'), Timestamp('2013-08-17 23:59:02'))}
# [2025-09-23 14:33:42:076] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 216.19690511741402. Mean of rewards: 0.15024107374385964. Std of rewards: 0.11868294687287145
# [2025-09-23 14:33:42:077] [SmartMeterContinuousEnv Test] Episode f_signal sum: -216.19690511741402. Mean: -0.15024107374385964. Std: 0.11868294687287145
# [2025-09-23 14:33:42:077] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.6275236960905275. Mean: 0.0018259372453721526. Std: 0.0017281683131494523
# [2025-09-23 14:33:42:095] [SmartMeterContinuousEnv Test] Episode 0047 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0047_info.json
# [2025-09-23 14:33:42:098] [SmartMeterContinuousEnv Test] Resetting environment with episode 48. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-18 00:00:05'), Timestamp('2013-08-18 23:59:05'))}
# [2025-09-23 14:33:47:445] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 153.8556404762242. Mean of rewards: 0.10691844369438791. Std of rewards: 0.12236674421858204
# [2025-09-23 14:33:47:445] [SmartMeterContinuousEnv Test] Episode f_signal sum: -153.8556404762242. Mean: -0.10691844369438791. Std: 0.12236674421858204
# [2025-09-23 14:33:47:445] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.776964204945297. Mean: 0.0019297874947500327. Std: 0.0017122116088126925
# [2025-09-23 14:33:47:464] [SmartMeterContinuousEnv Test] Episode 0048 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0048_info.json
# [2025-09-23 14:33:47:468] [SmartMeterContinuousEnv Test] Resetting environment with episode 49. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-19 00:00:01'), Timestamp('2013-08-19 23:59:01'))}
# [2025-09-23 14:33:52:846] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 202.54837516044728. Mean of rewards: 0.1407563413206722. Std of rewards: 0.13974178550461722
# [2025-09-23 14:33:52:846] [SmartMeterContinuousEnv Test] Episode f_signal sum: -202.54837516044728. Mean: -0.1407563413206722. Std: 0.13974178550461722
# [2025-09-23 14:33:52:846] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9506070045636497. Mean: 0.002050456570231862. Std: 0.0017676476795434645
# [2025-09-23 14:33:52:864] [SmartMeterContinuousEnv Test] Episode 0049 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0049_info.json
# [2025-09-23 14:33:52:864] Episode 50/80 completed.
# [2025-09-23 14:33:52:867] [SmartMeterContinuousEnv Test] Resetting environment with episode 50. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-20 00:00:02'), Timestamp('2013-08-20 23:59:02'))}
# [2025-09-23 14:33:58:260] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 187.6759591055347. Mean of rewards: 0.13042109736312352. Std of rewards: 0.13306302842151227
# [2025-09-23 14:33:58:260] [SmartMeterContinuousEnv Test] Episode f_signal sum: -187.67595910553473. Mean: -0.13042109736312352. Std: 0.13306302842151227
# [2025-09-23 14:33:58:260] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9407994521095984. Mean: 0.0020436410369072955. Std: 0.0016999802316502342
# [2025-09-23 14:33:58:279] [SmartMeterContinuousEnv Test] Episode 0050 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0050_info.json
# [2025-09-23 14:33:58:283] [SmartMeterContinuousEnv Test] Resetting environment with episode 51. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-21 00:00:00'), Timestamp('2013-08-21 23:59:00'))}
# [2025-09-23 14:34:03:682] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 218.89570921590732. Mean of rewards: 0.15211654566776048. Std of rewards: 0.13426408625137967
# [2025-09-23 14:34:03:682] [SmartMeterContinuousEnv Test] Episode f_signal sum: -218.89570921590735. Mean: -0.15211654566776048. Std: 0.13426408625137967
# [2025-09-23 14:34:03:682] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.211231123749923. Mean: 0.0022315713160180146. Std: 0.0017769993550755087
# [2025-09-23 14:34:03:701] [SmartMeterContinuousEnv Test] Episode 0051 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0051_info.json
# [2025-09-23 14:34:03:705] [SmartMeterContinuousEnv Test] Resetting environment with episode 52. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-15 00:00:00'), Timestamp('2013-09-15 23:59:00'))}
# ...
# [2025-09-23 14:35:03:081] [SmartMeterContinuousEnv Test] Episode 0062 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0062_info.json
# [2025-09-23 14:35:03:085] [SmartMeterContinuousEnv Test] Resetting environment with episode 63. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-19 00:00:04'), Timestamp('2013-10-19 23:59:04'))}
# [2025-09-23 14:35:08:267] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 150.28831775955342. Mean of rewards: 0.10443941470434567. Std of rewards: 0.12179906848464478
# [2025-09-23 14:35:08:267] [SmartMeterContinuousEnv Test] Episode f_signal sum: -150.28831775955342. Mean: -0.10443941470434567. Std: 0.12179906848464478
# [2025-09-23 14:35:08:267] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.8229846179068145. Mean: 0.0019617683237712403. Std: 0.0016958079972117263
# [2025-09-23 14:35:08:286] [SmartMeterContinuousEnv Test] Episode 0063 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0063_info.json
# [2025-09-23 14:35:08:289] [SmartMeterContinuousEnv Test] Resetting environment with episode 64. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-20 00:00:04'), Timestamp('2013-10-20 23:59:04'))}
# [2025-09-23 14:35:13:445] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 176.8835293070402. Mean of rewards: 0.12292114614804739. Std of rewards: 0.12314787253548073
# [2025-09-23 14:35:13:445] [SmartMeterContinuousEnv Test] Episode f_signal sum: -176.8835293070402. Mean: -0.12292114614804739. Std: 0.12314787253548073
# [2025-09-23 14:35:13:445] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9154451203529215. Mean: 0.002026021626374511. Std: 0.0016609898203344287
# [2025-09-23 14:35:13:463] [SmartMeterContinuousEnv Test] Episode 0064 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0064_info.json
# [2025-09-23 14:35:13:467] [SmartMeterContinuousEnv Test] Resetting environment with episode 65. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-21 00:00:04'), Timestamp('2013-10-21 23:59:04'))}
# [2025-09-23 14:35:18:750] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 223.86493659549154. Mean of rewards: 0.15556979610527558. Std of rewards: 0.13425230603987348
# [2025-09-23 14:35:18:751] [SmartMeterContinuousEnv Test] Episode f_signal sum: -223.86493659549154. Mean: -0.15556979610527558. Std: 0.13425230603987348
# [2025-09-23 14:35:18:751] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.1933811360622135. Mean: 0.002219166877041149. Std: 0.0017450820669995873
# [2025-09-23 14:35:18:769] [SmartMeterContinuousEnv Test] Episode 0065 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0065_info.json
# [2025-09-23 14:35:18:773] [SmartMeterContinuousEnv Test] Resetting environment with episode 66. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-15 00:00:04'), Timestamp('2013-11-15 23:59:04'))}
# [2025-09-23 14:35:24:715] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 192.44165020415613. Mean of rewards: 0.13373290493687015. Std of rewards: 0.1364190082666115
# [2025-09-23 14:35:24:715] [SmartMeterContinuousEnv Test] Episode f_signal sum: -192.44165020415613. Mean: -0.13373290493687015. Std: 0.1364190082666115
# [2025-09-23 14:35:24:715] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0209724846055583. Mean: 0.002099355444479193. Std: 0.0017923610144150964
# [2025-09-23 14:35:24:734] [SmartMeterContinuousEnv Test] Episode 0066 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0066_info.json
# [2025-09-23 14:35:24:738] [SmartMeterContinuousEnv Test] Resetting environment with episode 67. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-16 00:00:03'), Timestamp('2013-11-16 23:59:03'))}
# [2025-09-23 14:35:29:992] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 172.648259529313. Mean of rewards: 0.11997794268889021. Std of rewards: 0.1188289170931259
# [2025-09-23 14:35:29:993] [SmartMeterContinuousEnv Test] Episode f_signal sum: -172.648259529313. Mean: -0.11997794268889021. Std: 0.1188289170931259
# [2025-09-23 14:35:29:993] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.184239374126422. Mean: 0.002212814019545811. Std: 0.0017768943274007905
# [2025-09-23 14:35:30:012] [SmartMeterContinuousEnv Test] Episode 0067 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0067_info.json
# [2025-09-23 14:35:30:015] [SmartMeterContinuousEnv Test] Resetting environment with episode 68. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-17 00:00:03'), Timestamp('2013-11-17 23:59:03'))}
# [2025-09-23 14:35:35:185] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 180.21257347884017. Mean of rewards: 0.12523458893595565. Std of rewards: 0.12471144287521813
# [2025-09-23 14:35:35:185] [SmartMeterContinuousEnv Test] Episode f_signal sum: -180.21257347884017. Mean: -0.12523458893595565. Std: 0.12471144287521813
# [2025-09-23 14:35:35:185] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0849070385591464. Mean: 0.002143785294342701. Std: 0.00176839161596008
# [2025-09-23 14:35:35:204] [SmartMeterContinuousEnv Test] Episode 0068 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0068_info.json
# [2025-09-23 14:35:35:208] [SmartMeterContinuousEnv Test] Resetting environment with episode 69. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-18 00:00:04'), Timestamp('2013-11-18 23:59:04'))}
# [2025-09-23 14:35:40:420] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 209.7258931942614. Mean of rewards: 0.14574419262978555. Std of rewards: 0.1297857258004767
# [2025-09-23 14:35:40:421] [SmartMeterContinuousEnv Test] Episode f_signal sum: -209.7258931942614. Mean: -0.14574419262978555. Std: 0.1297857258004767
# [2025-09-23 14:35:40:421] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.097664369922129. Mean: 0.0021526507087714585. Std: 0.001700090150133297
# [2025-09-23 14:35:40:439] [SmartMeterContinuousEnv Test] Episode 0069 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0069_info.json
# [2025-09-23 14:35:40:439] Episode 70/80 completed.
# [2025-09-23 14:35:40:443] [SmartMeterContinuousEnv Test] Resetting environment with episode 70. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-19 00:00:02'), Timestamp('2013-11-19 23:59:02'))}
# [2025-09-23 14:35:45:614] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 190.90508487218526. Mean of rewards: 0.13266510415023297. Std of rewards: 0.13116342721173596
# [2025-09-23 14:35:45:614] [SmartMeterContinuousEnv Test] Episode f_signal sum: -190.90508487218523. Mean: -0.13266510415023297. Std: 0.13116342721173596
# [2025-09-23 14:35:45:614] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0865565783349553. Mean: 0.002144931604124361. Std: 0.0017949619225793645
# [2025-09-23 14:35:45:633] [SmartMeterContinuousEnv Test] Episode 0070 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0070_info.json
# [2025-09-23 14:35:45:637] [SmartMeterContinuousEnv Test] Resetting environment with episode 71. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-20 00:00:02'), Timestamp('2013-11-20 23:59:02'))}
# [2025-09-23 14:35:50:786] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 199.13864381947883. Mean of rewards: 0.13838682683771983. Std of rewards: 0.12598913173649634
# [2025-09-23 14:35:50:786] [SmartMeterContinuousEnv Test] Episode f_signal sum: -199.13864381947883. Mean: -0.13838682683771983. Std: 0.12598913173649634
# [2025-09-23 14:35:50:786] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.180282189691018. Mean: 0.002210064065108421. Std: 0.001705347599433698
# [2025-09-23 14:35:50:805] [SmartMeterContinuousEnv Test] Episode 0071 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0071_info.json
# [2025-09-23 14:35:50:808] [SmartMeterContinuousEnv Test] Resetting environment with episode 72. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-21 00:00:04'), Timestamp('2013-11-21 23:59:04'))}
# [2025-09-23 14:35:56:689] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 197.17580447406942. Mean of rewards: 0.1370227967158231. Std of rewards: 0.13198505894586168
# [2025-09-23 14:35:56:689] [SmartMeterContinuousEnv Test] Episode f_signal sum: -197.17580447406942. Mean: -0.1370227967158231. Std: 0.13198505894586168
# [2025-09-23 14:35:56:689] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.157159049712195. Mean: 0.0021939951700571192. Std: 0.0018845414295640347
# [2025-09-23 14:35:56:708] [SmartMeterContinuousEnv Test] Episode 0072 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0072_info.json
# [2025-09-23 14:35:56:712] [SmartMeterContinuousEnv Test] Resetting environment with episode 73. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-15 00:00:05'), Timestamp('2013-12-15 23:59:05'))}
# [2025-09-23 14:36:01:874] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 182.63540507374302. Mean of rewards: 0.12691828010684017. Std of rewards: 0.12807567008253648
# [2025-09-23 14:36:01:874] [SmartMeterContinuousEnv Test] Episode f_signal sum: -182.63540507374302. Mean: -0.12691828010684017. Std: 0.12807567008253648
# [2025-09-23 14:36:01:874] [SmartMeterContinuousEnv Test] Episode g_signal sum: 2.9853677461311974. Mean: 0.002074612749222514. Std: 0.001710428035818543
# [2025-09-23 14:36:01:893] [SmartMeterContinuousEnv Test] Episode 0073 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0073_info.json
# [2025-09-23 14:36:01:897] [SmartMeterContinuousEnv Test] Resetting environment with episode 74. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-16 00:00:06'), Timestamp('2013-12-16 23:59:06'))}
# [2025-09-23 14:36:07:124] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 213.4347232717667. Mean of rewards: 0.14832155891019227. Std of rewards: 0.134045726762347
# [2025-09-23 14:36:07:124] [SmartMeterContinuousEnv Test] Episode f_signal sum: -213.4347232717667. Mean: -0.14832155891019227. Std: 0.134045726762347
# [2025-09-23 14:36:07:124] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.2011595513098703. Mean: 0.0022245723080680127. Std: 0.0018400251172768943
# [2025-09-23 14:36:07:142] [SmartMeterContinuousEnv Test] Episode 0074 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0074_info.json
# [2025-09-23 14:36:07:146] [SmartMeterContinuousEnv Test] Resetting environment with episode 75. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-17 00:00:00'), Timestamp('2013-12-17 23:59:00'))}
# [2025-09-23 14:36:12:350] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 198.1059328065868. Mean of rewards: 0.13766916803793383. Std of rewards: 0.12697421833231853
# [2025-09-23 14:36:12:350] [SmartMeterContinuousEnv Test] Episode f_signal sum: -198.1059328065868. Mean: -0.13766916803793383. Std: 0.12697421833231853
# [2025-09-23 14:36:12:350] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.2508628478462995. Mean: 0.0022591124724435714. Std: 0.0017434834143680784
# [2025-09-23 14:36:12:369] [SmartMeterContinuousEnv Test] Episode 0075 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0075_info.json
# [2025-09-23 14:36:12:372] [SmartMeterContinuousEnv Test] Resetting environment with episode 76. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-18 00:00:01'), Timestamp('2013-12-18 23:59:01'))}
# [2025-09-23 14:36:17:584] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 231.69336851114983. Mean of rewards: 0.1610099850668171. Std of rewards: 0.1367897738209154
# [2025-09-23 14:36:17:584] [SmartMeterContinuousEnv Test] Episode f_signal sum: -231.6933685111498. Mean: -0.1610099850668171. Std: 0.1367897738209154
# [2025-09-23 14:36:17:584] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0573098084410684. Mean: 0.0021246072331070663. Std: 0.0017129366246968769
# [2025-09-23 14:36:17:602] [SmartMeterContinuousEnv Test] Episode 0076 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0076_info.json
# [2025-09-23 14:36:17:606] [SmartMeterContinuousEnv Test] Resetting environment with episode 77. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-19 00:00:05'), Timestamp('2013-12-19 23:59:05'))}
# [2025-09-23 14:36:22:807] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 214.18837476143415. Mean of rewards: 0.14884529170356786. Std of rewards: 0.12745994411812475
# [2025-09-23 14:36:22:807] [SmartMeterContinuousEnv Test] Episode f_signal sum: -214.18837476143415. Mean: -0.14884529170356786. Std: 0.12745994411812475
# [2025-09-23 14:36:22:807] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.443226941644771. Mean: 0.0023927914813375757. Std: 0.0019331167133914769
# [2025-09-23 14:36:22:827] [SmartMeterContinuousEnv Test] Episode 0077 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0077_info.json
# [2025-09-23 14:36:22:831] [SmartMeterContinuousEnv Test] Resetting environment with episode 78. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-20 00:00:02'), Timestamp('2013-12-20 23:59:02'))}
# [2025-09-23 14:36:28:703] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 204.64258485883175. Mean of rewards: 0.1422116642521416. Std of rewards: 0.12392065344845021
# [2025-09-23 14:36:28:703] [SmartMeterContinuousEnv Test] Episode f_signal sum: -204.64258485883175. Mean: -0.1422116642521416. Std: 0.12392065344845021
# [2025-09-23 14:36:28:703] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.293095553185723. Mean: 0.0022884611210463677. Std: 0.001832442189496072
# [2025-09-23 14:36:28:721] [SmartMeterContinuousEnv Test] Episode 0078 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0078_info.json
# [2025-09-23 14:36:28:725] [SmartMeterContinuousEnv Test] Resetting environment with episode 79. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-21 00:00:01'), Timestamp('2013-12-21 23:59:01'))}
# [2025-09-23 14:36:33:866] [SmartMeterContinuousEnv Test] Episode finished. Sum of rewards: 160.2817746793417. Mean of rewards: 0.11138413806764538. Std of rewards: 0.11119964284880123
# [2025-09-23 14:36:33:867] [SmartMeterContinuousEnv Test] Episode f_signal sum: -160.2817746793417. Mean: -0.11138413806764538. Std: 0.11119964284880123
# [2025-09-23 14:36:33:867] [SmartMeterContinuousEnv Test] Episode g_signal sum: 3.0584669594038054. Mean: 0.002125411368591943. Std: 0.0017382111699040764
# [2025-09-23 14:36:33:885] [SmartMeterContinuousEnv Test] Episode 0079 info saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/episode_info/episode_0079_info.json
# [2025-09-23 14:36:33:885] Episode 80/80 completed.
# [2025-09-23 14:36:33:887] Validation results saved to experiments/20250811_024631_action_continuous_reward_lambda_0.0/logs_test/episode_0602/test_stats_file.json
