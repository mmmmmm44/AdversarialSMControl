# %% [markdown]
# # Model Evaluation
#
# This notebook is to evaluate a selected checkpoint (from a list of save checkpoints at different number of training iterations during RL model training) on the training dataset.
#
# This notebook is used to evaluate trained DDQL-MI models.

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from datetime import datetime
import sys

from utils import print_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the created dataset
dataset_folder_path = Path("dataset", "20250707_downsampled_1min", "split")

# %%
from utils_data_split import load_split_data_from_folder, convert_to_naive_datetimes, convert_to_naive_datetimes_df

# %%
aggregate_load_segments_train, aggregate_load_df_train = load_split_data_from_folder(dataset_folder_path, 'train')

# %%
aggregate_load_segments_train, aggregate_load_df_train = convert_to_naive_datetimes(aggregate_load_segments_train), convert_to_naive_datetimes_df(aggregate_load_df_train )

# %% [markdown]
# ---

# %% [markdown]
# (DDQN) only
#
# We have to quantize the data into per 0.05kW = 50W. This is for the charging action and other stuffs

# %%
# https://stackoverflow.com/questions/47949053/round-to-nearest-1000-in-pandas

def round_to_nearest_50(x):
    """Round to the nearest 50"""
    return ((x + 25) / 50).astype(int) * 50


aggregate_load_df_train["aggregate"] = round_to_nearest_50(aggregate_load_df_train["aggregate"])

# then cap at 5kW
aggregate_load_df_train["aggregate"] = aggregate_load_df_train["aggregate"].clip(upper=5000)

# %% [markdown]
# ---

# %%
# initialize experiment folder to store related information/data for future analysis

# Change the datetime to point to the correct folder
# rl_datetime = datetime(2025, 8, 13, 23, 23, 31)     # 0.0
rl_datetime = datetime(2025, 8, 14, 2, 5, 26)     # 0.5
# rl_datetime = datetime(2025, 8, 14, 4, 46, 19)    # 1.0

# Keep the action type un-changed
ACTION_TYPE = "discrete"

# Change the lambda according to your experiment
REWARD_LAMBDA = 0.5  # between 0 and 1

experiment_folder = Path(
    "experiments", rl_datetime.strftime('%Y%m%d_%H%M%S') + f"_action_{ACTION_TYPE}_reward_lambda_{REWARD_LAMBDA:.1f}", 
)

if not experiment_folder.exists():
    raise FileNotFoundError(f"Experiment folder {experiment_folder} does not exist. Please check the path.")

# %%
# find the selected checkpoint

selected_ckpt_folder = experiment_folder / "selected_ckpt"

# search for any sub-folders under selected_ckpt_folder
sub_folders = [f for f in selected_ckpt_folder.iterdir() if f.is_dir()]
# assert len(sub_folders) == 1, "There should be exactly one sub-folder in selected_ckpt_folder."

selected_ckpt_folder = sub_folders[0]
selected_ckpt_episode_number = int(selected_ckpt_folder.name.split('_')[-1])

print_log(f"Selected checkpoint folder: {selected_ckpt_folder}")
# Out:
# [2025-09-23 16:33:30:254] Selected checkpoint folder: experiments/20250814_020526_action_discrete_reward_lambda_0.5/selected_ckpt/episode_0600

# %% [markdown]
# We create a new folder under the experiment_folder specifically for storing the results of executing a subset of training episodes with the selected ckpt (for IEEE journal)

# %%
log_folder = experiment_folder / "logs_train_selected-ckpt"

if not log_folder.exists():
    log_folder.mkdir()

# %% [markdown]
# Create data loader

# %%
sys.path.append(str(Path('rl_env')))
sys.path.append(str(Path('model', 'H_network')))

from rl_env.data_loader import SimpleSmartMeterDataLoader

sm_dl_train = SimpleSmartMeterDataLoader(
    aggregate_load_segments=aggregate_load_segments_train,
    aggregate_load_df=aggregate_load_df_train,
    registry_path=log_folder / "simple_episode_registry_train_subset.json"
)

sm_dl_train.get_divided_segments_length()
# Out:
# [SimpleDataLoader] Generated 162 episodes (1 day each)
# 162

# %% [markdown]
# Create environment

# %%
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from model.H_network.common.factories import create_h_network_module_with_defaults
from model.H_network.h_network_arch import HNetworkType

# the optimizer kwargs does not matter for the testing loop, but they are required to create the module

h_network_kwargs = {
    "h_network_type": HNetworkType.H_NETWORK,
    "optimizer_class": torch.optim.RMSprop,
    "optimizer_kwargs": {"lr": 0.001},
}

h_network_rl_module = create_h_network_module_with_defaults(
    action_type=ACTION_TYPE,
    **h_network_kwargs,
    device=DEVICE
)

# %%
from rl_env.base.env_module import SmartMeterEnvFactory
from rl_env.training_mode import TrainingMode
from decimal import Decimal

env_train = SmartMeterEnvFactory.create(
    action_type=ACTION_TYPE,
    smart_meter_data_loader=sm_dl_train,
    h_network_rl_module=h_network_rl_module,
    mode=TrainingMode.TEST,
    reward_lambda=REWARD_LAMBDA,
    render_mode=None,

    aggregate_step_size=50,  # step size for the aggregate load
    battery_step_size=Decimal("0.05")
)
# Out:
# [2025-09-23 16:33:39:449] [SmartMeterDiscreteEnv Test] Using data loader: SimpleSmartMeterDataLoader
# [2025-09-23 16:33:39:450] [SmartMeterDiscreteEnv Test] Curriculum enabled: False
# [2025-09-23 16:33:39:458] [SmartMeterDiscreteEnv Test]] Render mode set to 'None'. Render server at 127.0.0.1:50007. render_connected: False. render_client_socket: None

# %%
h_network_rl_module.set_h_network(
    h_network_rl_module.initialize_h_network(output_dim=env_train.num_aggregate_bins)  # output_dim is the number states in the aggregate load space
)
h_network_rl_module.initialize_h_network_training()

# %%
# load the h_network from the selected checkpoint

h_network_rl_module.load_h_network(
    selected_ckpt_folder / ("h_network" + f"_{selected_ckpt_episode_number:04d}" + ".pth")
)

# %%
h_network_rl_module.h_network
# Out:
# HNetwork(
#   (LSTM_1): LSTM(2, 44, batch_first=True, bidirectional=True)
#   (ac1): Tanh()
#   (LSTM_2): LSTM(88, 44, batch_first=True, bidirectional=True)
#   (ac2): Tanh()
#   (fc): Linear(in_features=88, out_features=101, bias=True)
# )

# %%
import torchinfo


torchinfo.summary(h_network_rl_module.h_network, input_size=(1, 1, 2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HNetwork                                 [1, 1, 101]               --
# ├─LSTM: 1-1                              [1, 1, 88]                16,896
# ├─Tanh: 1-2                              [1, 1, 88]                --
# ├─LSTM: 1-3                              [1, 1, 88]                47,168
# ├─Tanh: 1-4                              [1, 1, 88]                --
# ├─Linear: 1-5                            [1, 1, 101]               8,989
# ==========================================================================================
# Total params: 73,053
# Trainable params: 73,053
# Non-trainable params: 0
# Total mult-adds (M): 0.07
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.29
# Estimated Total Size (MB): 0.29
# ==========================================================================================

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env_train)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# [2025-09-23 16:33:51:809] [SmartMeterWorldDiscrete Test] Resetting environment with episode 40. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-07 00:00:04'), Timestamp('2013-05-07 23:59:04'))}
# [2025-09-23 16:33:51:813] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 693, 'datetime_range': (Timestamp('2013-01-10 00:00:02'), Timestamp('2013-01-10 11:32:02'))}
# [2025-09-23 16:33:51:817] [SmartMeterWorldDiscrete Test] Resetting environment with episode 110. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-26 00:00:00'), Timestamp('2013-09-26 23:59:00'))}
# [2025-09-23 16:33:51:821] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 693, 'datetime_range': (Timestamp('2013-01-10 00:00:02'), Timestamp('2013-01-10 11:32:02'))}
# [2025-09-23 16:33:51:826] [SmartMeterWorldDiscrete Test] Resetting environment with episode 110. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-26 00:00:00'), Timestamp('2013-09-26 23:59:00'))}
# [2025-09-23 16:33:51:830] [SmartMeterWorldDiscrete Test] Resetting environment with episode 57. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-05 00:00:05'), Timestamp('2013-06-05 23:59:05'))}
# [2025-09-23 16:33:51:836] [SmartMeterWorldDiscrete Test] Resetting environment with episode 76. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-25 00:00:05'), Timestamp('2013-07-25 23:59:05'))}
# [2025-09-23 16:33:51:840] [SmartMeterWorldDiscrete Test] Resetting environment with episode 75. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-24 00:00:00'), Timestamp('2013-07-24 23:59:00'))}
# [2025-09-23 16:33:51:916] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 693, 'datetime_range': (Timestamp('2013-01-10 00:00:02'), Timestamp('2013-01-10 11:32:02'))}
# [2025-09-23 16:33:51:924] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 693, 'datetime_range': (Timestamp('2013-01-10 00:00:02'), Timestamp('2013-01-10 11:32:02'))}
# Environment passes all checks!
# /root/miniforge3/envs/smartmeter/lib/python3.9/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
env_train.reset_render_window()

# %%
# initialize a DQN agent
from model.DDQN.ddqn import DoubleDQN

rl_model = DoubleDQN.load(
    selected_ckpt_folder / ("rl_model" + f"_{selected_ckpt_episode_number:04d}"),  # path to the saved RL model
    env=env_train
)
# Out:
# 2025-09-23 16:33:54.167765: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 16:33:54.177159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758616434.187061  124523 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758616434.189960  124523 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758616434.198077  124523 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758616434.198096  124523 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758616434.198096  124523 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758616434.198097  124523 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-23 16:33:54.201255: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
rl_model.buffer_size
# Out:
# 150000

# %%
rl_model.policy
# Out:
# MultiInputPolicy(
#   (q_net): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
# )

# %% [markdown]
# We execute on all training episodes

# %%
total_episodes = env_train.smart_meter_data_loader.get_divided_segments_length()
total_episodes
# Out:
# 162

# %%
episode_indices = list(range(total_episodes))

# %%
# we test the rl model and H-network

import json
from utils import print_log

all_episode_rewards = []
all_episode_lengths = []
all_episode_infos = []
per_episode_reward_stats = []

for i, episode_idx in enumerate(episode_indices):
    obs, info = env_train.reset(episode_idx=episode_idx)

    # Initialize episode tracking variables
    episode_reward = 0.0
    episode_length = 0
    done = False
    state = None  # For recurrent policies

    while not done:
        # Get action from the RL model
        action, state = rl_model.predict(obs, state=state)

        # Step the environment
        obs, reward, done, truncated, info = env_train.step(action)

        # Update episode tracking variables
        episode_reward += reward
        episode_length += 1

    # Store results for this episode
    all_episode_rewards.append(episode_reward)
    all_episode_lengths.append(episode_length)
    all_episode_infos.append({
        "episode_idx": episode_idx,
        "episode_info": env_train.episode.get_episode_info() if hasattr(env_train, 'episode') else {}
    })

    per_episode_reward_stats.append(env_train.prev_episode_reward_stats)

    env_train.save_episode_info(
        log_folder=log_folder,
        episode_training_idx=episode_idx
    )

    if (i + 1) % 10 == 0:
        print_log(f"Episode {i + 1}/{total_episodes} completed.")


# Calculate comprehensive statistics
mean_reward = np.mean(all_episode_rewards)
std_reward = np.std(all_episode_rewards)
min_reward = np.min(all_episode_rewards)
max_reward = np.max(all_episode_rewards)
median_reward = np.median(all_episode_rewards)

# we need to recover the true sum f_signal and g_signal from the per_episode_reward_stats, with length of each episode
f_signal_sums = np.array([item['f_signal_sum'] for item in per_episode_reward_stats])
g_signal_sums = np.array([item['g_signal_sum'] for item in per_episode_reward_stats])

# get the length of each episode
_episode_lengths = np.array(all_episode_lengths)
sum_episode_lengths = np.sum(_episode_lengths)

# calculate the (true) mean of rewards, f_signal and g_signal

f_signal_mean = f_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0
g_signal_mean = g_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0

mean_length = np.mean(all_episode_lengths)
std_length = np.std(all_episode_lengths)

# Prepare validation data
test_data = {
    'evaluated_episodes': len(episode_indices),
    'total_available_episodes': total_episodes,
    'episode_indices': episode_indices,
    'episode_rewards': all_episode_rewards,
    'episode_lengths': all_episode_lengths,
    'episode_infos': all_episode_infos,
    'summary_stats': {
        'mean_reward': mean_reward,
        'std_reward': std_reward,
        'min_reward': min_reward,
        'max_reward': max_reward,
        'median_reward': median_reward,
        'mean_f_signal': f_signal_mean,
        'mean_g_signal': g_signal_mean,
        'mean_length': mean_length,
        'std_length': std_length
    }
}

test_stats_file_path = log_folder / "test_stats_file.json"
with open(test_stats_file_path, 'w') as f:
    # Convert numpy types to Python native types for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        return obj

    json.dump(convert_numpy(test_data), f, indent=2, default=str)

sm_dl_train._save_registry()
print_log(f"Validation results saved to {test_stats_file_path}")
# Out:
# [2025-09-23 16:34:02:616] [SmartMeterWorldDiscrete Test] Resetting environment with episode 0. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-08 00:00:05'), Timestamp('2013-01-08 23:59:05'))}
# [2025-09-23 16:34:08:729] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 155.71376629557187. Mean of rewards: 0.10820970555633903. Std of rewards: 0.057085488035774394
# [2025-09-23 16:34:08:729] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -312.7396611744771. Mean: -0.21733124473556434. Std: 0.11403694198749469
# [2025-09-23 16:34:08:729] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3121285833333332. Mean: 0.0009118336228862635. Std: 0.0017470878125850258
# [2025-09-23 16:34:08:745] [SmartMeterDiscreteEnv Test] Episode 0000 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0000_info.json
# [2025-09-23 16:34:08:749] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-09 00:00:04'), Timestamp('2013-01-09 23:59:04'))}
# [2025-09-23 16:34:13:931] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 147.6873646067359. Mean of rewards: 0.10263194204776645. Std of rewards: 0.04853694854573041
# [2025-09-23 16:34:13:931] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -296.6948343134718. Mean: -0.20618126081547727. Std: 0.09687041891353274
# [2025-09-23 16:34:13:931] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3201050999999997. Mean: 0.0009173767199444057. Std: 0.0017211653337970902
# [2025-09-23 16:34:13:947] [SmartMeterDiscreteEnv Test] Episode 0001 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0001_info.json
# [2025-09-23 16:34:13:952] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 693, 'datetime_range': (Timestamp('2013-01-10 00:00:02'), Timestamp('2013-01-10 11:32:02'))}
# [2025-09-23 16:34:17:644] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 79.45866889536167. Mean of rewards: 0.11482466603375961. Std of rewards: 0.050951475445369876
# [2025-09-23 16:34:17:644] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -159.50000479072332. Mean: -0.23049133640277936. Std: 0.10170373527090806
# [2025-09-23 16:34:17:644] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.582667. Mean: 0.0008420043352601157. Std: 0.0014903091186490823
# [2025-09-23 16:34:17:652] [SmartMeterDiscreteEnv Test] Episode 0002 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0002_info.json
# [2025-09-23 16:34:17:657] [SmartMeterWorldDiscrete Test] Resetting environment with episode 3. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-27 00:00:13'), Timestamp('2013-02-27 23:59:13'))}
# [2025-09-23 16:34:23:297] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 78.7710210532558. Mean of rewards: 0.054740111920261146. Std of rewards: 0.02866565202579334
# [2025-09-23 16:34:23:297] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -158.66499410651159. Mean: -0.11026059354170367. Std: 0.05723418084625918
# [2025-09-23 16:34:23:297] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1229519999999997. Mean: 0.0007803697011813758. Std: 0.0014866183399417372
# [2025-09-23 16:34:23:313] [SmartMeterDiscreteEnv Test] Episode 0003 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0003_info.json
# [2025-09-23 16:34:23:317] [SmartMeterWorldDiscrete Test] Resetting environment with episode 4. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-28 00:00:02'), Timestamp('2013-02-28 23:59:02'))}
# [2025-09-23 16:34:29:053] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 105.21270617449147. Mean of rewards: 0.07311515370013306. Std of rewards: 0.041049182554488944
# [2025-09-23 16:34:29:053] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -211.43229059898295. Mean: -0.14693001431479008. Std: 0.08186354526232684
# [2025-09-23 16:34:29:053] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.00687825. Mean: 0.0006997069145239749. Std: 0.0013526448585695593
# [2025-09-23 16:34:29:069] [SmartMeterDiscreteEnv Test] Episode 0004 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0004_info.json
# [2025-09-23 16:34:29:074] [SmartMeterWorldDiscrete Test] Resetting environment with episode 5. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-08 00:00:03'), Timestamp('2013-03-08 23:59:03'))}
# [2025-09-23 16:34:34:237] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 189.95141369752048. Mean of rewards: 0.1320023722706883. Std of rewards: 0.05660309731836229
# [2025-09-23 16:34:34:237] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -381.40025534504093. Mean: -0.2650453477032946. Std: 0.11258987831067771
# [2025-09-23 16:34:34:237] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4974279499999998. Mean: 0.0010406031619179985. Std: 0.002107491924959303
# [2025-09-23 16:34:34:252] [SmartMeterDiscreteEnv Test] Episode 0005 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0005_info.json
# [2025-09-23 16:34:34:256] [SmartMeterWorldDiscrete Test] Resetting environment with episode 6. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-09 00:00:03'), Timestamp('2013-03-09 23:59:03'))}
# [2025-09-23 16:34:39:318] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 209.50391161588507. Mean of rewards: 0.14558993163021897. Std of rewards: 0.046872493112614586
# [2025-09-23 16:34:39:318] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -420.34566728177015. Mean: -0.29210956725626835. Std: 0.0930716029608697
# [2025-09-23 16:34:39:318] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.33784405. Mean: 0.0009297039958304378. Std: 0.001789254734577541
# [2025-09-23 16:34:39:334] [SmartMeterDiscreteEnv Test] Episode 0006 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0006_info.json
# [2025-09-23 16:34:39:338] [SmartMeterWorldDiscrete Test] Resetting environment with episode 7. Episode info: {'length': 458, 'datetime_range': (Timestamp('2013-03-10 00:00:04'), Timestamp('2013-03-10 07:37:04'))}
# [2025-09-23 16:34:40:490] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 51.395968388009656. Mean of rewards: 0.11246382579433184. Std of rewards: 0.05316111857259578
# [2025-09-23 16:34:40:490] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -103.22770414268598. Mean: -0.2258811906842144. Std: 0.10602029490508327
# [2025-09-23 16:34:40:490] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.4357673666666666. Mean: 0.0009535390955506928. Std: 0.0008409166076683106
# [2025-09-23 16:34:40:495] [SmartMeterDiscreteEnv Test] Episode 0007 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0007_info.json
# [2025-09-23 16:34:40:500] [SmartMeterWorldDiscrete Test] Resetting environment with episode 8. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-28 00:00:05'), Timestamp('2013-03-28 23:59:05'))}
# [2025-09-23 16:34:45:789] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 143.5322592210306. Mean of rewards: 0.09974444699168213. Std of rewards: 0.052190931230509496
# [2025-09-23 16:34:45:789] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -288.53071702539455. Mean: -0.20050779501417273. Std: 0.10403375259800927
# [2025-09-23 16:34:45:789] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.466198583333333. Mean: 0.0010189010308084316. Std: 0.002032194260915536
# [2025-09-23 16:34:45:805] [SmartMeterDiscreteEnv Test] Episode 0008 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0008_info.json
# [2025-09-23 16:34:45:809] [SmartMeterWorldDiscrete Test] Resetting environment with episode 9. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-29 00:00:04'), Timestamp('2013-03-29 23:59:04'))}
# [2025-09-23 16:34:52:227] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 206.88742908830147. Mean of rewards: 0.14377166719131443. Std of rewards: 0.04270466328061076
# [2025-09-23 16:34:52:227] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -415.02449015993625. Mean: -0.28841173742872567. Std: 0.08488067228381166
# [2025-09-23 16:34:52:227] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2496319833333334. Mean: 0.0008684030460968266. Std: 0.0015985557940225749
# [2025-09-23 16:34:52:244] [SmartMeterDiscreteEnv Test] Episode 0009 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0009_info.json
# [2025-09-23 16:34:52:244] Episode 10/162 completed.
# [2025-09-23 16:34:52:249] [SmartMeterWorldDiscrete Test] Resetting environment with episode 10. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-30 00:00:04'), Timestamp('2013-03-30 23:59:04'))}
# [2025-09-23 16:34:57:325] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 203.8858753436277. Mean of rewards: 0.1416858063541541. Std of rewards: 0.0366865600865681
# [2025-09-23 16:34:57:325] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -409.3576630372554. Mean: -0.284473706071755. Std: 0.07279119844902954
# [2025-09-23 16:34:57:325] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.58591235. Mean: 0.0011020933634468381. Std: 0.001863537319143235
# [2025-09-23 16:34:57:342] [SmartMeterDiscreteEnv Test] Episode 0010 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0010_info.json
# [2025-09-23 16:34:57:346] [SmartMeterWorldDiscrete Test] Resetting environment with episode 11. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-31 00:00:05'), Timestamp('2013-03-31 23:59:05'))}
# [2025-09-23 16:35:02:461] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 201.8345594142355. Mean of rewards: 0.14026029146229013. Std of rewards: 0.03450678812736127
# [2025-09-23 16:35:02:461] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -405.1178828701377. Mean: -0.2815273682210825. Std: 0.06845562599492971
# [2025-09-23 16:35:02:461] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4487640416666667. Mean: 0.0010067852965022007. Std: 0.0017598736139410244
# [2025-09-23 16:35:02:478] [SmartMeterDiscreteEnv Test] Episode 0011 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0011_info.json
# [2025-09-23 16:35:02:482] [SmartMeterWorldDiscrete Test] Resetting environment with episode 12. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-22 00:00:04'), Timestamp('2013-03-22 23:59:04'))}
# [2025-09-23 16:35:07:310] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 131.28779103878276. Mean of rewards: 0.09123543505127363. Std of rewards: 0.044346907621195225
# [2025-09-23 16:35:07:310] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -264.1170160775655. Mean: -0.1835420542582109. Std: 0.0882917596087581
# [2025-09-23 16:35:07:310] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5414339999999997. Mean: 0.0010711841556636551. Std: 0.002124307800284617
# [2025-09-23 16:35:07:325] [SmartMeterDiscreteEnv Test] Episode 0012 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0012_info.json
# [2025-09-23 16:35:07:329] [SmartMeterWorldDiscrete Test] Resetting environment with episode 13. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-23 00:00:05'), Timestamp('2013-03-23 23:59:05'))}
# [2025-09-23 16:35:12:425] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 183.54468360117025. Mean of rewards: 0.12755016233576805. Std of rewards: 0.046304672358115945
# [2025-09-23 16:35:12:425] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -368.1782952856738. Mean: -0.2558570502332688. Std: 0.09236979123103307
# [2025-09-23 16:35:12:425] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0889280833333332. Mean: 0.0007567255617326846. Std: 0.0013795906821745545
# [2025-09-23 16:35:12:441] [SmartMeterDiscreteEnv Test] Episode 0013 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0013_info.json
# [2025-09-23 16:35:12:445] [SmartMeterWorldDiscrete Test] Resetting environment with episode 14. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-24 00:00:01'), Timestamp('2013-03-24 23:59:01'))}
# [2025-09-23 16:35:17:559] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 171.46582257625607. Mean of rewards: 0.11915623528579296. Std of rewards: 0.05474933303140824
# [2025-09-23 16:35:17:559] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -344.02755900251213. Mean: -0.23907405073141913. Std: 0.10936493337007916
# [2025-09-23 16:35:17:559] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0959138499999999. Mean: 0.0007615801598332174. Std: 0.001521902068104244
# [2025-09-23 16:35:17:575] [SmartMeterDiscreteEnv Test] Episode 0014 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0014_info.json
# [2025-09-23 16:35:17:580] [SmartMeterWorldDiscrete Test] Resetting environment with episode 15. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-25 00:00:00'), Timestamp('2013-03-25 23:59:00'))}
# [2025-09-23 16:35:23:989] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 159.96723948139172. Mean of rewards: 0.11116555905586635. Std of rewards: 0.05758856625699136
# [2025-09-23 16:35:23:989] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -321.2876759627834. Mean: -0.22327149128754928. Std: 0.11471263811131081
# [2025-09-23 16:35:23:989] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.353197. Mean: 0.0009403731758165393. Std: 0.0016771261788417972
# [2025-09-23 16:35:24:006] [SmartMeterDiscreteEnv Test] Episode 0015 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0015_info.json
# [2025-09-23 16:35:24:011] [SmartMeterWorldDiscrete Test] Resetting environment with episode 16. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-26 00:00:01'), Timestamp('2013-03-26 23:59:01'))}
# [2025-09-23 16:35:29:190] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 153.60915484036238. Mean of rewards: 0.10674715416286475. Std of rewards: 0.05753710468320026
# [2025-09-23 16:35:29:191] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -308.5749769473914. Mean: -0.21443709308366324. Std: 0.11471639685140668
# [2025-09-23 16:35:29:191] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3566672666666666. Mean: 0.0009427847579337503. Std: 0.0020318802183192956
# [2025-09-23 16:35:29:207] [SmartMeterDiscreteEnv Test] Episode 0016 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0016_info.json
# [2025-09-23 16:35:29:211] [SmartMeterWorldDiscrete Test] Resetting environment with episode 17. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-08 00:00:01'), Timestamp('2013-04-08 23:59:01'))}
# [2025-09-23 16:35:34:313] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 114.47633968824086. Mean of rewards: 0.07955270304950719. Std of rewards: 0.05549042246904717
# [2025-09-23 16:35:34:313] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -230.0541291264817. Mean: -0.15987083330540772. Std: 0.11092124967106241
# [2025-09-23 16:35:34:313] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.10144975. Mean: 0.0007654272063933287. Std: 0.0015665008536171186
# [2025-09-23 16:35:34:329] [SmartMeterDiscreteEnv Test] Episode 0017 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0017_info.json
# [2025-09-23 16:35:34:333] [SmartMeterWorldDiscrete Test] Resetting environment with episode 18. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-09 00:00:03'), Timestamp('2013-04-09 23:59:03'))}
# [2025-09-23 16:35:39:267] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 158.7989430944503. Mean of rewards: 0.11035367831441995. Std of rewards: 0.05099063674557284
# [2025-09-23 16:35:39:267] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -319.0999481139006. Mean: -0.22175118006525407. Std: 0.10143901312573875
# [2025-09-23 16:35:39:267] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.502061925. Mean: 0.0010438234364141764. Std: 0.002077248607039704
# [2025-09-23 16:35:39:283] [SmartMeterDiscreteEnv Test] Episode 0018 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0018_info.json
# [2025-09-23 16:35:39:288] [SmartMeterWorldDiscrete Test] Resetting environment with episode 19. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-10 00:00:05'), Timestamp('2013-04-10 23:59:05'))}
# [2025-09-23 16:35:44:368] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 176.3604639179393. Mean of rewards: 0.12255765386931154. Std of rewards: 0.04813924618618571
# [2025-09-23 16:35:44:369] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -354.18115058587864. Mean: -0.24613005600130552. Std: 0.09575856727050461
# [2025-09-23 16:35:44:369] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4602227500000002. Mean: 0.0010147482626824186. Std: 0.0018892689421718698
# [2025-09-23 16:35:44:385] [SmartMeterDiscreteEnv Test] Episode 0019 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0019_info.json
# [2025-09-23 16:35:44:385] Episode 20/162 completed.
# [2025-09-23 16:35:44:389] [SmartMeterWorldDiscrete Test] Resetting environment with episode 20. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-26 00:00:00'), Timestamp('2013-04-26 23:59:00'))}
# [2025-09-23 16:35:49:561] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 189.4398038939285. Mean of rewards: 0.13164684078799757. Std of rewards: 0.057640525487587184
# [2025-09-23 16:35:49:561] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -380.698671287857. Mean: -0.2645577979762731. Std: 0.11436125233070876
# [2025-09-23 16:35:49:561] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.8190635. Mean: 0.0012641164002779707. Std: 0.0022044730869191006
# [2025-09-23 16:35:49:577] [SmartMeterDiscreteEnv Test] Episode 0020 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0020_info.json
# [2025-09-23 16:35:49:582] [SmartMeterWorldDiscrete Test] Resetting environment with episode 21. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-27 00:00:05'), Timestamp('2013-04-27 23:59:05'))}
# [2025-09-23 16:35:56:938] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 192.19256959886928. Mean of rewards: 0.13355981209094459. Std of rewards: 0.048682429841821626
# [2025-09-23 16:35:56:938] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -385.66601803107187. Mean: -0.2680097415087365. Std: 0.09693568900030063
# [2025-09-23 16:35:56:938] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2808788333333334. Mean: 0.0008901173268473477. Std: 0.0018601864700275711
# [2025-09-23 16:35:56:955] [SmartMeterDiscreteEnv Test] Episode 0021 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0021_info.json
# [2025-09-23 16:35:56:959] [SmartMeterWorldDiscrete Test] Resetting environment with episode 22. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-28 00:00:03'), Timestamp('2013-04-28 23:59:03'))}
# [2025-09-23 16:36:02:628] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 187.61196975449647. Mean of rewards: 0.13037662943328454. Std of rewards: 0.045414593443268286
# [2025-09-23 16:36:02:628] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -376.2428640089929. Mean: -0.2614613370458603. Std: 0.09055944040133235
# [2025-09-23 16:36:02:628] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0189245. Mean: 0.0007080781792911745. Std: 0.0013782723545908288
# [2025-09-23 16:36:02:643] [SmartMeterDiscreteEnv Test] Episode 0022 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0022_info.json
# [2025-09-23 16:36:02:648] [SmartMeterWorldDiscrete Test] Resetting environment with episode 23. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-29 00:00:05'), Timestamp('2013-04-29 23:59:05'))}
# [2025-09-23 16:36:08:209] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 208.92978799971013. Mean of rewards: 0.14519095760924958. Std of rewards: 0.047272357118252284
# [2025-09-23 16:36:08:209] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -419.1550909160869. Mean: -0.2912822035553071. Std: 0.09408785421092947
# [2025-09-23 16:36:08:209] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2955149166666668. Mean: 0.0009002883368079686. Std: 0.001713874813375798
# [2025-09-23 16:36:08:225] [SmartMeterDiscreteEnv Test] Episode 0023 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0023_info.json
# [2025-09-23 16:36:08:229] [SmartMeterWorldDiscrete Test] Resetting environment with episode 24. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-30 00:00:01'), Timestamp('2013-04-30 23:59:01'))}
# [2025-09-23 16:36:13:885] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 191.59652835221215. Mean of rewards: 0.13314560691606125. Std of rewards: 0.0471191787631361
# [2025-09-23 16:36:13:885] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.35634664609097. Mean: -0.26709961545940997. Std: 0.09378854321491695
# [2025-09-23 16:36:13:886] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1632899416666667. Mean: 0.0008084016272874681. Std: 0.0015035458963072066
# [2025-09-23 16:36:13:903] [SmartMeterDiscreteEnv Test] Episode 0024 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0024_info.json
# [2025-09-23 16:36:13:908] [SmartMeterWorldDiscrete Test] Resetting environment with episode 25. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-01 00:00:05'), Timestamp('2013-04-01 23:59:05'))}
# [2025-09-23 16:36:19:483] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 206.51022796938958. Mean of rewards: 0.14350953993703236. Std of rewards: 0.04050897018988503
# [2025-09-23 16:36:19:483] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -414.4716540221125. Mean: -0.2880275566519197. Std: 0.08050297339709707
# [2025-09-23 16:36:19:483] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4511980833333333. Mean: 0.001008476777854992. Std: 0.001772086170936509
# [2025-09-23 16:36:19:501] [SmartMeterDiscreteEnv Test] Episode 0025 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0025_info.json
# [2025-09-23 16:36:19:505] [SmartMeterWorldDiscrete Test] Resetting environment with episode 26. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-02 00:00:01'), Timestamp('2013-04-02 23:59:01'))}
# [2025-09-23 16:36:24:812] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 145.11482282726016. Mean of rewards: 0.10084421322255743. Std of rewards: 0.054738820384823174
# [2025-09-23 16:36:24:812] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -291.3436671295203. Mean: -0.20246259008305792. Std: 0.10935830120305279
# [2025-09-23 16:36:24:812] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.114021475. Mean: 0.0007741636379430159. Std: 0.0014996246654557304
# [2025-09-23 16:36:24:828] [SmartMeterDiscreteEnv Test] Episode 0026 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0026_info.json
# [2025-09-23 16:36:24:832] [SmartMeterWorldDiscrete Test] Resetting environment with episode 27. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-03 00:00:03'), Timestamp('2013-04-03 23:59:03'))}
# [2025-09-23 16:36:31:561] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 131.25610531767242. Mean of rewards: 0.09121341578712469. Std of rewards: 0.06324884589347504
# [2025-09-23 16:36:31:562] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -263.94050593534485. Mean: -0.18341939258884285. Std: 0.12634029101689612
# [2025-09-23 16:36:31:562] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4282952999999998. Mean: 0.0009925610145934676. Std: 0.0018984901254780907
# [2025-09-23 16:36:31:578] [SmartMeterDiscreteEnv Test] Episode 0027 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0027_info.json
# [2025-09-23 16:36:31:583] [SmartMeterWorldDiscrete Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-04 00:00:03'), Timestamp('2013-04-04 23:59:03'))}
# [2025-09-23 16:36:36:753] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 157.9379010308195. Mean of rewards: 0.10975531690814419. Std of rewards: 0.0543872409091926
# [2025-09-23 16:36:36:753] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -317.37723946163896. Mean: -0.22055402325339749. Std: 0.10831314808308763
# [2025-09-23 16:36:36:753] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5014374. Mean: 0.0010433894371091035. Std: 0.0020614357768230997
# [2025-09-23 16:36:36:770] [SmartMeterDiscreteEnv Test] Episode 0028 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0028_info.json
# [2025-09-23 16:36:36:774] [SmartMeterWorldDiscrete Test] Resetting environment with episode 29. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-05 00:00:05'), Timestamp('2013-04-05 23:59:05'))}
# [2025-09-23 16:36:41:544] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 138.51730865129065. Mean of rewards: 0.0962594222733083. Std of rewards: 0.05039004895359871
# [2025-09-23 16:36:41:544] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -278.2911520525813. Mean: -0.19339204451187025. Std: 0.10059083035786008
# [2025-09-23 16:36:41:544] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.25653475. Mean: 0.0008731999652536483. Std: 0.0017318904479836146
# [2025-09-23 16:36:41:559] [SmartMeterDiscreteEnv Test] Episode 0029 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0029_info.json
# [2025-09-23 16:36:41:559] Episode 30/162 completed.
# [2025-09-23 16:36:41:564] [SmartMeterWorldDiscrete Test] Resetting environment with episode 30. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-06 00:00:03'), Timestamp('2013-04-06 23:59:03'))}
# [2025-09-23 16:36:46:400] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 191.7481983369284. Mean of rewards: 0.13325100648848393. Std of rewards: 0.0439945089065953
# [2025-09-23 16:36:46:401] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.66170314885676. Mean: -0.2673118159477809. Std: 0.08757292889237243
# [2025-09-23 16:36:46:401] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.165306475. Mean: 0.0008098029708130646. Std: 0.0014549834025553534
# [2025-09-23 16:36:46:416] [SmartMeterDiscreteEnv Test] Episode 0030 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0030_info.json
# [2025-09-23 16:36:46:421] [SmartMeterWorldDiscrete Test] Resetting environment with episode 31. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-07 00:00:01'), Timestamp('2013-04-07 23:59:01'))}
# [2025-09-23 16:36:51:265] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 191.0162309552809. Mean of rewards: 0.1327423425679506. Std of rewards: 0.049660096600328996
# [2025-09-23 16:36:51:265] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -383.59244117722847. Mean: -0.2665687568986994. Std: 0.09865038131452616
# [2025-09-23 16:36:51:265] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5599792666666668. Mean: 0.0010840717627982395. Std: 0.002127578019939923
# [2025-09-23 16:36:51:281] [SmartMeterDiscreteEnv Test] Episode 0031 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0031_info.json
# [2025-09-23 16:36:51:285] [SmartMeterWorldDiscrete Test] Resetting environment with episode 32. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-15 00:00:04'), Timestamp('2013-05-15 23:59:04'))}
# [2025-09-23 16:36:56:203] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 152.4113238435061. Mean of rewards: 0.10591474902258939. Std of rewards: 0.04632725262842151
# [2025-09-23 16:36:56:203] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -305.9274849370122. Mean: -0.2125972793168952. Std: 0.09230324765267703
# [2025-09-23 16:36:56:203] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.10483725. Mean: 0.0007677812717164699. Std: 0.0015583625111871898
# [2025-09-23 16:36:56:219] [SmartMeterDiscreteEnv Test] Episode 0032 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0032_info.json
# [2025-09-23 16:36:56:224] [SmartMeterWorldDiscrete Test] Resetting environment with episode 33. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-16 00:00:00'), Timestamp('2013-05-16 23:59:00'))}
# [2025-09-23 16:37:01:163] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 146.52928362083514. Mean of rewards: 0.10182716026465263. Std of rewards: 0.04620466637109434
# [2025-09-23 16:37:01:163] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -294.35123299167026. Mean: -0.204552628903176. Std: 0.09212127329636957
# [2025-09-23 16:37:01:164] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.29266575. Mean: 0.0008983083738707436. Std: 0.001669426443942635
# [2025-09-23 16:37:01:180] [SmartMeterDiscreteEnv Test] Episode 0033 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0033_info.json
# [2025-09-23 16:37:01:184] [SmartMeterWorldDiscrete Test] Resetting environment with episode 34. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-01 00:00:01'), Timestamp('2013-05-01 23:59:01'))}
# [2025-09-23 16:37:07:528] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 124.8957018284441. Mean of rewards: 0.08679339946382494. Std of rewards: 0.039827626406206185
# [2025-09-23 16:37:07:528] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -251.2096405568882. Mean: -0.17457237008817802. Std: 0.07913865220910314
# [2025-09-23 16:37:07:528] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4182369000000001. Mean: 0.0009855711605281446. Std: 0.0019019228556064944
# [2025-09-23 16:37:07:544] [SmartMeterDiscreteEnv Test] Episode 0034 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0034_info.json
# [2025-09-23 16:37:07:548] [SmartMeterWorldDiscrete Test] Resetting environment with episode 35. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-02 00:00:06'), Timestamp('2013-05-02 23:59:06'))}
# [2025-09-23 16:37:12:286] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 168.7156381365597. Mean of rewards: 0.11724505777384274. Std of rewards: 0.05053169958726278
# [2025-09-23 16:37:12:287] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -338.7561857231194. Mean: -0.23541083094031925. Std: 0.10040706449685045
# [2025-09-23 16:37:12:287] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.32490945. Mean: 0.0009207153926337735. Std: 0.0016196352712393727
# [2025-09-23 16:37:12:302] [SmartMeterDiscreteEnv Test] Episode 0035 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0035_info.json
# [2025-09-23 16:37:12:306] [SmartMeterWorldDiscrete Test] Resetting environment with episode 36. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-03 00:00:01'), Timestamp('2013-05-03 23:59:01'))}
# [2025-09-23 16:37:17:088] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 198.96503434311796. Mean of rewards: 0.13826618091947043. Std of rewards: 0.04905049136484764
# [2025-09-23 16:37:17:088] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -399.34247874456923. Mean: -0.2775138837696798. Std: 0.09742607443714865
# [2025-09-23 16:37:17:088] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4124100583333332. Mean: 0.000981521930738939. Std: 0.0018994874448289042
# [2025-09-23 16:37:17:104] [SmartMeterDiscreteEnv Test] Episode 0036 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0036_info.json
# [2025-09-23 16:37:17:108] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-04 00:00:04'), Timestamp('2013-05-04 23:59:04'))}
# [2025-09-23 16:37:21:620] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 196.56386190672808. Mean of rewards: 0.13659754128334126. Std of rewards: 0.047432246386949616
# [2025-09-23 16:37:21:620] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -394.6561876467895. Mean: -0.2742572534029114. Std: 0.09418939138245294
# [2025-09-23 16:37:21:620] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5284638333333334. Mean: 0.0010621708362288627. Std: 0.0020006574088396456
# [2025-09-23 16:37:21:636] [SmartMeterDiscreteEnv Test] Episode 0037 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0037_info.json
# [2025-09-23 16:37:21:640] [SmartMeterWorldDiscrete Test] Resetting environment with episode 38. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-05 00:00:01'), Timestamp('2013-05-05 23:59:01'))}
# [2025-09-23 16:37:26:410] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 195.00295611362878. Mean of rewards: 0.1355128256522785. Std of rewards: 0.05443616128755539
# [2025-09-23 16:37:26:410] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -391.61079137725756. Mean: -0.27214092521004696. Std: 0.1082999975848118
# [2025-09-23 16:37:26:410] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.60487915. Mean: 0.0011152739054899235. Std: 0.002210736608590596
# [2025-09-23 16:37:26:426] [SmartMeterDiscreteEnv Test] Episode 0038 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0038_info.json
# [2025-09-23 16:37:26:430] [SmartMeterWorldDiscrete Test] Resetting environment with episode 39. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-06 00:00:03'), Timestamp('2013-05-06 23:59:03'))}
# [2025-09-23 16:37:31:217] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 207.6553385368771. Mean of rewards: 0.14430530822576587. Std of rewards: 0.04197543139536095
# [2025-09-23 16:37:31:217] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -416.4262788737542. Mean: -0.28938587830003765. Std: 0.08343769504109845
# [2025-09-23 16:37:31:217] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1156017999999999. Mean: 0.0007752618485059068. Std: 0.0015969125245561895
# [2025-09-23 16:37:31:233] [SmartMeterDiscreteEnv Test] Episode 0039 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0039_info.json
# [2025-09-23 16:37:31:233] Episode 40/162 completed.
# [2025-09-23 16:37:31:237] [SmartMeterWorldDiscrete Test] Resetting environment with episode 40. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-07 00:00:04'), Timestamp('2013-05-07 23:59:04'))}
# [2025-09-23 16:37:37:475] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 208.1059803027141. Mean of rewards: 0.14461847137089234. Std of rewards: 0.03798411973086398
# [2025-09-23 16:37:37:475] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -417.6892601554282. Mean: -0.2902635581344185. Std: 0.07529435122162861
# [2025-09-23 16:37:37:475] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4772995500000001. Mean: 0.0010266153926337736. Std: 0.0019226933472253436
# [2025-09-23 16:37:37:493] [SmartMeterDiscreteEnv Test] Episode 0040 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0040_info.json
# [2025-09-23 16:37:37:497] [SmartMeterWorldDiscrete Test] Resetting environment with episode 41. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-25 00:00:03'), Timestamp('2013-05-25 23:59:03'))}
# [2025-09-23 16:37:42:296] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 209.03226955513324. Mean of rewards: 0.14526217481246229. Std of rewards: 0.03225901105203071
# [2025-09-23 16:37:42:296] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -419.41787608526647. Mean: -0.2914648200731525. Std: 0.0639923799776078
# [2025-09-23 16:37:42:296] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.353336975. Mean: 0.000940470448227936. Std: 0.0016715067906256525
# [2025-09-23 16:37:42:312] [SmartMeterDiscreteEnv Test] Episode 0041 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0041_info.json
# [2025-09-23 16:37:42:316] [SmartMeterWorldDiscrete Test] Resetting environment with episode 42. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-26 00:00:04'), Timestamp('2013-05-26 23:59:04'))}
# [2025-09-23 16:37:46:867] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 200.19217725910508. Mean of rewards: 0.139118955704729. Std of rewards: 0.03269105752139213
# [2025-09-23 16:37:46:867] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -401.8924890682101. Mean: -0.2792859548771439. Std: 0.06487960659327943
# [2025-09-23 16:37:46:867] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.50813455. Mean: 0.001048043467685893. Std: 0.0017563887872762988
# [2025-09-23 16:37:46:882] [SmartMeterDiscreteEnv Test] Episode 0042 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0042_info.json
# [2025-09-23 16:37:46:885] [SmartMeterWorldDiscrete Test] Resetting environment with episode 43. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-27 00:00:05'), Timestamp('2013-05-27 23:59:05'))}
# [2025-09-23 16:37:51:595] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 210.79122103377878. Mean of rewards: 0.14648451774411314. Std of rewards: 0.034509354676935625
# [2025-09-23 16:37:51:595] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -422.7612764425576. Mean: -0.29378823936244447. Std: 0.06857678122658267
# [2025-09-23 16:37:51:595] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.178834375. Mean: 0.0008192038742182072. Std: 0.0012913350720294555
# [2025-09-23 16:37:51:612] [SmartMeterDiscreteEnv Test] Episode 0043 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0043_info.json
# [2025-09-23 16:37:51:616] [SmartMeterWorldDiscrete Test] Resetting environment with episode 44. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-28 00:00:00'), Timestamp('2013-05-28 23:59:00'))}
# [2025-09-23 16:37:56:711] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 203.0576078944037. Mean of rewards: 0.14111022091341466. Std of rewards: 0.03568868971276362
# [2025-09-23 16:37:56:711] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -407.2959325388074. Mean: -0.28304095381432065. Std: 0.07105728440345722
# [2025-09-23 16:37:56:711] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1807167500000002. Mean: 0.0008205119874913136. Std: 0.0015079270844942393
# [2025-09-23 16:37:56:727] [SmartMeterDiscreteEnv Test] Episode 0044 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0044_info.json
# [2025-09-23 16:37:56:732] [SmartMeterWorldDiscrete Test] Resetting environment with episode 45. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-29 00:00:04'), Timestamp('2013-05-29 23:59:04'))}
# [2025-09-23 16:38:01:502] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 201.68809928655986. Mean of rewards: 0.14015851236036125. Std of rewards: 0.03190186659624363
# [2025-09-23 16:38:01:502] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -404.90579538978636. Mean: -0.2813799828976973. Std: 0.06342956256226456
# [2025-09-23 16:38:01:502] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5295968166666667. Mean: 0.001062958176974751. Std: 0.0018184659740055253
# [2025-09-23 16:38:01:518] [SmartMeterDiscreteEnv Test] Episode 0045 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0045_info.json
# [2025-09-23 16:38:01:523] [SmartMeterWorldDiscrete Test] Resetting environment with episode 46. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-30 00:00:02'), Timestamp('2013-05-30 23:59:02'))}
# [2025-09-23 16:38:06:301] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 206.4737954788119. Mean of rewards: 0.14348422201446276. Std of rewards: 0.033429525641507106
# [2025-09-23 16:38:06:301] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -414.3147396076238. Mean: -0.2879185125834773. Std: 0.06636620009230225
# [2025-09-23 16:38:06:301] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3671486499999999. Mean: 0.000950068554551772. Std: 0.0015802127698592125
# [2025-09-23 16:38:06:318] [SmartMeterDiscreteEnv Test] Episode 0046 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0046_info.json
# [2025-09-23 16:38:06:323] [SmartMeterWorldDiscrete Test] Resetting environment with episode 47. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-31 00:00:05'), Timestamp('2013-05-31 23:59:05'))}
# [2025-09-23 16:38:12:653] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 195.57384568169374. Mean of rewards: 0.13590955224579132. Std of rewards: 0.041954015528543755
# [2025-09-23 16:38:12:654] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -392.29769673838746. Mean: -0.2726182743143763. Std: 0.08343679319191052
# [2025-09-23 16:38:12:654] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.150005375. Mean: 0.0007991698227936068. Std: 0.0014864256560432104
# [2025-09-23 16:38:12:669] [SmartMeterDiscreteEnv Test] Episode 0047 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0047_info.json
# [2025-09-23 16:38:12:674] [SmartMeterWorldDiscrete Test] Resetting environment with episode 48. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-01 00:00:00'), Timestamp('2013-06-01 23:59:00'))}
# [2025-09-23 16:38:17:615] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 208.3103368345333. Mean of rewards: 0.1447604842491545. Std of rewards: 0.0371442915339097
# [2025-09-23 16:38:17:615] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -418.1398801690666. Mean: -0.2905767061633541. Std: 0.07340369213748019
# [2025-09-23 16:38:17:615] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5192065. Mean: 0.0010557376650451701. Std: 0.0019624052915924776
# [2025-09-23 16:38:17:631] [SmartMeterDiscreteEnv Test] Episode 0048 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0048_info.json
# [2025-09-23 16:38:17:635] [SmartMeterWorldDiscrete Test] Resetting environment with episode 49. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-02 00:00:02'), Timestamp('2013-06-02 23:59:02'))}
# [2025-09-23 16:38:22:368] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 187.28070908847587. Mean of rewards: 0.13014642744160937. Std of rewards: 0.06122503522897643
# [2025-09-23 16:38:22:368] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -376.02446207695175. Mean: -0.26130956363929936. Std: 0.12188413043664088
# [2025-09-23 16:38:22:368] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4630439. Mean: 0.0010167087560806116. Std: 0.00196106097503198
# [2025-09-23 16:38:22:384] [SmartMeterDiscreteEnv Test] Episode 0049 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0049_info.json
# [2025-09-23 16:38:22:384] Episode 50/162 completed.
# [2025-09-23 16:38:22:388] [SmartMeterWorldDiscrete Test] Resetting environment with episode 50. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-25 00:00:01'), Timestamp('2013-06-25 23:59:01'))}
# [2025-09-23 16:38:27:324] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 188.781803769128. Mean of rewards: 0.131189578713779. Std of rewards: 0.04459815545780548
# [2025-09-23 16:38:27:324] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -378.7485812465893. Mean: -0.2632026276904721. Std: 0.08873316483589892
# [2025-09-23 16:38:27:324] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1849737083333334. Mean: 0.0008234702629140607. Std: 0.0014898759939188451
# [2025-09-23 16:38:27:341] [SmartMeterDiscreteEnv Test] Episode 0050 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0050_info.json
# [2025-09-23 16:38:27:345] [SmartMeterWorldDiscrete Test] Resetting environment with episode 51. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-26 00:00:00'), Timestamp('2013-06-26 23:59:00'))}
# [2025-09-23 16:38:32:214] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 176.03146359561586. Mean of rewards: 0.12232902265157458. Std of rewards: 0.045583228972393676
# [2025-09-23 16:38:32:214] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -353.5024489412317. Mean: -0.2456584078813285. Std: 0.09050361257118948
# [2025-09-23 16:38:32:214] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.43952175. Mean: 0.0010003625781792912. Std: 0.001850106448492125
# [2025-09-23 16:38:32:230] [SmartMeterDiscreteEnv Test] Episode 0051 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0051_info.json
# [2025-09-23 16:38:32:234] [SmartMeterWorldDiscrete Test] Resetting environment with episode 52. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-27 00:00:03'), Timestamp('2013-06-27 23:59:03'))}
# [2025-09-23 16:38:37:128] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 200.85887076625556. Mean of rewards: 0.13958225904534785. Std of rewards: 0.04974641921460237
# [2025-09-23 16:38:37:128] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -402.9792650825111. Mean: -0.2800411849079299. Std: 0.09886840289975433
# [2025-09-23 16:38:37:128] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.26152355. Mean: 0.0008766668172341904. Std: 0.0016935237042184682
# ...
# [2025-09-23 16:47:01:379] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4289135. Mean: 0.000992990618485059. Std: 0.001968135241818812
# [2025-09-23 16:47:01:395] [SmartMeterDiscreteEnv Test] Episode 0144 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0144_info.json
# [2025-09-23 16:47:01:399] [SmartMeterWorldDiscrete Test] Resetting environment with episode 145. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-28 00:00:04'), Timestamp('2013-11-28 23:59:04'))}
# [2025-09-23 16:47:06:215] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 89.7926276407367. Mean of rewards: 0.06239932428126247. Std of rewards: 0.0370718309084159
# [2025-09-23 16:47:06:215] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -180.9691835314734. Mean: -0.12576037771471396. Std: 0.07396490951967577
# [2025-09-23 16:47:06:215] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3839282499999999. Mean: 0.0009617291521890201. Std: 0.0018668693811824386
# [2025-09-23 16:47:06:230] [SmartMeterDiscreteEnv Test] Episode 0145 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0145_info.json
# [2025-09-23 16:47:06:234] [SmartMeterWorldDiscrete Test] Resetting environment with episode 146. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-29 00:00:01'), Timestamp('2013-12-29 23:59:01'))}
# [2025-09-23 16:47:12:565] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 180.16543743001043. Mean of rewards: 0.125201832821411. Std of rewards: 0.04851725038329207
# [2025-09-23 16:47:12:565] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -361.63137912668753. Mean: -0.2513074212138204. Std: 0.09661744707991439
# [2025-09-23 16:47:12:565] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3005042666666666. Mean: 0.0009037555709983785. Std: 0.0017143817864596158
# [2025-09-23 16:47:12:581] [SmartMeterDiscreteEnv Test] Episode 0146 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0146_info.json
# [2025-09-23 16:47:12:586] [SmartMeterWorldDiscrete Test] Resetting environment with episode 147. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-30 00:00:01'), Timestamp('2013-12-30 23:59:01'))}
# [2025-09-23 16:47:17:410] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 166.2541668119188. Mean of rewards: 0.1155345148102285. Std of rewards: 0.04861280158068542
# [2025-09-23 16:47:17:410] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -333.7556302738376. Mean: -0.2319358097802902. Std: 0.09704769063807128
# [2025-09-23 16:47:17:410] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.24729665. Mean: 0.0008667801598332176. Std: 0.0016914985240550808
# [2025-09-23 16:47:17:427] [SmartMeterDiscreteEnv Test] Episode 0147 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0147_info.json
# [2025-09-23 16:47:17:431] [SmartMeterWorldDiscrete Test] Resetting environment with episode 148. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-01 00:00:02'), Timestamp('2013-12-01 23:59:02'))}
# [2025-09-23 16:47:22:274] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 188.76160966083685. Mean of rewards: 0.131175545282027. Std of rewards: 0.044880491529457577
# [2025-09-23 16:47:22:274] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -378.7859463216737. Mean: -0.26322859369122564. Std: 0.08925515858641982
# [2025-09-23 16:47:22:274] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.262727. Mean: 0.000877503127171647. Std: 0.0017382642372352247
# [2025-09-23 16:47:22:290] [SmartMeterDiscreteEnv Test] Episode 0148 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0148_info.json
# [2025-09-23 16:47:22:295] [SmartMeterWorldDiscrete Test] Resetting environment with episode 149. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-02 00:00:00'), Timestamp('2013-12-02 23:59:00'))}
# [2025-09-23 16:47:27:118] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 175.63191472189536. Mean of rewards: 0.12205136533835673. Std of rewards: 0.058457075102388
# [2025-09-23 16:47:27:118] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -352.7574556937907. Mean: -0.2451406919345314. Std: 0.11659080444541063
# [2025-09-23 16:47:27:118] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4936262500000002. Mean: 0.0010379612578179291. Std: 0.002069632730610111
# [2025-09-23 16:47:27:134] [SmartMeterDiscreteEnv Test] Episode 0149 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0149_info.json
# [2025-09-23 16:47:27:134] Episode 150/162 completed.
# [2025-09-23 16:47:27:138] [SmartMeterWorldDiscrete Test] Resetting environment with episode 150. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-03 00:00:02'), Timestamp('2013-12-03 23:59:02'))}
# [2025-09-23 16:47:31:944] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 128.57634480998718. Mean of rewards: 0.08935117776927531. Std of rewards: 0.03889774852227252
# [2025-09-23 16:47:31:944] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -258.53818461997434. Mean: -0.17966517346766805. Std: 0.07733681907361512
# [2025-09-23 16:47:31:944] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.385495. Mean: 0.0009628179291174426. Std: 0.001984647411489206
# [2025-09-23 16:47:31:961] [SmartMeterDiscreteEnv Test] Episode 0150 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0150_info.json
# [2025-09-23 16:47:31:965] [SmartMeterWorldDiscrete Test] Resetting environment with episode 151. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-04 00:00:04'), Timestamp('2013-12-04 23:59:04'))}
# [2025-09-23 16:47:36:760] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 151.0804147547296. Mean of rewards: 0.10498986431878359. Std of rewards: 0.043518279244075336
# [2025-09-23 16:47:36:761] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -303.42791025945917. Mean: -0.21086025730330726. Std: 0.0866460292488524
# [2025-09-23 16:47:36:761] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2670807499999999. Mean: 0.0008805286657400972. Std: 0.0016257251220400917
# [2025-09-23 16:47:36:777] [SmartMeterDiscreteEnv Test] Episode 0151 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0151_info.json
# [2025-09-23 16:47:36:781] [SmartMeterWorldDiscrete Test] Resetting environment with episode 152. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-05 00:00:03'), Timestamp('2013-12-05 23:59:03'))}
# [2025-09-23 16:47:43:002] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 188.40654668924344. Mean of rewards: 0.1309288024247696. Std of rewards: 0.04970812568201832
# [2025-09-23 16:47:43:002] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -378.3284185784869. Mean: -0.2629106452942925. Std: 0.09871908933859261
# [2025-09-23 16:47:43:002] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5153252. Mean: 0.001053040444753301. Std: 0.0019057256466673295
# [2025-09-23 16:47:43:018] [SmartMeterDiscreteEnv Test] Episode 0152 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0152_info.json
# [2025-09-23 16:47:43:023] [SmartMeterWorldDiscrete Test] Resetting environment with episode 153. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-06 00:00:01'), Timestamp('2013-12-06 23:59:01'))}
# [2025-09-23 16:47:47:845] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 148.3383774675801. Mean of rewards: 0.1030843484833774. Std of rewards: 0.05350448751158327
# [2025-09-23 16:47:47:845] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -298.06290045182686. Mean: -0.20713196695748914. Std: 0.10666388784017161
# [2025-09-23 16:47:47:845] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3861455166666665. Mean: 0.0009632699907343061. Std: 0.0018125097202626502
# [2025-09-23 16:47:47:862] [SmartMeterDiscreteEnv Test] Episode 0153 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0153_info.json
# [2025-09-23 16:47:47:867] [SmartMeterWorldDiscrete Test] Resetting environment with episode 154. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-07 00:00:05'), Timestamp('2013-12-07 23:59:05'))}
# [2025-09-23 16:47:52:697] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 149.36371759370982. Mean of rewards: 0.1037968850546976. Std of rewards: 0.04695961224661497
# [2025-09-23 16:47:52:697] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -300.01025768741965. Mean: -0.20848523814275166. Std: 0.09362197113939956
# [2025-09-23 16:47:52:697] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2828225. Mean: 0.0008914680333564975. Std: 0.0017149913424950268
# [2025-09-23 16:47:52:713] [SmartMeterDiscreteEnv Test] Episode 0154 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0154_info.json
# [2025-09-23 16:47:52:717] [SmartMeterWorldDiscrete Test] Resetting environment with episode 155. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-22 00:00:05'), Timestamp('2013-12-22 23:59:05'))}
# [2025-09-23 16:47:57:514] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 205.85492491375396. Mean of rewards: 0.14305415212908545. Std of rewards: 0.03977459845974702
# [2025-09-23 16:47:57:515] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -413.04731266084127. Mean: -0.2870377433362344. Std: 0.07885213412266652
# [2025-09-23 16:47:57:515] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3374628333333334. Mean: 0.0009294390780634701. Std: 0.0017645975479277482
# [2025-09-23 16:47:57:531] [SmartMeterDiscreteEnv Test] Episode 0155 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0155_info.json
# [2025-09-23 16:47:57:535] [SmartMeterWorldDiscrete Test] Resetting environment with episode 156. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-23 00:00:05'), Timestamp('2013-12-23 23:59:05'))}
# [2025-09-23 16:48:02:357] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 196.91165895816636. Mean of rewards: 0.1368392348562657. Std of rewards: 0.0400900390804867
# [2025-09-23 16:48:02:357] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -394.87947520799935. Mean: -0.2744124219652532. Std: 0.08000475183404786
# [2025-09-23 16:48:02:357] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0561572916666666. Mean: 0.0007339522527217975. Std: 0.0011377710404011196
# [2025-09-23 16:48:02:373] [SmartMeterDiscreteEnv Test] Episode 0156 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0156_info.json
# [2025-09-23 16:48:02:378] [SmartMeterWorldDiscrete Test] Resetting environment with episode 157. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-24 00:00:05'), Timestamp('2013-12-24 23:59:05'))}
# [2025-09-23 16:48:07:242] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 198.91735260314394. Mean of rewards: 0.13823304558939814. Std of rewards: 0.03807433822354115
# [2025-09-23 16:48:07:242] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -399.27321983128786. Mean: -0.2774657538785878. Std: 0.07594347354957083
# [2025-09-23 16:48:07:242] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.4385146249999998. Mean: 0.0009996626997915217. Std: 0.0013741877834661514
# [2025-09-23 16:48:07:258] [SmartMeterDiscreteEnv Test] Episode 0157 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0157_info.json
# [2025-09-23 16:48:07:263] [SmartMeterWorldDiscrete Test] Resetting environment with episode 158. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-25 00:00:00'), Timestamp('2013-12-25 23:59:00'))}
# [2025-09-23 16:48:12:252] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 191.1591032115746. Mean of rewards: 0.13284162836106642. Std of rewards: 0.04080026309092412
# [2025-09-23 16:48:12:252] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -383.66433542314917. Mean: -0.26661871815368254. Std: 0.08126979845711083
# [2025-09-23 16:48:12:253] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.346129. Mean: 0.0009354614315496872. Std: 0.0015919811963419105
# [2025-09-23 16:48:12:269] [SmartMeterDiscreteEnv Test] Episode 0158 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0158_info.json
# [2025-09-23 16:48:12:273] [SmartMeterWorldDiscrete Test] Resetting environment with episode 159. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-26 00:00:02'), Timestamp('2013-12-26 23:59:02'))}
# [2025-09-23 16:48:18:699] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 199.64932192920702. Mean of rewards: 0.13874171086115847. Std of rewards: 0.03563160658598631
# [2025-09-23 16:48:18:699] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -400.48530164174736. Mean: -0.27830806229447347. Std: 0.07099168162296216
# [2025-09-23 16:48:18:699] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1866577833333334. Mean: 0.0008246405721565903. Std: 0.0014259242488446836
# [2025-09-23 16:48:18:715] [SmartMeterDiscreteEnv Test] Episode 0159 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0159_info.json
# [2025-09-23 16:48:18:715] Episode 160/162 completed.
# [2025-09-23 16:48:18:719] [SmartMeterWorldDiscrete Test] Resetting environment with episode 160. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-27 00:00:04'), Timestamp('2013-12-27 23:59:04'))}
# [2025-09-23 16:48:23:700] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 197.6640096661482. Mean of rewards: 0.13736206370128437. Std of rewards: 0.03631102205320944
# [2025-09-23 16:48:23:701] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -396.85427764896303. Mean: -0.2757847655656449. Std: 0.07221410725249586
# [2025-09-23 16:48:23:701] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.526258316666667. Mean: 0.0010606381630762106. Std: 0.0013778696256131328
# [2025-09-23 16:48:23:717] [SmartMeterDiscreteEnv Test] Episode 0160 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0160_info.json
# [2025-09-23 16:48:23:721] [SmartMeterWorldDiscrete Test] Resetting environment with episode 161. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-28 00:00:03'), Timestamp('2013-12-28 23:59:03'))}
# [2025-09-23 16:48:28:563] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: 190.62855851511398. Mean of rewards: 0.13247293850946074. Std of rewards: 0.05073582703924815
# [2025-09-23 16:48:28:563] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -382.84663433022797. Mean: -0.2660504755595747. Std: 0.10106370796867999
# [2025-09-23 16:48:28:563] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5895173. Mean: 0.0011045985406532314. Std: 0.0019848424555562816
# [2025-09-23 16:48:28:578] [SmartMeterDiscreteEnv Test] Episode 0161 info saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/episode_info/episode_0161_info.json
# [2025-09-23 16:48:28:582] Validation results saved to experiments/20250814_020526_action_discrete_reward_lambda_0.5/logs_train_selected-ckpt/test_stats_file.json
