# %% [markdown]
# **FULLY REFACTORED VERSION** - A template of the RL training, with H-network trained along side the DDQN agent
#
# This notebook uses the refactored environment factory pattern for creating discrete environments.
# It uses the unified factory pattern for environments, H-network modules, and callbacks.

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from datetime import datetime
import sys

from utils import print_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the created dataset
dataset_folder_path = Path("dataset", "20250707_downsampled_1min", "split")

# %%
from utils_data_split import load_split_data_from_folder, convert_to_naive_datetimes, convert_to_naive_datetimes_df

# %%
aggregate_load_segments_test, aggregate_load_df_test = load_split_data_from_folder(dataset_folder_path, 'test')

# %%
aggregate_load_segments_test, aggregate_load_df_test = convert_to_naive_datetimes(aggregate_load_segments_test), convert_to_naive_datetimes_df(aggregate_load_df_test)

# %% [markdown]
# ---

# %% [markdown]
# (DDQN) only
#
# We have to quantize the data into per 0.05kW = 50W. This is for the charging action and other stuffs

# %%
# https://stackoverflow.com/questions/47949053/round-to-nearest-1000-in-pandas

def round_to_nearest_50(x):
    """Round to the nearest 50"""
    return ((x + 25) / 50).astype(int) * 50


aggregate_load_df_test["aggregate"] = round_to_nearest_50(aggregate_load_df_test["aggregate"])

# then cap at 5kW
aggregate_load_df_test["aggregate"] = aggregate_load_df_test["aggregate"].clip(upper=5000)

# %% [markdown]
# ---

# %% [markdown]
# Experiment start

# %%
# initialize experiment folder to store related information/data for future analysis

# rl_datetime = datetime(2025, 8, 7, 5, 26, 15)
# rl_datetime = datetime(2025, 8, 7, 8, 13, 47)
rl_datetime = datetime(2025, 8, 7, 11, 5, 34)
ACTION_TYPE = "discrete"
REWARD_LAMBDA = 1.0  # between 0 and 1

experiment_folder = Path(
    "experiments", rl_datetime.strftime('%Y%m%d_%H%M%S') + f"_action_{ACTION_TYPE}_reward_lambda_{REWARD_LAMBDA:.1f}", 
)

if not experiment_folder.exists():
    raise FileNotFoundError(f"Experiment folder {experiment_folder} does not exist. Please check the path.")

# %%
# find the selected checkpoint

selected_ckpt_folder = experiment_folder / "selected_ckpt"

# search for any sub-folders under selected_ckpt_folder
sub_folders = [f for f in selected_ckpt_folder.iterdir() if f.is_dir()]
# assert len(sub_folders) == 1, "There should be exactly one sub-folder in selected_ckpt_folder."

selected_ckpt_folder = sub_folders[0]
selected_ckpt_episode_number = int(selected_ckpt_folder.name.split('_')[-1])

print_log(f"Selected checkpoint folder: {selected_ckpt_folder}")
# Out:
# [2025-08-12 12:27:01:464] Selected checkpoint folder: experiments/20250807_110534_action_discrete_reward_lambda_1.0/selected_ckpt/episode_0700

# %% [markdown]
# TODO: read the experiment_details under the experiment_folder, find the seed element, and use it to set the action_space and RL model for reproducibility

# %% [markdown]
# Create data loader

# %%
sys.path.append(str(Path('rl_env')))
sys.path.append(str(Path('model', 'H_network')))

from rl_env.data_loader import SimpleSmartMeterDataLoader

sm_dl_test = SimpleSmartMeterDataLoader(
    aggregate_load_segments=aggregate_load_segments_test,
    aggregate_load_df=aggregate_load_df_test,
    registry_path=experiment_folder / "simple_episode_registry_test.json"
)

sm_dl_test.get_divided_segments_length()
# Out:
# [SimpleDataLoader] Generated 80 episodes (1 day each)
# 80

# %%
sm_dl_test.divided_segments[7]
# Out:
# array([datetime.datetime(2013, 2, 15, 0, 0),
#        datetime.datetime(2013, 2, 15, 23, 59, 59, 999000)], dtype=object)

# %%
# sample segment

sm_dl_test.get_aggregate_load_segment(13)
# Out:
#         timestamp  aggregate            datetime  segment_index  \
# 18720  1362355201        150 2013-03-04 00:00:01             13
# 18721  1362355261        150 2013-03-04 00:01:01             13
# 18722  1362355321        150 2013-03-04 00:02:01             13
# 18723  1362355381        150 2013-03-04 00:03:01             13
# 18724  1362355441        150 2013-03-04 00:04:01             13
# ...           ...        ...                 ...            ...
# 20155  1362441301        250 2013-03-04 23:55:01             13
# 20156  1362441361        250 2013-03-04 23:56:01             13
# 20157  1362441421        300 2013-03-04 23:57:01             13
# 20158  1362441481        300 2013-03-04 23:58:01             13
# 20159  1362441541        300 2013-03-04 23:59:01             13
#
#       episode_content_id  episode_length_days
# 18720       9eafa9c7f9a1                    1
# 18721       9eafa9c7f9a1                    1
# 18722       9eafa9c7f9a1                    1
# 18723       9eafa9c7f9a1                    1
# 18724       9eafa9c7f9a1                    1
# ...                  ...                  ...
# 20155       9eafa9c7f9a1                    1
# 20156       9eafa9c7f9a1                    1
# 20157       9eafa9c7f9a1                    1
# 20158       9eafa9c7f9a1                    1
# 20159       9eafa9c7f9a1                    1
#
# [1440 rows x 6 columns]

# %% [markdown]
# Create the environment

# %%
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from model.H_network.common.factories import create_h_network_module_with_defaults
from model.H_network.h_network_arch import HNetworkType

# the optimizer kwargs does not matter for the testing loop, but they are required to create the module

h_network_kwargs = {
    "h_network_type": HNetworkType.H_NETWORK,
    "optimizer_class": torch.optim.RMSprop,
    "optimizer_kwargs": {"lr": 0.001},
}

h_network_rl_module = create_h_network_module_with_defaults(
    action_type=ACTION_TYPE,
    **h_network_kwargs,
    device=DEVICE
)

# %%
from rl_env.base.env_module import SmartMeterEnvFactory
from rl_env.training_mode import TrainingMode
from decimal import Decimal

env_test = SmartMeterEnvFactory.create(
    action_type=ACTION_TYPE,
    smart_meter_data_loader=sm_dl_test,
    h_network_rl_module=h_network_rl_module,
    mode=TrainingMode.TEST,
    reward_lambda=REWARD_LAMBDA,
    render_mode=None,

    aggregate_step_size=50,  # step size for the aggregate load
    battery_step_size=Decimal("0.05")
)
# Out:
# [2025-08-12 12:27:02:626] [SmartMeterDiscreteEnv Test] Using data loader: SimpleSmartMeterDataLoader
# [2025-08-12 12:27:02:626] [SmartMeterDiscreteEnv Test] Curriculum enabled: False
# [2025-08-12 12:27:02:631] [SmartMeterDiscreteEnv Test]] Render mode set to 'None'. Render server at 127.0.0.1:50007. render_connected: False. render_client_socket: None

# %%
h_network_rl_module.set_h_network(
    h_network_rl_module.initialize_h_network(output_dim=env_test.observation_space["aggregate_logit"].n)  # output_dim is the number states in the aggregate load space
)
h_network_rl_module.initialize_h_network_training()

# %%
# load the h_network from the selected checkpoint

h_network_rl_module.load_h_network(
    selected_ckpt_folder / ("h_network" + f"_{selected_ckpt_episode_number:04d}" + ".pth")
)

# %%
h_network_rl_module.h_network
# Out:
# HNetwork(
#   (LSTM_1): LSTM(2, 44, batch_first=True, bidirectional=True)
#   (ac1): Tanh()
#   (LSTM_2): LSTM(88, 44, batch_first=True, bidirectional=True)
#   (ac2): Tanh()
#   (fc): Linear(in_features=88, out_features=101, bias=True)
# )

# %%
import torchinfo


torchinfo.summary(h_network_rl_module.h_network, input_size=(1, 1, 2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HNetwork                                 [1, 1, 101]               --
# ├─LSTM: 1-1                              [1, 1, 88]                16,896
# ├─Tanh: 1-2                              [1, 1, 88]                --
# ├─LSTM: 1-3                              [1, 1, 88]                47,168
# ├─Tanh: 1-4                              [1, 1, 88]                --
# ├─Linear: 1-5                            [1, 1, 101]               8,989
# ==========================================================================================
# Total params: 73,053
# Trainable params: 73,053
# Non-trainable params: 0
# Total mult-adds (M): 0.07
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.29
# Estimated Total Size (MB): 0.29
# ==========================================================================================

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env_test)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# [2025-08-12 12:27:03:704] [SmartMeterWorldDiscrete Test] Resetting environment with episode 74. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-16 00:00:06'), Timestamp('2013-12-16 23:59:06'))}
# [2025-08-12 12:27:03:707] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:27:03:709] [SmartMeterWorldDiscrete Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-08-12 12:27:03:712] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:27:03:714] [SmartMeterWorldDiscrete Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-08-12 12:27:03:716] [SmartMeterWorldDiscrete Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-08-12 12:27:03:719] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-08-12 12:27:03:721] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-08-12 12:27:03:778] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:27:03:784] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# Environment passes all checks!
# /root/miniforge3/envs/smartmeter/lib/python3.9/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
env_test.reset_render_window()

# %% [markdown]
# Also initiate a validation environment for time-to-time validation

# %%
# callbacks for training - using refactored callback system
from rl_env.env_callbacks import TrainHNetworkEveryNEpisodes, SaveCheckpointEveryNEpisodes, ValidateEveryNEpisodes, EnvLoggingCallback, UpdateGlobalTimestepCallback
# Out:
# 2025-08-12 12:27:04.028693: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-12 12:27:04.037362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754998024.046897   78725 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754998024.049870   78725 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754998024.057699   78725 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754998024.057711   78725 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754998024.057712   78725 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754998024.057713   78725 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-12 12:27:04.060989: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# initialize a DQN agent
from model.DDQN.ddqn import DoubleDQN

# rl_datetime = datetime.now()

# rl_lr = 0.00025
# rl_buffer_size = 150000  # scaled to match with our episode length
# rl_batch_size = 128     # keep the same as the paper
# rl_gamma = 1  # keep the same as the paper
# rl_train_freq = (120, "step")  # scaled to match with our episode length
# rl_target_update_interval = 7500  # scaled to match with our episode length
# policy_kwargs = {
#     "optimizer_class": torch.optim.RMSprop,     # keep the same as the paper
# }

rl_model = DoubleDQN(
    "MultiInputPolicy",
    env_test,
    verbose=2,

)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
rl_model = rl_model.load(
    selected_ckpt_folder / ("rl_model" + f"_{selected_ckpt_episode_number:04d}")  # path to the saved RL model
)

# %%
rl_model.policy
# Out:
# MultiInputPolicy(
#   (q_net): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_logit): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=105, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_logit): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=105, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
# )

# %%
# we test the rl model and H-network

import json
from utils import print_log

total_episodes = env_test.smart_meter_data_loader.get_divided_segments_length()
episode_indices = list(range(total_episodes))

all_episode_rewards = []
all_episode_lengths = []
all_episode_infos = []
per_episode_reward_stats = []

for i, episode_idx in enumerate(episode_indices):
    obs, info = env_test.reset(episode_idx=episode_idx)

    # Initialize episode tracking variables
    episode_reward = 0.0
    episode_length = 0
    done = False
    state = None  # For recurrent policies

    while not done:
        # Get action from the RL model
        action, state = rl_model.predict(obs, state=state, deterministic=True)

        # Step the environment
        obs, reward, done, truncated, info = env_test.step(action)

        # Update episode tracking variables
        episode_reward += reward
        episode_length += 1

    # Store results for this episode
    all_episode_rewards.append(episode_reward)
    all_episode_lengths.append(episode_length)
    all_episode_infos.append({
        "episode_idx": episode_idx,
        "episode_info": env_test.episode.get_episode_info() if hasattr(env_test, 'episode') else {}
    })

    per_episode_reward_stats.append(env_test.prev_episode_reward_stats)

    env_test.save_episode_info(
        log_folder=experiment_folder / "logs_test",
        episode_training_idx=episode_idx
    )

    if (i + 1) % 10 == 0:
        print_log(f"Episode {i + 1}/{total_episodes} completed.")


# Calculate comprehensive statistics
mean_reward = np.mean(all_episode_rewards)
std_reward = np.std(all_episode_rewards)
min_reward = np.min(all_episode_rewards)
max_reward = np.max(all_episode_rewards)
median_reward = np.median(all_episode_rewards)

# we need to recover the true sum f_signal and g_signal from the per_episode_reward_stats, with length of each episode
f_signal_sums = np.array([item['f_signal_sum'] for item in per_episode_reward_stats])
g_signal_sums = np.array([item['g_signal_sum'] for item in per_episode_reward_stats])

# get the length of each episode
_episode_lengths = np.array(all_episode_lengths)
sum_episode_lengths = np.sum(_episode_lengths)

# calculate the (true) mean of rewards, f_signal and g_signal

f_signal_mean = f_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0
g_signal_mean = g_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0

mean_length = np.mean(all_episode_lengths)
std_length = np.std(all_episode_lengths)

# Prepare validation data
test_data = {
    'evaluated_episodes': len(episode_indices),
    'total_available_episodes': total_episodes,
    'episode_indices': episode_indices,
    'episode_rewards': all_episode_rewards,
    'episode_lengths': all_episode_lengths,
    'episode_infos': all_episode_infos,
    'summary_stats': {
        'mean_reward': mean_reward,
        'std_reward': std_reward,
        'min_reward': min_reward,
        'max_reward': max_reward,
        'median_reward': median_reward,
        'mean_f_signal': f_signal_mean,
        'mean_g_signal': g_signal_mean,
        'mean_length': mean_length,
        'std_length': std_length
    }
}

test_stats_file_path = experiment_folder / "logs_test" / "test_stats_file.json"
with open(test_stats_file_path, 'w') as f:
    # Convert numpy types to Python native types for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        return obj

    json.dump(convert_numpy(test_data), f, indent=2, default=str)

sm_dl_test._save_registry()
print_log(f"Validation results saved to {test_stats_file_path}")
# Out:
# [2025-08-12 12:27:05:044] [SmartMeterWorldDiscrete Test] Resetting environment with episode 0. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-01 00:00:01'), Timestamp('2013-01-01 23:59:01'))}
# [2025-08-12 12:27:09:448] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.7876317500000001. Mean of rewards: -0.00054734659485754. Std of rewards: 0.0004644640847213585
# [2025-08-12 12:27:09:448] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -315.90230377204716. Mean: -0.2195290505712628. Std: 0.09901721263733372
# [2025-08-12 12:27:09:448] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.78763175. Mean: 0.00054734659485754. Std: 0.0004644640847213585
# [2025-08-12 12:27:09:461] [SmartMeterDiscreteEnv Test] Episode 0000 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0000_info.json
# [2025-08-12 12:27:09:464] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-08-12 12:27:14:124] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.21126515. Mean of rewards: -0.0008417408964558723. Std of rewards: 0.0008823683155647301
# [2025-08-12 12:27:14:124] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -293.25635857495945. Mean: -0.20379177107363408. Std: 0.10426956692672971
# [2025-08-12 12:27:14:124] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2112651500000002. Mean: 0.0008417408964558723. Std: 0.0008823683155647301
# [2025-08-12 12:27:14:137] [SmartMeterDiscreteEnv Test] Episode 0001 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0001_info.json
# [2025-08-12 12:27:14:140] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-03 00:00:00'), Timestamp('2013-01-03 23:59:00'))}
# [2025-08-12 12:27:18:737] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.3368772500000001. Mean of rewards: -0.0009290321403752607. Std of rewards: 0.0010329871618752252
# [2025-08-12 12:27:18:737] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -200.38900209782878. Mean: -0.13925573460585738. Std: 0.07051709141503407
# [2025-08-12 12:27:18:737] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3368772500000001. Mean: 0.0009290321403752607. Std: 0.0010329871618752252
# [2025-08-12 12:27:18:750] [SmartMeterDiscreteEnv Test] Episode 0002 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0002_info.json
# [2025-08-12 12:27:18:753] [SmartMeterWorldDiscrete Test] Resetting environment with episode 3. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-04 00:00:05'), Timestamp('2013-01-04 23:59:05'))}
# [2025-08-12 12:27:26:891] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.30997325. Mean of rewards: -0.0009103358234885337. Std of rewards: 0.0010501848273000206
# [2025-08-12 12:27:26:891] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -267.3457378895837. Mean: -0.1857857803263264. Std: 0.09799425588328248
# [2025-08-12 12:27:26:891] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.30997325. Mean: 0.0009103358234885337. Std: 0.0010501848273000206
# [2025-08-12 12:27:26:904] [SmartMeterDiscreteEnv Test] Episode 0003 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0003_info.json
# [2025-08-12 12:27:26:907] [SmartMeterWorldDiscrete Test] Resetting environment with episode 4. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-05 00:00:04'), Timestamp('2013-01-05 23:59:04'))}
# [2025-08-12 12:27:31:442] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.5231241000000002. Mean of rewards: -0.0010584601111883255. Std of rewards: 0.001382432556546054
# [2025-08-12 12:27:31:442] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -294.67021633294644. Mean: -0.20477429904999753. Std: 0.1019742962818901
# [2025-08-12 12:27:31:442] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.5231241000000004. Mean: 0.0010584601111883255. Std: 0.001382432556546054
# [2025-08-12 12:27:31:455] [SmartMeterDiscreteEnv Test] Episode 0004 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0004_info.json
# [2025-08-12 12:27:31:459] [SmartMeterWorldDiscrete Test] Resetting environment with episode 5. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-06 00:00:01'), Timestamp('2013-01-06 23:59:01'))}
# [2025-08-12 12:27:35:959] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2065825166666668. Mean of rewards: -0.0008384868079684967. Std of rewards: 0.0009087374888486755
# [2025-08-12 12:27:35:960] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -269.4127930441173. Mean: -0.18722223283121422. Std: 0.10109897970468339
# [2025-08-12 12:27:35:960] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2065825166666668. Mean: 0.0008384868079684967. Std: 0.0009087374888486755
# [2025-08-12 12:27:35:973] [SmartMeterDiscreteEnv Test] Episode 0005 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0005_info.json
# [2025-08-12 12:27:35:976] [SmartMeterWorldDiscrete Test] Resetting environment with episode 6. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-14 00:00:03'), Timestamp('2013-02-14 23:59:03'))}
# [2025-08-12 12:27:40:446] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.344164375. Mean of rewards: -0.0009340961605281447. Std of rewards: 0.0010434948078538804
# [2025-08-12 12:27:40:446] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -353.3161590859527. Mean: -0.24552895002498448. Std: 0.10851120089944147
# [2025-08-12 12:27:40:446] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3441643750000003. Mean: 0.0009340961605281447. Std: 0.0010434948078538804
# [2025-08-12 12:27:40:459] [SmartMeterDiscreteEnv Test] Episode 0006 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0006_info.json
# [2025-08-12 12:27:40:462] [SmartMeterWorldDiscrete Test] Resetting environment with episode 7. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-15 00:00:00'), Timestamp('2013-02-15 23:59:00'))}
# [2025-08-12 12:27:44:573] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.314893. Mean of rewards: -0.0009137546907574706. Std of rewards: 0.0008754675563695209
# [2025-08-12 12:27:44:573] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -252.41839186870493. Mean: -0.17541236405052463. Std: 0.08455783492253875
# [2025-08-12 12:27:44:573] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.314893. Mean: 0.0009137546907574706. Std: 0.0008754675563695209
# [2025-08-12 12:27:44:586] [SmartMeterDiscreteEnv Test] Episode 0007 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0007_info.json
# [2025-08-12 12:27:44:589] [SmartMeterWorldDiscrete Test] Resetting environment with episode 8. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-16 00:00:02'), Timestamp('2013-02-16 23:59:02'))}
# [2025-08-12 12:27:48:665] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.3711230333333335. Mean of rewards: -0.000952830460968265. Std of rewards: 0.0008793673065185105
# [2025-08-12 12:27:48:665] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -291.1389855230809. Mean: -0.20232035130165457. Std: 0.0929277421865786
# [2025-08-12 12:27:48:665] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.3711230333333333. Mean: 0.000952830460968265. Std: 0.0008793673065185105
# [2025-08-12 12:27:48:678] [SmartMeterDiscreteEnv Test] Episode 0008 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0008_info.json
# [2025-08-12 12:27:48:682] [SmartMeterWorldDiscrete Test] Resetting environment with episode 9. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-17 00:00:01'), Timestamp('2013-02-17 23:59:01'))}
# [2025-08-12 12:27:52:746] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.1191124416666667. Mean of rewards: -0.0014726285209636324. Std of rewards: 0.0012146359241771705
# [2025-08-12 12:27:52:746] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -283.82025988958776. Mean: -0.197234371014307. Std: 0.11732174206011685
# [2025-08-12 12:27:52:746] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.119112441666667. Mean: 0.0014726285209636324. Std: 0.0012146359241771705
# [2025-08-12 12:27:52:760] [SmartMeterDiscreteEnv Test] Episode 0009 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0009_info.json
# [2025-08-12 12:27:52:760] Episode 10/80 completed.
# [2025-08-12 12:27:52:763] [SmartMeterWorldDiscrete Test] Resetting environment with episode 10. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-01 00:00:00'), Timestamp('2013-03-01 23:59:00'))}
# [2025-08-12 12:28:00:453] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.16044525. Mean of rewards: -0.0008064247741487143. Std of rewards: 0.0008814293851822466
# [2025-08-12 12:28:00:454] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -382.3456519637257. Mean: -0.2657023293702055. Std: 0.09393655785468417
# [2025-08-12 12:28:00:454] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.16044525. Mean: 0.0008064247741487143. Std: 0.0008814293851822466
# [2025-08-12 12:28:00:466] [SmartMeterDiscreteEnv Test] Episode 0010 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0010_info.json
# [2025-08-12 12:28:00:470] [SmartMeterWorldDiscrete Test] Resetting environment with episode 11. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-02 00:00:02'), Timestamp('2013-03-02 23:59:02'))}
# [2025-08-12 12:28:04:610] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.6791351666666667. Mean of rewards: -0.0011668764188093586. Std of rewards: 0.0010805185031611268
# [2025-08-12 12:28:04:610] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -333.7006317853229. Mean: -0.23189758984386583. Std: 0.10712427920784882
# [2025-08-12 12:28:04:610] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.679135166666667. Mean: 0.0011668764188093586. Std: 0.0010805185031611268
# [2025-08-12 12:28:04:624] [SmartMeterDiscreteEnv Test] Episode 0011 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0011_info.json
# [2025-08-12 12:28:04:627] [SmartMeterWorldDiscrete Test] Resetting environment with episode 12. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-03 00:00:03'), Timestamp('2013-03-03 23:59:03'))}
# [2025-08-12 12:28:08:747] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.27883455. Mean of rewards: -0.000888696699096595. Std of rewards: 0.0008787710787185093
# [2025-08-12 12:28:08:747] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -394.1873800670728. Mean: -0.27393146634264964. Std: 0.1024605749608565
# [2025-08-12 12:28:08:747] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2788345500000002. Mean: 0.000888696699096595. Std: 0.0008787710787185093
# [2025-08-12 12:28:08:761] [SmartMeterDiscreteEnv Test] Episode 0012 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0012_info.json
# [2025-08-12 12:28:08:764] [SmartMeterWorldDiscrete Test] Resetting environment with episode 13. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-04 00:00:01'), Timestamp('2013-03-04 23:59:01'))}
# [2025-08-12 12:28:13:353] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1840999583333334. Mean of rewards: -0.0008228630704192727. Std of rewards: 0.0008275405742236339
# [2025-08-12 12:28:13:353] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -379.7383356390055. Mean: -0.26389043477345764. Std: 0.09659128956660139
# [2025-08-12 12:28:13:353] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1840999583333334. Mean: 0.0008228630704192727. Std: 0.0008275405742236339
# [2025-08-12 12:28:13:366] [SmartMeterDiscreteEnv Test] Episode 0013 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0013_info.json
# [2025-08-12 12:28:13:369] [SmartMeterWorldDiscrete Test] Resetting environment with episode 14. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-05 00:00:00'), Timestamp('2013-03-05 23:59:00'))}
# [2025-08-12 12:28:17:970] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.06158. Mean of rewards: -0.0007377206393328702. Std of rewards: 0.0009444908580957338
# [2025-08-12 12:28:17:970] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -389.57722356682643. Mean: -0.27072774396582794. Std: 0.0996157449309237
# [2025-08-12 12:28:17:970] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0615800000000002. Mean: 0.0007377206393328702. Std: 0.0009444908580957338
# [2025-08-12 12:28:17:983] [SmartMeterDiscreteEnv Test] Episode 0014 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0014_info.json
# [2025-08-12 12:28:17:986] [SmartMeterWorldDiscrete Test] Resetting environment with episode 15. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-06 00:00:02'), Timestamp('2013-03-06 23:59:02'))}
# [2025-08-12 12:28:22:550] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.0424366333333337. Mean of rewards: -0.0014193444290016217. Std of rewards: 0.001325149485020184
# [2025-08-12 12:28:22:550] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -354.32166118733585. Mean: -0.24622770061663365. Std: 0.11834265371479692
# [2025-08-12 12:28:22:550] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.0424366333333337. Mean: 0.0014193444290016217. Std: 0.001325149485020184
# [2025-08-12 12:28:22:564] [SmartMeterDiscreteEnv Test] Episode 0015 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0015_info.json
# [2025-08-12 12:28:22:567] [SmartMeterWorldDiscrete Test] Resetting environment with episode 16. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-07 00:00:02'), Timestamp('2013-03-07 23:59:02'))}
# [2025-08-12 12:28:27:236] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1133287833333334. Mean of rewards: -0.00077368226777855. Std of rewards: 0.0006535661176329252
# [2025-08-12 12:28:27:236] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.6727800933877. Mean: -0.2673195136159748. Std: 0.1003059266431773
# [2025-08-12 12:28:27:236] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1133287833333334. Mean: 0.00077368226777855. Std: 0.0006535661176329252
# [2025-08-12 12:28:27:250] [SmartMeterDiscreteEnv Test] Episode 0016 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0016_info.json
# [2025-08-12 12:28:27:253] [SmartMeterWorldDiscrete Test] Resetting environment with episode 17. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-19 00:00:03'), Timestamp('2013-04-19 23:59:03'))}
# [2025-08-12 12:28:35:478] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.06837655. Mean of rewards: -0.000742443745656706. Std of rewards: 0.0008181832137191229
# [2025-08-12 12:28:35:479] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -362.1029362777481. Mean: -0.25163511902553726. Std: 0.09406725091221996
# [2025-08-12 12:28:35:479] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.06837655. Mean: 0.000742443745656706. Std: 0.0008181832137191229
# [2025-08-12 12:28:35:492] [SmartMeterDiscreteEnv Test] Episode 0017 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0017_info.json
# [2025-08-12 12:28:35:495] [SmartMeterWorldDiscrete Test] Resetting environment with episode 18. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-20 00:00:05'), Timestamp('2013-04-20 23:59:05'))}
# [2025-08-12 12:28:39:931] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0878363333333334. Mean of rewards: -0.0007559668751447765. Std of rewards: 0.0006900008537142227
# [2025-08-12 12:28:39:931] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -389.44968592515215. Mean: -0.2706391146109466. Std: 0.09144261940680352
# [2025-08-12 12:28:39:931] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0878363333333334. Mean: 0.0007559668751447765. Std: 0.0006900008537142227
# [2025-08-12 12:28:39:944] [SmartMeterDiscreteEnv Test] Episode 0018 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0018_info.json
# [2025-08-12 12:28:39:947] [SmartMeterWorldDiscrete Test] Resetting environment with episode 19. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-21 00:00:03'), Timestamp('2013-04-21 23:59:03'))}
# [2025-08-12 12:28:44:083] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1482238. Mean of rewards: -0.0007979317581653927. Std of rewards: 0.001076401455252227
# [2025-08-12 12:28:44:083] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.31182023719884. Mean: -0.2670686728542035. Std: 0.09689961025028732
# [2025-08-12 12:28:44:083] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1482238. Mean: 0.0007979317581653927. Std: 0.001076401455252227
# [2025-08-12 12:28:44:096] [SmartMeterDiscreteEnv Test] Episode 0019 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0019_info.json
# [2025-08-12 12:28:44:096] Episode 20/80 completed.
# [2025-08-12 12:28:44:099] [SmartMeterWorldDiscrete Test] Resetting environment with episode 20. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-22 00:00:00'), Timestamp('2013-04-22 23:59:00'))}
# [2025-08-12 12:28:48:220] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.25626225. Mean of rewards: -0.0008730105976372483. Std of rewards: 0.0009245490979880997
# [2025-08-12 12:28:48:220] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -348.2312412606552. Mean: -0.2419953031693226. Std: 0.10439830644672043
# [2025-08-12 12:28:48:220] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2562622500000002. Mean: 0.0008730105976372483. Std: 0.0009245490979880997
# [2025-08-12 12:28:48:233] [SmartMeterDiscreteEnv Test] Episode 0020 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0020_info.json
# [2025-08-12 12:28:48:237] [SmartMeterWorldDiscrete Test] Resetting environment with episode 21. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-23 00:00:05'), Timestamp('2013-04-23 23:59:05'))}
# [2025-08-12 12:28:52:335] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2103015833333335. Mean of rewards: -0.000841071287931434. Std of rewards: 0.0007650591003463031
# [2025-08-12 12:28:52:335] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -363.38322587514995. Mean: -0.2525248268764072. Std: 0.09197801321611226
# [2025-08-12 12:28:52:335] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2103015833333335. Mean: 0.000841071287931434. Std: 0.0007650591003463031
# [2025-08-12 12:28:52:348] [SmartMeterDiscreteEnv Test] Episode 0021 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0021_info.json
# [2025-08-12 12:28:52:352] [SmartMeterWorldDiscrete Test] Resetting environment with episode 22. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-24 00:00:00'), Timestamp('2013-04-24 23:59:00'))}
# [2025-08-12 12:28:56:453] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0080735. Mean of rewards: -0.0007005375260597638. Std of rewards: 0.0006082352150755101
# [2025-08-12 12:28:56:453] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -349.6076775336405. Mean: -0.24295182594415604. Std: 0.09242506152287529
# [2025-08-12 12:28:56:453] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0080735. Mean: 0.0007005375260597638. Std: 0.0006082352150755101
# [2025-08-12 12:28:56:467] [SmartMeterDiscreteEnv Test] Episode 0022 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0022_info.json
# [2025-08-12 12:28:56:470] [SmartMeterWorldDiscrete Test] Resetting environment with episode 23. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-25 00:00:03'), Timestamp('2013-04-25 23:59:03'))}
# [2025-08-12 12:29:00:572] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1881303. Mean of rewards: -0.0008256638637943016. Std of rewards: 0.0008513170140795814
# [2025-08-12 12:29:00:572] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -387.7546151477145. Mean: -0.26946116410543053. Std: 0.09484291493118518
# [2025-08-12 12:29:00:572] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1881303. Mean: 0.0008256638637943016. Std: 0.0008513170140795814
# [2025-08-12 12:29:00:585] [SmartMeterDiscreteEnv Test] Episode 0023 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0023_info.json
# [2025-08-12 12:29:00:588] [SmartMeterWorldDiscrete Test] Resetting environment with episode 24. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-18 00:00:03'), Timestamp('2013-05-18 23:59:03'))}
# [2025-08-12 12:29:04:704] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.88538645. Mean of rewards: -0.000615278978457262. Std of rewards: 0.0007089933896505463
# [2025-08-12 12:29:04:704] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -324.6644580074353. Mean: -0.2256181084137841. Std: 0.09303516005083154
# [2025-08-12 12:29:04:704] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.8853864499999999. Mean: 0.000615278978457262. Std: 0.0007089933896505463
# [2025-08-12 12:29:04:717] [SmartMeterDiscreteEnv Test] Episode 0024 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0024_info.json
# [2025-08-12 12:29:04:721] [SmartMeterWorldDiscrete Test] Resetting environment with episode 25. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-19 00:00:01'), Timestamp('2013-05-19 23:59:01'))}
# [2025-08-12 12:29:12:433] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0963077666666667. Mean of rewards: -0.0007618539031735003. Std of rewards: 0.000740922769625153
# [2025-08-12 12:29:12:433] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -347.5265700153541. Mean: -0.24150560807182356. Std: 0.09987266620561273
# [2025-08-12 12:29:12:433] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.096307766666667. Mean: 0.0007618539031735003. Std: 0.000740922769625153
# [2025-08-12 12:29:12:446] [SmartMeterDiscreteEnv Test] Episode 0025 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0025_info.json
# [2025-08-12 12:29:12:449] [SmartMeterWorldDiscrete Test] Resetting environment with episode 26. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-20 00:00:04'), Timestamp('2013-05-20 23:59:04'))}
# [2025-08-12 12:29:16:600] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2858647833333334. Mean of rewards: -0.0008935821982858467. Std of rewards: 0.0008978569864804895
# [2025-08-12 12:29:16:600] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -347.02298464102205. Mean: -0.24115565298194722. Std: 0.11064031993775393
# [2025-08-12 12:29:16:601] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2858647833333334. Mean: 0.0008935821982858467. Std: 0.0008978569864804895
# [2025-08-12 12:29:16:614] [SmartMeterDiscreteEnv Test] Episode 0026 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0026_info.json
# [2025-08-12 12:29:16:617] [SmartMeterWorldDiscrete Test] Resetting environment with episode 27. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-21 00:00:02'), Timestamp('2013-05-21 23:59:02'))}
# [2025-08-12 12:29:20:678] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1732847833333333. Mean of rewards: -0.0008153473129488072. Std of rewards: 0.0010750282031248392
# [2025-08-12 12:29:20:678] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -297.8597202160163. Mean: -0.20699077151912182. Std: 0.08674034681435026
# [2025-08-12 12:29:20:678] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1732847833333335. Mean: 0.0008153473129488072. Std: 0.0010750282031248392
# [2025-08-12 12:29:20:691] [SmartMeterDiscreteEnv Test] Episode 0027 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0027_info.json
# [2025-08-12 12:29:20:695] [SmartMeterWorldDiscrete Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-08-12 12:29:24:829] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.1931032083333335. Mean of rewards: -0.0015240467048876535. Std of rewards: 0.0013730978109408477
# [2025-08-12 12:29:24:829] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -363.2121032164432. Mean: -0.25240590911497096. Std: 0.12182826950157614
# [2025-08-12 12:29:24:829] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.1931032083333335. Mean: 0.0015240467048876535. Std: 0.0013730978109408477
# [2025-08-12 12:29:24:843] [SmartMeterDiscreteEnv Test] Episode 0028 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0028_info.json
# [2025-08-12 12:29:24:846] [SmartMeterWorldDiscrete Test] Resetting environment with episode 29. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-23 00:00:01'), Timestamp('2013-05-23 23:59:01'))}
# [2025-08-12 12:29:28:959] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.9956964583333334. Mean of rewards: -0.0006919363852212185. Std of rewards: 0.0005396061736780032
# [2025-08-12 12:29:28:959] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -334.60409263835754. Mean: -0.23252542921359107. Std: 0.07829451364216077
# [2025-08-12 12:29:28:959] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.9956964583333334. Mean: 0.0006919363852212185. Std: 0.0005396061736780032
# [2025-08-12 12:29:28:972] [SmartMeterDiscreteEnv Test] Episode 0029 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0029_info.json
# [2025-08-12 12:29:28:972] Episode 30/80 completed.
# [2025-08-12 12:29:28:975] [SmartMeterWorldDiscrete Test] Resetting environment with episode 30. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-24 00:00:01'), Timestamp('2013-05-24 23:59:01'))}
# [2025-08-12 12:29:33:103] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.170713575. Mean of rewards: -0.000813560510771369. Std of rewards: 0.000590633926407662
# [2025-08-12 12:29:33:103] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -346.97123406548053. Mean: -0.24111969010804762. Std: 0.09276023059413714
# [2025-08-12 12:29:33:103] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.170713575. Mean: 0.000813560510771369. Std: 0.000590633926407662
# [2025-08-12 12:29:33:116] [SmartMeterDiscreteEnv Test] Episode 0030 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0030_info.json
# [2025-08-12 12:29:33:119] [SmartMeterWorldDiscrete Test] Resetting environment with episode 31. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-18 00:00:04'), Timestamp('2013-06-18 23:59:04'))}
# [2025-08-12 12:29:37:221] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2198303333333333. Mean of rewards: -0.0008476930738939079. Std of rewards: 0.0007651816741074701
# [2025-08-12 12:29:37:221] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.17633654293604. Mean: -0.26697452157257545. Std: 0.10600628519559001
# [2025-08-12 12:29:37:221] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2198303333333333. Mean: 0.0008476930738939079. Std: 0.0007651816741074701
# [2025-08-12 12:29:37:234] [SmartMeterDiscreteEnv Test] Episode 0031 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0031_info.json
# [2025-08-12 12:29:37:238] [SmartMeterWorldDiscrete Test] Resetting environment with episode 32. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-19 00:00:05'), Timestamp('2013-06-19 23:59:05'))}
# [2025-08-12 12:29:41:311] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2718858333333334. Mean of rewards: -0.0008838678480426223. Std of rewards: 0.00081005646651067
# [2025-08-12 12:29:41:311] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -327.1563631789759. Mean: -0.2273498006803168. Std: 0.11191350023388827
# [2025-08-12 12:29:41:311] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2718858333333336. Mean: 0.0008838678480426223. Std: 0.00081005646651067
# [2025-08-12 12:29:41:324] [SmartMeterDiscreteEnv Test] Episode 0032 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0032_info.json
# [2025-08-12 12:29:41:327] [SmartMeterWorldDiscrete Test] Resetting environment with episode 33. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-20 00:00:00'), Timestamp('2013-06-20 23:59:00'))}
# [2025-08-12 12:29:48:963] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.12349125. Mean of rewards: -0.0007807444405837388. Std of rewards: 0.0005995682465166752
# [2025-08-12 12:29:48:963] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -379.2144774401095. Mean: -0.2635263915497634. Std: 0.0857607558211422
# [2025-08-12 12:29:48:963] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.12349125. Mean: 0.0007807444405837388. Std: 0.0005995682465166752
# [2025-08-12 12:29:48:976] [SmartMeterDiscreteEnv Test] Episode 0033 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0033_info.json
# [2025-08-12 12:29:48:979] [SmartMeterWorldDiscrete Test] Resetting environment with episode 34. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-21 00:00:03'), Timestamp('2013-06-21 23:59:03'))}
# [2025-08-12 12:29:53:101] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.501174725. Mean of rewards: -0.0010432068971507993. Std of rewards: 0.000696961397449077
# [2025-08-12 12:29:53:101] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -362.3250111794914. Mean: -0.25178944487803434. Std: 0.09621706382975848
# [2025-08-12 12:29:53:101] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.501174725. Mean: 0.0010432068971507993. Std: 0.000696961397449077
# [2025-08-12 12:29:53:114] [SmartMeterDiscreteEnv Test] Episode 0034 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0034_info.json
# [2025-08-12 12:29:53:117] [SmartMeterWorldDiscrete Test] Resetting environment with episode 35. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-22 00:00:05'), Timestamp('2013-06-22 23:59:05'))}
# [2025-08-12 12:29:57:191] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2926133333333334. Mean of rewards: -0.0008982719481121149. Std of rewards: 0.0009415838370875922
# [2025-08-12 12:29:57:191] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -372.55592662398703. Mean: -0.2588991845892891. Std: 0.09123885528765757
# [2025-08-12 12:29:57:191] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2926133333333334. Mean: 0.0008982719481121149. Std: 0.0009415838370875922
# [2025-08-12 12:29:57:204] [SmartMeterDiscreteEnv Test] Episode 0035 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0035_info.json
# [2025-08-12 12:29:57:207] [SmartMeterWorldDiscrete Test] Resetting environment with episode 36. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-23 00:00:03'), Timestamp('2013-06-23 23:59:03'))}
# [2025-08-12 12:30:01:291] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.156684725. Mean of rewards: -0.0008038114836692148. Std of rewards: 0.0009863086624051023
# [2025-08-12 12:30:01:291] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -383.3856331342831. Mean: -0.2664250403990849. Std: 0.09745306022370219
# [2025-08-12 12:30:01:291] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.156684725. Mean: 0.0008038114836692148. Std: 0.0009863086624051023
# [2025-08-12 12:30:01:304] [SmartMeterDiscreteEnv Test] Episode 0036 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0036_info.json
# [2025-08-12 12:30:01:308] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-08-12 12:30:05:370] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1373385. Mean of rewards: -0.0007903672689367617. Std of rewards: 0.0006584671663318952
# [2025-08-12 12:30:05:371] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -378.03181755251717. Mean: -0.26270452922343096. Std: 0.0906103731145631
# [2025-08-12 12:30:05:371] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1373385. Mean: 0.0007903672689367617. Std: 0.0006584671663318952
# [2025-08-12 12:30:05:384] [SmartMeterDiscreteEnv Test] Episode 0037 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0037_info.json
# [2025-08-12 12:30:05:387] [SmartMeterWorldDiscrete Test] Resetting environment with episode 38. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-15 00:00:03'), Timestamp('2013-07-15 23:59:03'))}
# [2025-08-12 12:30:09:602] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.185424725. Mean of rewards: -0.0008237836865879083. Std of rewards: 0.0006660460195511643
# [2025-08-12 12:30:09:603] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -368.3997109896154. Mean: -0.25601091799139364. Std: 0.08433681950418563
# [2025-08-12 12:30:09:603] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.185424725. Mean: 0.0008237836865879083. Std: 0.0006660460195511643
# [2025-08-12 12:30:09:617] [SmartMeterDiscreteEnv Test] Episode 0038 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0038_info.json
# [2025-08-12 12:30:09:621] [SmartMeterWorldDiscrete Test] Resetting environment with episode 39. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-16 00:00:05'), Timestamp('2013-07-16 23:59:05'))}
# [2025-08-12 12:30:14:181] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0318879166666668. Mean of rewards: -0.0007170868079684966. Std of rewards: 0.001114997151482617
# [2025-08-12 12:30:14:182] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -349.7040800275281. Mean: -0.2430188186431745. Std: 0.10562802743048762
# [2025-08-12 12:30:14:182] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0318879166666666. Mean: 0.0007170868079684966. Std: 0.001114997151482617
# [2025-08-12 12:30:14:195] [SmartMeterDiscreteEnv Test] Episode 0039 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0039_info.json
# [2025-08-12 12:30:14:195] Episode 40/80 completed.
# [2025-08-12 12:30:14:198] [SmartMeterWorldDiscrete Test] Resetting environment with episode 40. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-17 00:00:02'), Timestamp('2013-07-17 23:59:02'))}
# [2025-08-12 12:30:22:490] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0520819166666666. Mean of rewards: -0.0007311201644660645. Std of rewards: 0.0006636836080051626
# [2025-08-12 12:30:22:490] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -329.0880153212929. Mean: -0.22869215797171155. Std: 0.09204446425272489
# [2025-08-12 12:30:22:490] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0520819166666668. Mean: 0.0007311201644660645. Std: 0.0006636836080051626
# [2025-08-12 12:30:22:503] [SmartMeterDiscreteEnv Test] Episode 0040 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0040_info.json
# [2025-08-12 12:30:22:507] [SmartMeterWorldDiscrete Test] Resetting environment with episode 41. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-18 00:00:01'), Timestamp('2013-07-18 23:59:01'))}
# [2025-08-12 12:30:26:933] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.9183825166666667. Mean of rewards: -0.0006382088371554321. Std of rewards: 0.0005631210534218832
# [2025-08-12 12:30:26:933] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -369.28512453625444. Mean: -0.25662621580003786. Std: 0.08824209226007437
# [2025-08-12 12:30:26:933] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.9183825166666668. Mean: 0.0006382088371554321. Std: 0.0005631210534218832
# [2025-08-12 12:30:26:946] [SmartMeterDiscreteEnv Test] Episode 0041 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0041_info.json
# [2025-08-12 12:30:26:949] [SmartMeterWorldDiscrete Test] Resetting environment with episode 42. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-19 00:00:05'), Timestamp('2013-07-19 23:59:05'))}
# [2025-08-12 12:30:31:473] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.9215888750000001. Mean of rewards: -0.000640437022237665. Std of rewards: 0.0005102821166768966
# [2025-08-12 12:30:31:473] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -363.1362758423202. Mean: -0.25235321462287713. Std: 0.09106451952280634
# [2025-08-12 12:30:31:473] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.921588875. Mean: 0.000640437022237665. Std: 0.0005102821166768966
# [2025-08-12 12:30:31:486] [SmartMeterDiscreteEnv Test] Episode 0042 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0042_info.json
# [2025-08-12 12:30:31:489] [SmartMeterWorldDiscrete Test] Resetting environment with episode 43. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-20 00:00:00'), Timestamp('2013-07-20 23:59:00'))}
# [2025-08-12 12:30:35:912] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.02094475. Mean of rewards: -0.0007094821056289089. Std of rewards: 0.0005506058018476535
# [2025-08-12 12:30:35:912] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -375.1665771435946. Mean: -0.2607133962081964. Std: 0.08998464791322672
# [2025-08-12 12:30:35:912] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.02094475. Mean: 0.0007094821056289089. Std: 0.0005506058018476535
# [2025-08-12 12:30:35:925] [SmartMeterDiscreteEnv Test] Episode 0043 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0043_info.json
# [2025-08-12 12:30:35:928] [SmartMeterWorldDiscrete Test] Resetting environment with episode 44. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-21 00:00:04'), Timestamp('2013-07-21 23:59:04'))}
# [2025-08-12 12:30:40:251] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2410383166666668. Mean of rewards: -0.0008624310748204773. Std of rewards: 0.0006299876634338107
# [2025-08-12 12:30:40:251] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -365.41383552132174. Mean: -0.2539359524123153. Std: 0.08209175449737151
# [2025-08-12 12:30:40:251] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2410383166666668. Mean: 0.0008624310748204773. Std: 0.0006299876634338107
# [2025-08-12 12:30:40:265] [SmartMeterDiscreteEnv Test] Episode 0044 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0044_info.json
# [2025-08-12 12:30:40:268] [SmartMeterWorldDiscrete Test] Resetting environment with episode 45. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-15 00:00:01'), Timestamp('2013-08-15 23:59:01'))}
# [2025-08-12 12:30:44:320] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.186653825. Mean of rewards: -0.0008246378214037528. Std of rewards: 0.0011987976850777937
# [2025-08-12 12:30:44:321] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -392.3570610571187. Mean: -0.27265952818423816. Std: 0.10040229256953416
# [2025-08-12 12:30:44:321] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1866538250000003. Mean: 0.0008246378214037528. Std: 0.0011987976850777937
# [2025-08-12 12:30:44:333] [SmartMeterDiscreteEnv Test] Episode 0045 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0045_info.json
# [2025-08-12 12:30:44:337] [SmartMeterWorldDiscrete Test] Resetting environment with episode 46. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-16 00:00:05'), Timestamp('2013-08-16 23:59:05'))}
# [2025-08-12 12:30:48:409] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.084027. Mean of rewards: -0.0007533196664350244. Std of rewards: 0.000868694994290424
# [2025-08-12 12:30:48:409] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -382.1922315804986. Mean: -0.2655957133985397. Std: 0.10634584063199877
# [2025-08-12 12:30:48:409] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.084027. Mean: 0.0007533196664350244. Std: 0.000868694994290424
# [2025-08-12 12:30:48:422] [SmartMeterDiscreteEnv Test] Episode 0046 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0046_info.json
# [2025-08-12 12:30:48:425] [SmartMeterWorldDiscrete Test] Resetting environment with episode 47. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-17 00:00:02'), Timestamp('2013-08-17 23:59:02'))}
# [2025-08-12 12:30:52:533] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0815669. Mean of rewards: -0.0007516100764419736. Std of rewards: 0.0006250265874533276
# [2025-08-12 12:30:52:533] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -360.97403029020643. Mean: -0.25085061173746104. Std: 0.08014779322725801
# [2025-08-12 12:30:52:533] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0815669. Mean: 0.0007516100764419736. Std: 0.0006250265874533276
# [2025-08-12 12:30:52:546] [SmartMeterDiscreteEnv Test] Episode 0047 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0047_info.json
# [2025-08-12 12:30:52:549] [SmartMeterWorldDiscrete Test] Resetting environment with episode 48. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-18 00:00:05'), Timestamp('2013-08-18 23:59:05'))}
# [2025-08-12 12:31:00:044] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.117549375. Mean of rewards: -0.0007766152710215429. Std of rewards: 0.0006538590066376577
# [2025-08-12 12:31:00:044] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -416.3610463514924. Mean: -0.28934054645690926. Std: 0.0915861395564506
# [2025-08-12 12:31:00:044] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1175493750000003. Mean: 0.0007766152710215429. Std: 0.0006538590066376577
# [2025-08-12 12:31:00:057] [SmartMeterDiscreteEnv Test] Episode 0048 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0048_info.json
# [2025-08-12 12:31:00:060] [SmartMeterWorldDiscrete Test] Resetting environment with episode 49. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-19 00:00:01'), Timestamp('2013-08-19 23:59:01'))}
# [2025-08-12 12:31:04:148] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.144671075. Mean of rewards: -0.0007954628735232802. Std of rewards: 0.0009467696949015151
# [2025-08-12 12:31:04:148] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -384.6625780930044. Mean: -0.2673124239701212. Std: 0.09457727755972635
# [2025-08-12 12:31:04:148] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1446710750000002. Mean: 0.0007954628735232802. Std: 0.0009467696949015151
# [2025-08-12 12:31:04:161] [SmartMeterDiscreteEnv Test] Episode 0049 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0049_info.json
# [2025-08-12 12:31:04:161] Episode 50/80 completed.
# [2025-08-12 12:31:04:164] [SmartMeterWorldDiscrete Test] Resetting environment with episode 50. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-20 00:00:02'), Timestamp('2013-08-20 23:59:02'))}
# [2025-08-12 12:31:08:268] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2579124000000002. Mean of rewards: -0.0008741573314801945. Std of rewards: 0.0008174105601298416
# [2025-08-12 12:31:08:268] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -382.17889729794115. Mean: -0.26558644704512935. Std: 0.09713595452312666
# [2025-08-12 12:31:08:268] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2579124. Mean: 0.0008741573314801945. Std: 0.0008174105601298416
# [2025-08-12 12:31:08:282] [SmartMeterDiscreteEnv Test] Episode 0050 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0050_info.json
# [2025-08-12 12:31:08:285] [SmartMeterWorldDiscrete Test] Resetting environment with episode 51. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-21 00:00:00'), Timestamp('2013-08-21 23:59:00'))}
# [2025-08-12 12:31:12:393] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2845545. Mean of rewards: -0.0008926716469770675. Std of rewards: 0.0008781941045816056
# [2025-08-12 12:31:12:393] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -313.96308032085653. Mean: -0.21818143177265917. Std: 0.10778090054221985
# [2025-08-12 12:31:12:393] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2845545. Mean: 0.0008926716469770675. Std: 0.0008781941045816056
# [2025-08-12 12:31:12:406] [SmartMeterDiscreteEnv Test] Episode 0051 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0051_info.json
# [2025-08-12 12:31:12:409] [SmartMeterWorldDiscrete Test] Resetting environment with episode 52. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-15 00:00:00'), Timestamp('2013-09-15 23:59:00'))}
# [2025-08-12 12:31:16:485] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.95118175. Mean of rewards: -0.0006610019110493398. Std of rewards: 0.000796728934566388
# [2025-08-12 12:31:16:486] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -380.9886271272553. Mean: -0.26475929612734905. Std: 0.0795210252520737
# [2025-08-12 12:31:16:486] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.95118175. Mean: 0.0006610019110493398. Std: 0.000796728934566388
# [2025-08-12 12:31:16:499] [SmartMeterDiscreteEnv Test] Episode 0052 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0052_info.json
# [2025-08-12 12:31:16:502] [SmartMeterWorldDiscrete Test] Resetting environment with episode 53. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-16 00:00:05'), Timestamp('2013-09-16 23:59:05'))}
# [2025-08-12 12:31:20:594] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0835795833333335. Mean of rewards: -0.0007530087444984943. Std of rewards: 0.0007661605799122183
# [2025-08-12 12:31:20:594] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -364.1442617389839. Mean: -0.25305369127101035. Std: 0.10318961427437902
# ...
# [2025-08-12 12:32:01:103] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -320.49403954617446. Mean: -0.22271997188754306. Std: 0.09786237367565412
# [2025-08-12 12:32:01:103] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1153405000000003. Mean: 0.0007750802640722727. Std: 0.0008339014988916364
# [2025-08-12 12:32:01:116] [SmartMeterDiscreteEnv Test] Episode 0062 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0062_info.json
# [2025-08-12 12:32:01:120] [SmartMeterWorldDiscrete Test] Resetting environment with episode 63. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-19 00:00:04'), Timestamp('2013-10-19 23:59:04'))}
# [2025-08-12 12:32:05:164] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.12017605. Mean of rewards: -0.0007784406184850592. Std of rewards: 0.0008129576310745912
# [2025-08-12 12:32:05:164] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -392.9680224286858. Mean: -0.2730841017572521. Std: 0.09490229194049164
# [2025-08-12 12:32:05:164] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1201760500000002. Mean: 0.0007784406184850592. Std: 0.0008129576310745912
# [2025-08-12 12:32:05:177] [SmartMeterDiscreteEnv Test] Episode 0063 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0063_info.json
# [2025-08-12 12:32:05:180] [SmartMeterWorldDiscrete Test] Resetting environment with episode 64. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-20 00:00:04'), Timestamp('2013-10-20 23:59:04'))}
# [2025-08-12 12:32:13:093] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.07649005. Mean of rewards: -0.0007480820361362057. Std of rewards: 0.0009475150977628943
# [2025-08-12 12:32:13:093] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -382.3191223856993. Mean: -0.26568389324926983. Std: 0.10025575673001129
# [2025-08-12 12:32:13:093] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.07649005. Mean: 0.0007480820361362057. Std: 0.0009475150977628943
# [2025-08-12 12:32:13:112] [SmartMeterDiscreteEnv Test] Episode 0064 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0064_info.json
# [2025-08-12 12:32:13:116] [SmartMeterWorldDiscrete Test] Resetting environment with episode 65. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-21 00:00:04'), Timestamp('2013-10-21 23:59:04'))}
# [2025-08-12 12:32:17:612] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1160093500000001. Mean of rewards: -0.0007755450660180682. Std of rewards: 0.0009599485421515325
# [2025-08-12 12:32:17:612] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -358.2215763514978. Mean: -0.24893785708929658. Std: 0.10214914594158551
# [2025-08-12 12:32:17:612] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1160093500000001. Mean: 0.0007755450660180682. Std: 0.0009599485421515325
# [2025-08-12 12:32:17:625] [SmartMeterDiscreteEnv Test] Episode 0065 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0065_info.json
# [2025-08-12 12:32:17:628] [SmartMeterWorldDiscrete Test] Resetting environment with episode 66. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-15 00:00:04'), Timestamp('2013-11-15 23:59:04'))}
# [2025-08-12 12:32:22:111] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0485510166666667. Mean of rewards: -0.0007286664466064399. Std of rewards: 0.0007355888126864501
# [2025-08-12 12:32:22:111] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -376.34409018268343. Mean: -0.2615316818503707. Std: 0.08855393926809527
# [2025-08-12 12:32:22:111] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.048551016666667. Mean: 0.0007286664466064399. Std: 0.0007355888126864501
# [2025-08-12 12:32:22:124] [SmartMeterDiscreteEnv Test] Episode 0066 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0066_info.json
# [2025-08-12 12:32:22:127] [SmartMeterWorldDiscrete Test] Resetting environment with episode 67. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-16 00:00:03'), Timestamp('2013-11-16 23:59:03'))}
# [2025-08-12 12:32:26:620] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.16262095. Mean of rewards: -0.0008079367268936763. Std of rewards: 0.0011237379200637564
# [2025-08-12 12:32:26:620] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -352.0596606936306. Mean: -0.24465577532566404. Std: 0.11222669129830615
# [2025-08-12 12:32:26:620] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1626209500000002. Mean: 0.0008079367268936763. Std: 0.0011237379200637564
# [2025-08-12 12:32:26:633] [SmartMeterDiscreteEnv Test] Episode 0067 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0067_info.json
# [2025-08-12 12:32:26:636] [SmartMeterWorldDiscrete Test] Resetting environment with episode 68. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-17 00:00:03'), Timestamp('2013-11-17 23:59:03'))}
# [2025-08-12 12:32:31:152] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.973617075. Mean of rewards: -0.0006765928248783879. Std of rewards: 0.0010344506546354144
# [2025-08-12 12:32:31:152] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -365.1173981393222. Mean: -0.2537299500620724. Std: 0.10132275182276318
# [2025-08-12 12:32:31:152] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.9736170750000002. Mean: 0.0006765928248783879. Std: 0.0010344506546354144
# [2025-08-12 12:32:31:165] [SmartMeterDiscreteEnv Test] Episode 0068 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0068_info.json
# [2025-08-12 12:32:31:169] [SmartMeterWorldDiscrete Test] Resetting environment with episode 69. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-18 00:00:04'), Timestamp('2013-11-18 23:59:04'))}
# [2025-08-12 12:32:35:637] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.2024255166666666. Mean of rewards: -0.0008355979962937224. Std of rewards: 0.0007709851110435869
# [2025-08-12 12:32:35:637] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -331.1707326496253. Mean: -0.2301394945445624. Std: 0.10004855869223428
# [2025-08-12 12:32:35:637] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.2024255166666666. Mean: 0.0008355979962937224. Std: 0.0007709851110435869
# [2025-08-12 12:32:35:651] [SmartMeterDiscreteEnv Test] Episode 0069 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0069_info.json
# [2025-08-12 12:32:35:651] Episode 70/80 completed.
# [2025-08-12 12:32:35:654] [SmartMeterWorldDiscrete Test] Resetting environment with episode 70. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-19 00:00:02'), Timestamp('2013-11-19 23:59:02'))}
# [2025-08-12 12:32:39:929] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.8690980500000001. Mean of rewards: -0.0006039597289784573. Std of rewards: 0.0006175616672883423
# [2025-08-12 12:32:39:929] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -402.15061805862933. Mean: -0.27946533569049986. Std: 0.08637576486932427
# [2025-08-12 12:32:39:929] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.8690980500000001. Mean: 0.0006039597289784573. Std: 0.0006175616672883423
# [2025-08-12 12:32:39:943] [SmartMeterDiscreteEnv Test] Episode 0070 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0070_info.json
# [2025-08-12 12:32:39:946] [SmartMeterWorldDiscrete Test] Resetting environment with episode 71. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-20 00:00:02'), Timestamp('2013-11-20 23:59:02'))}
# [2025-08-12 12:32:47:700] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0607274333333334. Mean of rewards: -0.0007371281677090571. Std of rewards: 0.0008524419202281885
# [2025-08-12 12:32:47:701] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -332.27689339383505. Mean: -0.23090819554818282. Std: 0.11142287931703672
# [2025-08-12 12:32:47:701] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0607274333333332. Mean: 0.0007371281677090571. Std: 0.0008524419202281885
# [2025-08-12 12:32:47:714] [SmartMeterDiscreteEnv Test] Episode 0071 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0071_info.json
# [2025-08-12 12:32:47:717] [SmartMeterWorldDiscrete Test] Resetting environment with episode 72. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-21 00:00:04'), Timestamp('2013-11-21 23:59:04'))}
# [2025-08-12 12:32:51:889] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0333191166666666. Mean of rewards: -0.0007180813875376419. Std of rewards: 0.000698606688939143
# [2025-08-12 12:32:51:889] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -367.38722789590247. Mean: -0.25530731611945967. Std: 0.09224343510614891
# [2025-08-12 12:32:51:889] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0333191166666666. Mean: 0.0007180813875376419. Std: 0.000698606688939143
# [2025-08-12 12:32:51:903] [SmartMeterDiscreteEnv Test] Episode 0072 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0072_info.json
# [2025-08-12 12:32:51:906] [SmartMeterWorldDiscrete Test] Resetting environment with episode 73. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-15 00:00:05'), Timestamp('2013-12-15 23:59:05'))}
# [2025-08-12 12:32:56:224] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.9091894583333333. Mean of rewards: -0.0006318203324067641. Std of rewards: 0.0006665998832089554
# [2025-08-12 12:32:56:224] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -374.72270840685815. Mean: -0.26040493982408486. Std: 0.09021312610161164
# [2025-08-12 12:32:56:224] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.9091894583333334. Mean: 0.0006318203324067641. Std: 0.0006665998832089554
# [2025-08-12 12:32:56:237] [SmartMeterDiscreteEnv Test] Episode 0073 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0073_info.json
# [2025-08-12 12:32:56:240] [SmartMeterWorldDiscrete Test] Resetting environment with episode 74. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-16 00:00:06'), Timestamp('2013-12-16 23:59:06'))}
# [2025-08-12 12:33:00:560] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1803249. Mean of rewards: -0.0008202396803335649. Std of rewards: 0.0011740413902533305
# [2025-08-12 12:33:00:560] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -367.2590683911694. Mean: -0.25521825461512815. Std: 0.10167848450850218
# [2025-08-12 12:33:00:560] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1803249. Mean: 0.0008202396803335649. Std: 0.0011740413902533305
# [2025-08-12 12:33:00:574] [SmartMeterDiscreteEnv Test] Episode 0074 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0074_info.json
# [2025-08-12 12:33:00:577] [SmartMeterWorldDiscrete Test] Resetting environment with episode 75. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-17 00:00:00'), Timestamp('2013-12-17 23:59:00'))}
# [2025-08-12 12:33:05:001] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.7281507500000001. Mean of rewards: -0.000506011640027797. Std of rewards: 0.0005677254549771386
# [2025-08-12 12:33:05:001] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -356.99317844060715. Mean: -0.2480842101741537. Std: 0.09770028338763702
# [2025-08-12 12:33:05:001] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.72815075. Mean: 0.000506011640027797. Std: 0.0005677254549771386
# [2025-08-12 12:33:05:014] [SmartMeterDiscreteEnv Test] Episode 0075 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0075_info.json
# [2025-08-12 12:33:05:017] [SmartMeterWorldDiscrete Test] Resetting environment with episode 76. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-18 00:00:01'), Timestamp('2013-12-18 23:59:01'))}
# [2025-08-12 12:33:10:081] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -0.9440314000000001. Mean of rewards: -0.0006560329395413481. Std of rewards: 0.0006913981877038419
# [2025-08-12 12:33:10:081] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -362.44681719952496. Mean: -0.2518740911740966. Std: 0.098254112748
# [2025-08-12 12:33:10:081] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 0.9440314. Mean: 0.0006560329395413481. Std: 0.0006913981877038419
# [2025-08-12 12:33:10:094] [SmartMeterDiscreteEnv Test] Episode 0076 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0076_info.json
# [2025-08-12 12:33:10:097] [SmartMeterWorldDiscrete Test] Resetting environment with episode 77. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-19 00:00:05'), Timestamp('2013-12-19 23:59:05'))}
# [2025-08-12 12:33:14:699] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.0742487916666668. Mean of rewards: -0.0007465245251331945. Std of rewards: 0.000837671112066105
# [2025-08-12 12:33:14:699] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -315.5276908328524. Mean: -0.21926872191303154. Std: 0.11170479658493261
# [2025-08-12 12:33:14:699] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.0742487916666668. Mean: 0.0007465245251331945. Std: 0.000837671112066105
# [2025-08-12 12:33:14:712] [SmartMeterDiscreteEnv Test] Episode 0077 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0077_info.json
# [2025-08-12 12:33:14:716] [SmartMeterWorldDiscrete Test] Resetting environment with episode 78. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-20 00:00:02'), Timestamp('2013-12-20 23:59:02'))}
# [2025-08-12 12:33:22:900] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.1446276333333334. Mean of rewards: -0.0007954326847347695. Std of rewards: 0.00100590394223818
# [2025-08-12 12:33:22:900] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -332.2375051337294. Mean: -0.2308808235814659. Std: 0.11782882237401933
# [2025-08-12 12:33:22:900] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.1446276333333334. Mean: 0.0007954326847347695. Std: 0.00100590394223818
# [2025-08-12 12:33:22:913] [SmartMeterDiscreteEnv Test] Episode 0078 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0078_info.json
# [2025-08-12 12:33:22:917] [SmartMeterWorldDiscrete Test] Resetting environment with episode 79. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-21 00:00:01'), Timestamp('2013-12-21 23:59:01'))}
# [2025-08-12 12:33:27:538] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.10016015. Mean of rewards: -0.0007645310284920084. Std of rewards: 0.001091857145027397
# [2025-08-12 12:33:27:538] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -363.05955546651967. Mean: -0.2522998995597774. Std: 0.10925363287007808
# [2025-08-12 12:33:27:538] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.10016015. Mean: 0.0007645310284920084. Std: 0.001091857145027397
# [2025-08-12 12:33:27:551] [SmartMeterDiscreteEnv Test] Episode 0079 info saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/episode_info/episode_0079_info.json
# [2025-08-12 12:33:27:551] Episode 80/80 completed.
# [2025-08-12 12:33:27:553] Validation results saved to experiments/20250807_110534_action_discrete_reward_lambda_1.0/logs_test/test_stats_file.json
