# %% [markdown]
# # Model Evaluation
#
# This notebook is used to evaluate a trained RL model, which is trained after some number of training iterations, on the unseen testing dataset.
#
# This script is for evaluating trained DDQN-MI models.

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from datetime import datetime
import sys

from utils import print_log

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load the created dataset
dataset_folder_path = Path("dataset", "20250707_downsampled_1min", "split")

# %%
from utils_data_split import load_split_data_from_folder, convert_to_naive_datetimes, convert_to_naive_datetimes_df

# %%
aggregate_load_segments_test, aggregate_load_df_test = load_split_data_from_folder(dataset_folder_path, 'test')

# %%
aggregate_load_segments_test, aggregate_load_df_test = convert_to_naive_datetimes(aggregate_load_segments_test), convert_to_naive_datetimes_df(aggregate_load_df_test)

# %% [markdown]
# ---

# %% [markdown]
# (DDQN) only
#
# We have to quantize the data into per 0.05kW = 50W. This is for the charging action and other stuffs

# %%
# https://stackoverflow.com/questions/47949053/round-to-nearest-1000-in-pandas

def round_to_nearest_50(x):
    """Round to the nearest 50"""
    return ((x + 25) / 50).astype(int) * 50


aggregate_load_df_test["aggregate"] = round_to_nearest_50(aggregate_load_df_test["aggregate"])

# then cap at 5kW
aggregate_load_df_test["aggregate"] = aggregate_load_df_test["aggregate"].clip(upper=5000)

# %% [markdown]
# ---

# %% [markdown]
# Experiment start

# %%
# initialize experiment folder to store related information/data for future analysis

# Change the datetime to point to the correct folder
# rl_datetime = datetime(2025, 8, 13, 23, 23, 31)     # 0.0
# rl_datetime = datetime(2025, 8, 14, 2, 5, 26)     # 0.5
rl_datetime = datetime(2025, 8, 14, 4, 46, 19)    # 1.0

# Keep the action type un-changed
ACTION_TYPE = "discrete"

# Change the lambda according to your experiment
REWARD_LAMBDA = 1.0  # between 0 and 1

experiment_folder = Path(
    "experiments", rl_datetime.strftime('%Y%m%d_%H%M%S') + f"_action_{ACTION_TYPE}_reward_lambda_{REWARD_LAMBDA:.1f}", 
)

if not experiment_folder.exists():
    raise FileNotFoundError(f"Experiment folder {experiment_folder} does not exist. Please check the path.")

# %%
# find the selected checkpoint

selected_ckpt_folder = experiment_folder / "selected_ckpt"

# search for any sub-folders under selected_ckpt_folder
sub_folders = [f for f in selected_ckpt_folder.iterdir() if f.is_dir()]
# assert len(sub_folders) == 1, "There should be exactly one sub-folder in selected_ckpt_folder."

# search for the first folder. Add sorted() to the sub_folders can find the smallest num of iteration checkpoint.
selected_ckpt_folder = sub_folders[0]
selected_ckpt_episode_number = int(selected_ckpt_folder.name.split('_')[-1])

print_log(f"Selected checkpoint folder: {selected_ckpt_folder}")
# Out:
# [2025-09-23 14:14:56:219] Selected checkpoint folder: experiments/20250814_044619_action_discrete_reward_lambda_1.0/selected_ckpt/episode_0600

# %% [markdown]
# TODO: read the experiment_details under the experiment_folder, find the seed element, and use it to set the action_space and RL model for reproducibility

# %% [markdown]
# Create data loader

# %%
sys.path.append(str(Path('rl_env')))
sys.path.append(str(Path('model', 'H_network')))

from rl_env.data_loader import SimpleSmartMeterDataLoader

sm_dl_test = SimpleSmartMeterDataLoader(
    aggregate_load_segments=aggregate_load_segments_test,
    aggregate_load_df=aggregate_load_df_test,
    registry_path=experiment_folder / "simple_episode_registry_test.json"
)

sm_dl_test.get_divided_segments_length()
# Out:
# [SimpleDataLoader] Generated 80 episodes (1 day each)
# 80

# %%
sm_dl_test.divided_segments[7]
# Out:
# array([datetime.datetime(2013, 2, 15, 0, 0),
#        datetime.datetime(2013, 2, 15, 23, 59, 59, 999000)], dtype=object)

# %%
# sample segment

sm_dl_test.get_aggregate_load_segment(13)
# Out:
#         timestamp  aggregate            datetime  segment_index  \
# 18720  1362355201        150 2013-03-04 00:00:01             13
# 18721  1362355261        150 2013-03-04 00:01:01             13
# 18722  1362355321        150 2013-03-04 00:02:01             13
# 18723  1362355381        150 2013-03-04 00:03:01             13
# 18724  1362355441        150 2013-03-04 00:04:01             13
# ...           ...        ...                 ...            ...
# 20155  1362441301        250 2013-03-04 23:55:01             13
# 20156  1362441361        250 2013-03-04 23:56:01             13
# 20157  1362441421        300 2013-03-04 23:57:01             13
# 20158  1362441481        300 2013-03-04 23:58:01             13
# 20159  1362441541        300 2013-03-04 23:59:01             13
#
#       episode_content_id  episode_length_days
# 18720       9eafa9c7f9a1                    1
# 18721       9eafa9c7f9a1                    1
# 18722       9eafa9c7f9a1                    1
# 18723       9eafa9c7f9a1                    1
# 18724       9eafa9c7f9a1                    1
# ...                  ...                  ...
# 20155       9eafa9c7f9a1                    1
# 20156       9eafa9c7f9a1                    1
# 20157       9eafa9c7f9a1                    1
# 20158       9eafa9c7f9a1                    1
# 20159       9eafa9c7f9a1                    1
#
# [1440 rows x 6 columns]

# %% [markdown]
# Create the environment

# %%
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from model.H_network.common.factories import create_h_network_module_with_defaults
from model.H_network.h_network_arch import HNetworkType

# the optimizer kwargs does not matter for the testing loop, but they are required to create the module

h_network_kwargs = {
    "h_network_type": HNetworkType.H_NETWORK,
    "optimizer_class": torch.optim.RMSprop,
    "optimizer_kwargs": {"lr": 0.001},
}

h_network_rl_module = create_h_network_module_with_defaults(
    action_type=ACTION_TYPE,
    **h_network_kwargs,
    device=DEVICE
)

# %%
from rl_env.base.env_module import SmartMeterEnvFactory
from rl_env.training_mode import TrainingMode
from decimal import Decimal

env_test = SmartMeterEnvFactory.create(
    action_type=ACTION_TYPE,
    smart_meter_data_loader=sm_dl_test,
    h_network_rl_module=h_network_rl_module,
    mode=TrainingMode.TEST,
    reward_lambda=REWARD_LAMBDA,
    render_mode=None,

    aggregate_step_size=50,  # step size for the aggregate load
    battery_step_size=Decimal("0.05")
)
# Out:
# [2025-09-23 14:14:57:548] [SmartMeterDiscreteEnv Test] Using data loader: SimpleSmartMeterDataLoader
# [2025-09-23 14:14:57:548] [SmartMeterDiscreteEnv Test] Curriculum enabled: False
# [2025-09-23 14:14:57:554] [SmartMeterDiscreteEnv Test]] Render mode set to 'None'. Render server at 127.0.0.1:50007. render_connected: False. render_client_socket: None

# %%
h_network_rl_module.set_h_network(
    h_network_rl_module.initialize_h_network(output_dim=env_test.num_aggregate_bins)  # output_dim is the number states in the aggregate load space
)
h_network_rl_module.initialize_h_network_training()

# %%
# load the h_network from the selected checkpoint

h_network_rl_module.load_h_network(
    selected_ckpt_folder / ("h_network" + f"_{selected_ckpt_episode_number:04d}" + ".pth")
)

# %%
h_network_rl_module.h_network
# Out:
# HNetwork(
#   (LSTM_1): LSTM(2, 44, batch_first=True, bidirectional=True)
#   (ac1): Tanh()
#   (LSTM_2): LSTM(88, 44, batch_first=True, bidirectional=True)
#   (ac2): Tanh()
#   (fc): Linear(in_features=88, out_features=101, bias=True)
# )

# %%
import torchinfo


torchinfo.summary(h_network_rl_module.h_network, input_size=(1, 1, 2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HNetwork                                 [1, 1, 101]               --
# ├─LSTM: 1-1                              [1, 1, 88]                16,896
# ├─Tanh: 1-2                              [1, 1, 88]                --
# ├─LSTM: 1-3                              [1, 1, 88]                47,168
# ├─Tanh: 1-4                              [1, 1, 88]                --
# ├─Linear: 1-5                            [1, 1, 101]               8,989
# ==========================================================================================
# Total params: 73,053
# Trainable params: 73,053
# Non-trainable params: 0
# Total mult-adds (M): 0.07
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.29
# Estimated Total Size (MB): 0.29
# ==========================================================================================

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env_test)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# [2025-09-23 14:14:58:369] [SmartMeterWorldDiscrete Test] Resetting environment with episode 45. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-15 00:00:01'), Timestamp('2013-08-15 23:59:01'))}
# [2025-09-23 14:14:58:373] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:14:58:375] [SmartMeterWorldDiscrete Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-09-23 14:14:58:378] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:14:58:381] [SmartMeterWorldDiscrete Test] Resetting environment with episode 54. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-17 00:00:02'), Timestamp('2013-09-17 23:59:02'))}
# [2025-09-23 14:14:58:385] [SmartMeterWorldDiscrete Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-09-23 14:14:58:389] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:14:58:392] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:14:58:457] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:14:58:464] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# Environment passes all checks!
# /root/miniforge3/envs/smartmeter/lib/python3.9/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %%
env_test.reset_render_window()

# %% [markdown]
# Also initiate a validation environment for time-to-time validation

# %%
# callbacks for training - using refactored callback system
from rl_env.env_callbacks import TrainHNetworkEveryNEpisodes, SaveCheckpointEveryNEpisodes, ValidateEveryNEpisodes, EnvLoggingCallback, UpdateGlobalTimestepCallback
# Out:
# 2025-09-23 14:14:58.749224: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 14:14:58.758491: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758608098.767963   93408 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758608098.771455   93408 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758608098.780783   93408 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608098.780803   93408 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608098.780804   93408 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758608098.780804   93408 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-23 14:14:58.783896: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# initialize a DQN agent
from model.DDQN.ddqn import DoubleDQN

rl_model = DoubleDQN.load(
    selected_ckpt_folder / ("rl_model" + f"_{selected_ckpt_episode_number:04d}"),  # path to the saved RL model
    env=env_test
)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
rl_model.buffer_size
# Out:
# 150000

# %%
rl_model.policy
# Out:
# MultiInputPolicy(
#   (q_net): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (aggregate_load): Flatten(start_dim=1, end_dim=-1)
#         (battery_soc): Flatten(start_dim=1, end_dim=-1)
#         (timestamp_features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=161, bias=True)
#     )
#   )
# )

# %%
log_folder = experiment_folder / "logs_test" / selected_ckpt_folder.name
if not log_folder.exists():
    log_folder.mkdir(parents=True)

# %%
# we test the rl model and H-network

import json
from utils import print_log

total_episodes = env_test.smart_meter_data_loader.get_divided_segments_length()
episode_indices = list(range(total_episodes))

all_episode_rewards = []
all_episode_lengths = []
all_episode_infos = []
per_episode_reward_stats = []

for i, episode_idx in enumerate(episode_indices):
    obs, info = env_test.reset(episode_idx=episode_idx)

    # Initialize episode tracking variables
    episode_reward = 0.0
    episode_length = 0
    done = False
    state = None  # For recurrent policies

    while not done:
        # Get action from the RL model
        action, state = rl_model.predict(obs, state=state, deterministic=True)

        # Step the environment
        obs, reward, done, truncated, info = env_test.step(action)

        # Update episode tracking variables
        episode_reward += reward
        episode_length += 1

    # Store results for this episode
    all_episode_rewards.append(episode_reward)
    all_episode_lengths.append(episode_length)
    all_episode_infos.append({
        "episode_idx": episode_idx,
        "episode_info": env_test.episode.get_episode_info() if hasattr(env_test, 'episode') else {}
    })

    per_episode_reward_stats.append(env_test.prev_episode_reward_stats)

    env_test.save_episode_info(
        log_folder=log_folder,
        episode_training_idx=episode_idx
    )

    if (i + 1) % 10 == 0:
        print_log(f"Episode {i + 1}/{total_episodes} completed.")


# Calculate comprehensive statistics
mean_reward = np.mean(all_episode_rewards)
std_reward = np.std(all_episode_rewards)
min_reward = np.min(all_episode_rewards)
max_reward = np.max(all_episode_rewards)
median_reward = np.median(all_episode_rewards)

# we need to recover the true sum f_signal and g_signal from the per_episode_reward_stats, with length of each episode
f_signal_sums = np.array([item['f_signal_sum'] for item in per_episode_reward_stats])
g_signal_sums = np.array([item['g_signal_sum'] for item in per_episode_reward_stats])

# get the length of each episode
_episode_lengths = np.array(all_episode_lengths)
sum_episode_lengths = np.sum(_episode_lengths)

# calculate the (true) mean of rewards, f_signal and g_signal

f_signal_mean = f_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0
g_signal_mean = g_signal_sums @ _episode_lengths / sum_episode_lengths if sum_episode_lengths > 0 else 0.0

mean_length = np.mean(all_episode_lengths)
std_length = np.std(all_episode_lengths)

# Prepare validation data
test_data = {
    'evaluated_episodes': len(episode_indices),
    'total_available_episodes': total_episodes,
    'episode_indices': episode_indices,
    'episode_rewards': all_episode_rewards,
    'episode_lengths': all_episode_lengths,
    'episode_infos': all_episode_infos,
    'summary_stats': {
        'mean_reward': mean_reward,
        'std_reward': std_reward,
        'min_reward': min_reward,
        'max_reward': max_reward,
        'median_reward': median_reward,
        'mean_f_signal': f_signal_mean,
        'mean_g_signal': g_signal_mean,
        'mean_length': mean_length,
        'std_length': std_length
    }
}

test_stats_file_path = log_folder / "test_stats_file.json"
with open(test_stats_file_path, 'w') as f:
    # Convert numpy types to Python native types for JSON serialization
    def convert_numpy(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, list):
            return [convert_numpy(item) for item in obj]
        elif isinstance(obj, dict):
            return {key: convert_numpy(value) for key, value in obj.items()}
        return obj

    json.dump(convert_numpy(test_data), f, indent=2, default=str)

sm_dl_test._save_registry()
print_log(f"Validation results saved to {test_stats_file_path}")
# Out:
# [2025-09-23 14:14:59:927] [SmartMeterWorldDiscrete Test] Resetting environment with episode 0. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-01 00:00:01'), Timestamp('2013-01-01 23:59:01'))}
# [2025-09-23 14:15:05:585] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.0339432083333335. Mean of rewards: -0.0028032961836923793. Std of rewards: 0.004578196371896104
# [2025-09-23 14:15:05:585] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -260.08277436951175. Mean: -0.18073855063899358. Std: 0.10664498869337037
# [2025-09-23 14:15:05:585] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.0339432083333335. Mean: 0.0028032961836923793. Std: 0.004578196371896104
# [2025-09-23 14:15:05:607] [SmartMeterDiscreteEnv Test] Episode 0000 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0000_info.json
# [2025-09-23 14:15:05:611] [SmartMeterWorldDiscrete Test] Resetting environment with episode 1. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-02 00:00:26'), Timestamp('2013-01-02 23:59:26'))}
# [2025-09-23 14:15:10:555] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.9353037833333335. Mean of rewards: -0.0027347489807736853. Std of rewards: 0.0043067546632820945
# [2025-09-23 14:15:10:555] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -233.7608216505032. Mean: -0.1624467141421148. Std: 0.10980643934867247
# [2025-09-23 14:15:10:555] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.935303783333333. Mean: 0.0027347489807736853. Std: 0.0043067546632820945
# [2025-09-23 14:15:10:571] [SmartMeterDiscreteEnv Test] Episode 0001 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0001_info.json
# [2025-09-23 14:15:10:575] [SmartMeterWorldDiscrete Test] Resetting environment with episode 2. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-03 00:00:00'), Timestamp('2013-01-03 23:59:00'))}
# [2025-09-23 14:15:15:205] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.8559295. Mean of rewards: -0.003374516678248784. Std of rewards: 0.0044879481376427196
# [2025-09-23 14:15:15:205] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -151.87041872018017. Mean: -0.10553885943028504. Std: 0.08014184930452765
# [2025-09-23 14:15:15:205] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.8559295. Mean: 0.003374516678248784. Std: 0.0044879481376427196
# [2025-09-23 14:15:15:221] [SmartMeterDiscreteEnv Test] Episode 0002 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0002_info.json
# [2025-09-23 14:15:15:224] [SmartMeterWorldDiscrete Test] Resetting environment with episode 3. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-04 00:00:05'), Timestamp('2013-01-04 23:59:05'))}
# [2025-09-23 14:15:19:861] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.33496475. Mean of rewards: -0.003012484190410007. Std of rewards: 0.0041237285734430605
# [2025-09-23 14:15:19:861] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -215.4663605906535. Mean: -0.14973339860365079. Std: 0.11972695311379376
# [2025-09-23 14:15:19:861] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.33496475. Mean: 0.003012484190410007. Std: 0.0041237285734430605
# [2025-09-23 14:15:19:877] [SmartMeterDiscreteEnv Test] Episode 0003 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0003_info.json
# [2025-09-23 14:15:19:881] [SmartMeterWorldDiscrete Test] Resetting environment with episode 4. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-05 00:00:04'), Timestamp('2013-01-05 23:59:04'))}
# [2025-09-23 14:15:24:533] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -5.36664375. Mean of rewards: -0.003729425816539263. Std of rewards: 0.004519934601369317
# [2025-09-23 14:15:24:533] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -203.30726713733748. Mean: -0.14128371587028316. Std: 0.1391692195526338
# [2025-09-23 14:15:24:533] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 5.36664375. Mean: 0.003729425816539263. Std: 0.004519934601369317
# [2025-09-23 14:15:24:549] [SmartMeterDiscreteEnv Test] Episode 0004 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0004_info.json
# [2025-09-23 14:15:24:553] [SmartMeterWorldDiscrete Test] Resetting environment with episode 5. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-01-06 00:00:01'), Timestamp('2013-01-06 23:59:01'))}
# [2025-09-23 14:15:29:196] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -5.1813987500000005. Mean of rewards: -0.0036006940583738706. Std of rewards: 0.003969368612455562
# [2025-09-23 14:15:29:196] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -192.13959907740355. Mean: -0.13352300144364387. Std: 0.1215053424008794
# [2025-09-23 14:15:29:196] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 5.18139875. Mean: 0.0036006940583738706. Std: 0.003969368612455562
# [2025-09-23 14:15:29:212] [SmartMeterDiscreteEnv Test] Episode 0005 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0005_info.json
# [2025-09-23 14:15:29:216] [SmartMeterWorldDiscrete Test] Resetting environment with episode 6. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-14 00:00:03'), Timestamp('2013-02-14 23:59:03'))}
# [2025-09-23 14:15:33:826] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.363026475. Mean of rewards: -0.002337058009034051. Std of rewards: 0.003833652116583789
# [2025-09-23 14:15:33:826] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -319.6232967134565. Mean: -0.22211486915459105. Std: 0.10847062896539375
# [2025-09-23 14:15:33:826] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.363026475. Mean: 0.002337058009034051. Std: 0.003833652116583789
# [2025-09-23 14:15:33:843] [SmartMeterDiscreteEnv Test] Episode 0006 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0006_info.json
# [2025-09-23 14:15:33:847] [SmartMeterWorldDiscrete Test] Resetting environment with episode 7. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-15 00:00:00'), Timestamp('2013-02-15 23:59:00'))}
# [2025-09-23 14:15:39:103] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.90713. Mean of rewards: -0.003410097289784573. Std of rewards: 0.004175915278220894
# [2025-09-23 14:15:39:103] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -188.2743063014932. Mean: -0.1308369050045123. Std: 0.10135518411608346
# [2025-09-23 14:15:39:103] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.90713. Mean: 0.003410097289784573. Std: 0.004175915278220894
# [2025-09-23 14:15:39:120] [SmartMeterDiscreteEnv Test] Episode 0007 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0007_info.json
# [2025-09-23 14:15:39:125] [SmartMeterWorldDiscrete Test] Resetting environment with episode 8. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-16 00:00:02'), Timestamp('2013-02-16 23:59:02'))}
# [2025-09-23 14:15:43:871] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.183682933333333. Mean of rewards: -0.0029073543664581885. Std of rewards: 0.003749985877336654
# [2025-09-23 14:15:43:871] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -234.7420970746316. Mean: -0.16312862896082808. Std: 0.11870758557305243
# [2025-09-23 14:15:43:871] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.183682933333333. Mean: 0.0029073543664581885. Std: 0.003749985877336654
# [2025-09-23 14:15:43:886] [SmartMeterDiscreteEnv Test] Episode 0008 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0008_info.json
# [2025-09-23 14:15:43:890] [SmartMeterWorldDiscrete Test] Resetting environment with episode 9. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-02-17 00:00:01'), Timestamp('2013-02-17 23:59:01'))}
# [2025-09-23 14:15:48:624] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.7048092500000003. Mean of rewards: -0.002574572098679639. Std of rewards: 0.0028806004108433442
# [2025-09-23 14:15:48:624] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -252.20367555157281. Mean: -0.17526315187739597. Std: 0.13236667181720482
# [2025-09-23 14:15:48:624] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.7048092500000003. Mean: 0.002574572098679639. Std: 0.0028806004108433442
# [2025-09-23 14:15:48:640] [SmartMeterDiscreteEnv Test] Episode 0009 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0009_info.json
# [2025-09-23 14:15:48:640] Episode 10/80 completed.
# [2025-09-23 14:15:48:644] [SmartMeterWorldDiscrete Test] Resetting environment with episode 10. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-01 00:00:00'), Timestamp('2013-03-01 23:59:00'))}
# [2025-09-23 14:15:53:553] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.22754425. Mean of rewards: -0.0029378347810979843. Std of rewards: 0.004140193910118463
# [2025-09-23 14:15:53:553] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -275.03700969321653. Mean: -0.19113065301821858. Std: 0.1301366335344874
# [2025-09-23 14:15:53:553] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.227544249999999. Mean: 0.0029378347810979843. Std: 0.004140193910118463
# [2025-09-23 14:15:53:569] [SmartMeterDiscreteEnv Test] Episode 0010 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0010_info.json
# [2025-09-23 14:15:53:573] [SmartMeterWorldDiscrete Test] Resetting environment with episode 11. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-02 00:00:02'), Timestamp('2013-03-02 23:59:02'))}
# [2025-09-23 14:15:58:495] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.1593695. Mean of rewards: -0.0028904583043780404. Std of rewards: 0.003853521790740489
# [2025-09-23 14:15:58:496] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -256.06665103998967. Mean: -0.17794763797080587. Std: 0.1332147159079177
# [2025-09-23 14:15:58:496] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.1593695. Mean: 0.0028904583043780404. Std: 0.003853521790740489
# [2025-09-23 14:15:58:512] [SmartMeterDiscreteEnv Test] Episode 0011 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0011_info.json
# [2025-09-23 14:15:58:516] [SmartMeterWorldDiscrete Test] Resetting environment with episode 12. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-03 00:00:03'), Timestamp('2013-03-03 23:59:03'))}
# [2025-09-23 14:16:03:812] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.4521900000000003. Mean of rewards: -0.0023990201528839477. Std of rewards: 0.0030223490895701557
# [2025-09-23 14:16:03:812] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -346.17950208694674. Mean: -0.24056949415354187. Std: 0.13475647427438484
# [2025-09-23 14:16:03:812] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.4521900000000008. Mean: 0.0023990201528839477. Std: 0.0030223490895701557
# [2025-09-23 14:16:03:829] [SmartMeterDiscreteEnv Test] Episode 0012 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0012_info.json
# [2025-09-23 14:16:03:833] [SmartMeterWorldDiscrete Test] Resetting environment with episode 13. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-04 00:00:01'), Timestamp('2013-03-04 23:59:01'))}
# [2025-09-23 14:16:09:225] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.158088458333333. Mean of rewards: -0.0028895680738939083. Std of rewards: 0.0045470852333106505
# [2025-09-23 14:16:09:225] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -345.70664296182804. Mean: -0.24024089156485617. Std: 0.12281633092503143
# [2025-09-23 14:16:09:225] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.158088458333334. Mean: 0.0028895680738939083. Std: 0.0045470852333106505
# [2025-09-23 14:16:09:241] [SmartMeterDiscreteEnv Test] Episode 0013 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0013_info.json
# [2025-09-23 14:16:09:244] [SmartMeterWorldDiscrete Test] Resetting environment with episode 14. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-05 00:00:00'), Timestamp('2013-03-05 23:59:00'))}
# [2025-09-23 14:16:14:040] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.2682455. Mean of rewards: -0.002966119179986102. Std of rewards: 0.004616383489384702
# [2025-09-23 14:16:14:040] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -299.0997167848982. Mean: -0.20785247865524545. Std: 0.13155417299668096
# [2025-09-23 14:16:14:040] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.268245500000001. Mean: 0.002966119179986102. Std: 0.004616383489384702
# [2025-09-23 14:16:14:056] [SmartMeterDiscreteEnv Test] Episode 0014 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0014_info.json
# [2025-09-23 14:16:14:060] [SmartMeterWorldDiscrete Test] Resetting environment with episode 15. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-06 00:00:02'), Timestamp('2013-03-06 23:59:02'))}
# [2025-09-23 14:16:18:732] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.64828215. Mean of rewards: -0.002535289888811675. Std of rewards: 0.004621045942922294
# [2025-09-23 14:16:18:732] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -296.90258650667965. Mean: -0.20632563343063215. Std: 0.10693836590319365
# [2025-09-23 14:16:18:732] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.64828215. Mean: 0.002535289888811675. Std: 0.004621045942922294
# [2025-09-23 14:16:18:748] [SmartMeterDiscreteEnv Test] Episode 0015 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0015_info.json
# [2025-09-23 14:16:18:752] [SmartMeterWorldDiscrete Test] Resetting environment with episode 16. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-03-07 00:00:02'), Timestamp('2013-03-07 23:59:02'))}
# [2025-09-23 14:16:23:490] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.8086657. Mean of rewards: -0.0026467447533009033. Std of rewards: 0.004169217039018465
# [2025-09-23 14:16:23:491] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -284.0866096201353. Mean: -0.19741946464220658. Std: 0.11803618530138292
# [2025-09-23 14:16:23:491] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.8086656999999997. Mean: 0.0026467447533009033. Std: 0.004169217039018465
# [2025-09-23 14:16:23:507] [SmartMeterDiscreteEnv Test] Episode 0016 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0016_info.json
# [2025-09-23 14:16:23:510] [SmartMeterWorldDiscrete Test] Resetting environment with episode 17. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-19 00:00:03'), Timestamp('2013-04-19 23:59:03'))}
# [2025-09-23 14:16:28:256] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.17530005. Mean of rewards: -0.002901528874218207. Std of rewards: 0.004254642163674374
# [2025-09-23 14:16:28:256] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -252.3124880300602. Mean: -0.17533876861018777. Std: 0.12195666835115254
# [2025-09-23 14:16:28:256] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.17530005. Mean: 0.002901528874218207. Std: 0.004254642163674374
# [2025-09-23 14:16:28:272] [SmartMeterDiscreteEnv Test] Episode 0017 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0017_info.json
# [2025-09-23 14:16:28:276] [SmartMeterWorldDiscrete Test] Resetting environment with episode 18. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-20 00:00:05'), Timestamp('2013-04-20 23:59:05'))}
# [2025-09-23 14:16:33:015] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.6114497500000002. Mean of rewards: -0.002509694058373871. Std of rewards: 0.003562750861740059
# [2025-09-23 14:16:33:015] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -304.1788162961602. Mean: -0.2113820822071996. Std: 0.13223950615771024
# [2025-09-23 14:16:33:015] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.6114497500000002. Mean: 0.002509694058373871. Std: 0.003562750861740059
# [2025-09-23 14:16:33:031] [SmartMeterDiscreteEnv Test] Episode 0018 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0018_info.json
# [2025-09-23 14:16:33:035] [SmartMeterWorldDiscrete Test] Resetting environment with episode 19. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-21 00:00:03'), Timestamp('2013-04-21 23:59:03'))}
# [2025-09-23 14:16:37:761] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.05383025. Mean of rewards: -0.0028171162265462125. Std of rewards: 0.0038735554945537433
# [2025-09-23 14:16:37:761] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -292.94241221854463. Mean: -0.20357360126375582. Std: 0.1364306729932302
# [2025-09-23 14:16:37:761] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.05383025. Mean: 0.0028171162265462125. Std: 0.0038735554945537433
# [2025-09-23 14:16:37:776] [SmartMeterDiscreteEnv Test] Episode 0019 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0019_info.json
# [2025-09-23 14:16:37:776] Episode 20/80 completed.
# [2025-09-23 14:16:37:780] [SmartMeterWorldDiscrete Test] Resetting environment with episode 20. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-22 00:00:00'), Timestamp('2013-04-22 23:59:00'))}
# [2025-09-23 14:16:43:080] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -5.248521. Mean of rewards: -0.003647339124391939. Std of rewards: 0.004941199252034115
# [2025-09-23 14:16:43:080] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -245.9313883667346. Mean: -0.17090436995603517. Std: 0.11781240061806833
# [2025-09-23 14:16:43:080] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 5.248521. Mean: 0.003647339124391939. Std: 0.004941199252034115
# [2025-09-23 14:16:43:097] [SmartMeterDiscreteEnv Test] Episode 0020 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0020_info.json
# [2025-09-23 14:16:43:100] [SmartMeterWorldDiscrete Test] Resetting environment with episode 21. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-23 00:00:05'), Timestamp('2013-04-23 23:59:05'))}
# [2025-09-23 14:16:47:837] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.8257297083333333. Mean of rewards: -0.002658602993977299. Std of rewards: 0.004118375028121505
# [2025-09-23 14:16:47:837] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -311.23202172876336. Mean: -0.21628354532923097. Std: 0.1214192536390392
# [2025-09-23 14:16:47:837] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.8257297083333333. Mean: 0.002658602993977299. Std: 0.004118375028121505
# [2025-09-23 14:16:47:852] [SmartMeterDiscreteEnv Test] Episode 0021 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0021_info.json
# [2025-09-23 14:16:47:856] [SmartMeterWorldDiscrete Test] Resetting environment with episode 22. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-24 00:00:00'), Timestamp('2013-04-24 23:59:00'))}
# [2025-09-23 14:16:52:596] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.412841. Mean of rewards: -0.003066602501737318. Std of rewards: 0.004710333769420222
# [2025-09-23 14:16:52:596] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -211.34697399835568. Mean: -0.1468707255026794. Std: 0.10630342635633647
# [2025-09-23 14:16:52:596] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.412841. Mean: 0.003066602501737318. Std: 0.004710333769420222
# [2025-09-23 14:16:52:613] [SmartMeterDiscreteEnv Test] Episode 0022 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0022_info.json
# [2025-09-23 14:16:52:617] [SmartMeterWorldDiscrete Test] Resetting environment with episode 23. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-04-25 00:00:03'), Timestamp('2013-04-25 23:59:03'))}
# [2025-09-23 14:16:57:267] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.3602763. Mean of rewards: -0.002335146838082001. Std of rewards: 0.004621294750775996
# [2025-09-23 14:16:57:267] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -296.06000486249104. Mean: -0.20574010066886103. Std: 0.10353567116846046
# [2025-09-23 14:16:57:267] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.3602762999999998. Mean: 0.002335146838082001. Std: 0.004621294750775996
# [2025-09-23 14:16:57:283] [SmartMeterDiscreteEnv Test] Episode 0023 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0023_info.json
# [2025-09-23 14:16:57:287] [SmartMeterWorldDiscrete Test] Resetting environment with episode 24. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-18 00:00:03'), Timestamp('2013-05-18 23:59:03'))}
# [2025-09-23 14:17:01:997] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.79207105. Mean of rewards: -0.001245358617095205. Std of rewards: 0.0019413098629600107
# [2025-09-23 14:17:01:997] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -312.5429419693537. Mean: -0.2171945392420804. Std: 0.10557793223150319
# [2025-09-23 14:17:01:997] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.79207105. Mean: 0.001245358617095205. Std: 0.0019413098629600107
# [2025-09-23 14:17:02:014] [SmartMeterDiscreteEnv Test] Episode 0024 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0024_info.json
# [2025-09-23 14:17:02:018] [SmartMeterWorldDiscrete Test] Resetting environment with episode 25. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-19 00:00:01'), Timestamp('2013-05-19 23:59:01'))}
# [2025-09-23 14:17:06:708] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -5.837193983333333. Mean of rewards: -0.004056423893907807. Std of rewards: 0.004935088898461543
# [2025-09-23 14:17:06:708] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -203.3416098621674. Mean: -0.14130758155814274. Std: 0.09747112667970513
# [2025-09-23 14:17:06:708] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 5.837193983333334. Mean: 0.004056423893907807. Std: 0.004935088898461543
# [2025-09-23 14:17:06:724] [SmartMeterDiscreteEnv Test] Episode 0025 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0025_info.json
# [2025-09-23 14:17:06:728] [SmartMeterWorldDiscrete Test] Resetting environment with episode 26. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-20 00:00:04'), Timestamp('2013-05-20 23:59:04'))}
# [2025-09-23 14:17:11:542] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -5.522606633333333. Mean of rewards: -0.003837808640259439. Std of rewards: 0.00504832666807199
# [2025-09-23 14:17:11:543] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -267.6593033771496. Mean: -0.18600368546014567. Std: 0.1366226102241365
# [2025-09-23 14:17:11:543] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 5.522606633333333. Mean: 0.003837808640259439. Std: 0.00504832666807199
# [2025-09-23 14:17:11:559] [SmartMeterDiscreteEnv Test] Episode 0026 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0026_info.json
# [2025-09-23 14:17:11:563] [SmartMeterWorldDiscrete Test] Resetting environment with episode 27. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-21 00:00:02'), Timestamp('2013-05-21 23:59:02'))}
# [2025-09-23 14:17:16:833] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.694316533333334. Mean of rewards: -0.003262207458883484. Std of rewards: 0.004624427407164523
# [2025-09-23 14:17:16:834] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -224.05138660245575. Mean: -0.15569936525535494. Std: 0.10740802686386658
# [2025-09-23 14:17:16:834] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.694316533333334. Mean: 0.003262207458883484. Std: 0.004624427407164523
# [2025-09-23 14:17:16:850] [SmartMeterDiscreteEnv Test] Episode 0027 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0027_info.json
# [2025-09-23 14:17:16:854] [SmartMeterWorldDiscrete Test] Resetting environment with episode 28. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-22 00:00:05'), Timestamp('2013-05-22 23:59:05'))}
# [2025-09-23 14:17:21:570] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.4511924166666668. Mean of rewards: -0.002398326905258281. Std of rewards: 0.004067353914497118
# [2025-09-23 14:17:21:570] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -324.9728895924054. Mean: -0.22583244585990647. Std: 0.11177563549640179
# [2025-09-23 14:17:21:570] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.4511924166666668. Mean: 0.002398326905258281. Std: 0.004067353914497118
# [2025-09-23 14:17:21:587] [SmartMeterDiscreteEnv Test] Episode 0028 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0028_info.json
# [2025-09-23 14:17:21:591] [SmartMeterWorldDiscrete Test] Resetting environment with episode 29. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-23 00:00:01'), Timestamp('2013-05-23 23:59:01'))}
# [2025-09-23 14:17:26:361] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.672188016666667. Mean of rewards: -0.0018569756891359738. Std of rewards: 0.003908461217746689
# [2025-09-23 14:17:26:361] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -247.07217220868915. Mean: -0.17169713148623292. Std: 0.10483416763760879
# [2025-09-23 14:17:26:361] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.6721880166666665. Mean: 0.0018569756891359738. Std: 0.003908461217746689
# [2025-09-23 14:17:26:376] [SmartMeterDiscreteEnv Test] Episode 0029 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0029_info.json
# [2025-09-23 14:17:26:376] Episode 30/80 completed.
# [2025-09-23 14:17:26:380] [SmartMeterWorldDiscrete Test] Resetting environment with episode 30. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-05-24 00:00:01'), Timestamp('2013-05-24 23:59:01'))}
# [2025-09-23 14:17:31:174] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.2478748250000002. Mean of rewards: -0.0015621089819318973. Std of rewards: 0.002782476502949231
# [2025-09-23 14:17:31:174] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -306.9481898150407. Mean: -0.21330659472900673. Std: 0.1430008442959042
# [2025-09-23 14:17:31:174] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.2478748250000002. Mean: 0.0015621089819318973. Std: 0.002782476502949231
# [2025-09-23 14:17:31:190] [SmartMeterDiscreteEnv Test] Episode 0030 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0030_info.json
# [2025-09-23 14:17:31:194] [SmartMeterWorldDiscrete Test] Resetting environment with episode 31. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-18 00:00:04'), Timestamp('2013-06-18 23:59:04'))}
# [2025-09-23 14:17:35:879] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.798424883333333. Mean of rewards: -0.0033345551656242768. Std of rewards: 0.005035114667321583
# [2025-09-23 14:17:35:879] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -236.6657359560486. Mean: -0.1644654176206036. Std: 0.11472426405054617
# [2025-09-23 14:17:35:879] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.798424883333334. Mean: 0.0033345551656242768. Std: 0.005035114667321583
# [2025-09-23 14:17:35:895] [SmartMeterDiscreteEnv Test] Episode 0031 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0031_info.json
# [2025-09-23 14:17:35:898] [SmartMeterWorldDiscrete Test] Resetting environment with episode 32. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-19 00:00:05'), Timestamp('2013-06-19 23:59:05'))}
# [2025-09-23 14:17:40:656] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.708009416666667. Mean of rewards: -0.003271723013666898. Std of rewards: 0.005454242458466193
# [2025-09-23 14:17:40:656] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -261.8164552715607. Mean: -0.18194333236383647. Std: 0.09711913561755835
# [2025-09-23 14:17:40:656] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.708009416666666. Mean: 0.003271723013666898. Std: 0.005454242458466193
# [2025-09-23 14:17:40:672] [SmartMeterDiscreteEnv Test] Episode 0032 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0032_info.json
# [2025-09-23 14:17:40:677] [SmartMeterWorldDiscrete Test] Resetting environment with episode 33. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-20 00:00:00'), Timestamp('2013-06-20 23:59:00'))}
# [2025-09-23 14:17:45:517] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.3688245. Mean of rewards: -0.002341087213342599. Std of rewards: 0.003547678302769886
# [2025-09-23 14:17:45:517] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -314.63463744008914. Mean: -0.21864811496879022. Std: 0.13054498985107615
# [2025-09-23 14:17:45:517] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.3688245. Mean: 0.002341087213342599. Std: 0.003547678302769886
# [2025-09-23 14:17:45:533] [SmartMeterDiscreteEnv Test] Episode 0033 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0033_info.json
# [2025-09-23 14:17:45:537] [SmartMeterWorldDiscrete Test] Resetting environment with episode 34. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-21 00:00:03'), Timestamp('2013-06-21 23:59:03'))}
# [2025-09-23 14:17:50:839] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.296715475. Mean of rewards: -0.00229097670257123. Std of rewards: 0.0033822432514815075
# [2025-09-23 14:17:50:839] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -322.28470767941326. Mean: -0.22396435557985633. Std: 0.12045523257388291
# [2025-09-23 14:17:50:839] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.296715475. Mean: 0.00229097670257123. Std: 0.0033822432514815075
# [2025-09-23 14:17:50:855] [SmartMeterDiscreteEnv Test] Episode 0034 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0034_info.json
# [2025-09-23 14:17:50:859] [SmartMeterWorldDiscrete Test] Resetting environment with episode 35. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-22 00:00:05'), Timestamp('2013-06-22 23:59:05'))}
# [2025-09-23 14:17:55:580] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.2177810833333336. Mean of rewards: -0.0015411960273337968. Std of rewards: 0.0014100520325851698
# [2025-09-23 14:17:55:580] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -308.84211051044986. Mean: -0.21462273141796376. Std: 0.11563897600899994
# [2025-09-23 14:17:55:581] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.2177810833333336. Mean: 0.0015411960273337968. Std: 0.0014100520325851698
# [2025-09-23 14:17:55:597] [SmartMeterDiscreteEnv Test] Episode 0035 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0035_info.json
# [2025-09-23 14:17:55:601] [SmartMeterWorldDiscrete Test] Resetting environment with episode 36. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-23 00:00:03'), Timestamp('2013-06-23 23:59:03'))}
# [2025-09-23 14:18:00:300] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -1.7647402250000002. Mean of rewards: -0.0012263656879777623. Std of rewards: 0.0017831596409736672
# [2025-09-23 14:18:00:300] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -327.4803737255279. Mean: -0.22757496436798325. Std: 0.10981868105532402
# [2025-09-23 14:18:00:300] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 1.764740225. Mean: 0.0012263656879777623. Std: 0.0017831596409736672
# [2025-09-23 14:18:00:316] [SmartMeterDiscreteEnv Test] Episode 0036 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0036_info.json
# [2025-09-23 14:18:00:320] [SmartMeterWorldDiscrete Test] Resetting environment with episode 37. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-06-24 00:00:00'), Timestamp('2013-06-24 23:59:00'))}
# [2025-09-23 14:18:05:106] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.10798275. Mean of rewards: -0.002854748262682418. Std of rewards: 0.004561895925025567
# [2025-09-23 14:18:05:106] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -339.6315145350527. Mean: -0.23601912059419924. Std: 0.1210227182060943
# [2025-09-23 14:18:05:106] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.10798275. Mean: 0.002854748262682418. Std: 0.004561895925025567
# [2025-09-23 14:18:05:122] [SmartMeterDiscreteEnv Test] Episode 0037 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0037_info.json
# [2025-09-23 14:18:05:126] [SmartMeterWorldDiscrete Test] Resetting environment with episode 38. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-15 00:00:03'), Timestamp('2013-07-15 23:59:03'))}
# [2025-09-23 14:18:09:938] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.272657975. Mean of rewards: -0.002969185528144546. Std of rewards: 0.004295523237286336
# [2025-09-23 14:18:09:938] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -342.7471296393778. Mean: -0.23818424575356345. Std: 0.12468590105687194
# [2025-09-23 14:18:09:938] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.272657975000001. Mean: 0.002969185528144546. Std: 0.004295523237286336
# [2025-09-23 14:18:09:954] [SmartMeterDiscreteEnv Test] Episode 0038 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0038_info.json
# [2025-09-23 14:18:09:959] [SmartMeterWorldDiscrete Test] Resetting environment with episode 39. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-16 00:00:05'), Timestamp('2013-07-16 23:59:05'))}
# [2025-09-23 14:18:14:779] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.826443666666667. Mean of rewards: -0.0033540261755848964. Std of rewards: 0.0051720759124085575
# [2025-09-23 14:18:14:779] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -264.05805024923757. Mean: -0.18350107731010254. Std: 0.1086886185622841
# [2025-09-23 14:18:14:779] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.826443666666666. Mean: 0.0033540261755848964. Std: 0.0051720759124085575
# [2025-09-23 14:18:14:795] [SmartMeterDiscreteEnv Test] Episode 0039 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0039_info.json
# [2025-09-23 14:18:14:795] Episode 40/80 completed.
# [2025-09-23 14:18:14:799] [SmartMeterWorldDiscrete Test] Resetting environment with episode 40. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-17 00:00:02'), Timestamp('2013-07-17 23:59:02'))}
# [2025-09-23 14:18:20:134] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.107430783333333. Mean of rewards: -0.0028543646861246236. Std of rewards: 0.004835776802225366
# [2025-09-23 14:18:20:134] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -269.4119207118638. Mean: -0.1872216266239498. Std: 0.09724906481618226
# [2025-09-23 14:18:20:134] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.107430783333333. Mean: 0.0028543646861246236. Std: 0.004835776802225366
# [2025-09-23 14:18:20:151] [SmartMeterDiscreteEnv Test] Episode 0040 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0040_info.json
# [2025-09-23 14:18:20:155] [SmartMeterWorldDiscrete Test] Resetting environment with episode 41. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-18 00:00:01'), Timestamp('2013-07-18 23:59:01'))}
# [2025-09-23 14:18:24:977] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.0425885166666666. Mean of rewards: -0.0021143770094973363. Std of rewards: 0.004098399261125035
# [2025-09-23 14:18:24:978] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -268.35891821980476. Mean: -0.186489866726758. Std: 0.1045617001609653
# [2025-09-23 14:18:24:978] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.0425885166666666. Mean: 0.0021143770094973363. Std: 0.004098399261125035
# [2025-09-23 14:18:24:994] [SmartMeterDiscreteEnv Test] Episode 0041 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0041_info.json
# [2025-09-23 14:18:24:997] [SmartMeterWorldDiscrete Test] Resetting environment with episode 42. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-19 00:00:05'), Timestamp('2013-07-19 23:59:05'))}
# [2025-09-23 14:18:29:827] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.047608916666667. Mean of rewards: -0.0014229387885105395. Std of rewards: 0.002782816092275469
# [2025-09-23 14:18:29:827] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -283.17446050047874. Mean: -0.19678558756113881. Std: 0.14527712796327613
# [2025-09-23 14:18:29:827] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.0476089166666664. Mean: 0.0014229387885105395. Std: 0.002782816092275469
# [2025-09-23 14:18:29:843] [SmartMeterDiscreteEnv Test] Episode 0042 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0042_info.json
# [2025-09-23 14:18:29:847] [SmartMeterWorldDiscrete Test] Resetting environment with episode 43. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-20 00:00:00'), Timestamp('2013-07-20 23:59:00'))}
# [2025-09-23 14:18:34:665] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.0377135. Mean of rewards: -0.001416062195969423. Std of rewards: 0.0025382442842301458
# [2025-09-23 14:18:34:665] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -326.24729561060667. Mean: -0.2267180650525411. Std: 0.1357206002338896
# [2025-09-23 14:18:34:665] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.0377134999999997. Mean: 0.001416062195969423. Std: 0.0025382442842301458
# [2025-09-23 14:18:34:681] [SmartMeterDiscreteEnv Test] Episode 0043 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0043_info.json
# [2025-09-23 14:18:34:684] [SmartMeterWorldDiscrete Test] Resetting environment with episode 44. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-07-21 00:00:04'), Timestamp('2013-07-21 23:59:04'))}
# [2025-09-23 14:18:39:494] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.0440003166666667. Mean of rewards: -0.0014204310748204773. Std of rewards: 0.0025696727294066066
# [2025-09-23 14:18:39:494] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -315.23496448341757. Mean: -0.21906529845963696. Std: 0.13055302959814505
# [2025-09-23 14:18:39:494] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.0440003166666667. Mean: 0.0014204310748204773. Std: 0.0025696727294066066
# [2025-09-23 14:18:39:510] [SmartMeterDiscreteEnv Test] Episode 0044 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0044_info.json
# [2025-09-23 14:18:39:514] [SmartMeterWorldDiscrete Test] Resetting environment with episode 45. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-15 00:00:01'), Timestamp('2013-08-15 23:59:01'))}
# [2025-09-23 14:18:44:430] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.8516485166666667. Mean of rewards: -0.0026766146745425064. Std of rewards: 0.004585720251564578
# [2025-09-23 14:18:44:430] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -274.724766404368. Mean: -0.19091366671603058. Std: 0.10349140731751268
# [2025-09-23 14:18:44:430] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.8516485166666667. Mean: 0.0026766146745425064. Std: 0.004585720251564578
# [2025-09-23 14:18:44:445] [SmartMeterDiscreteEnv Test] Episode 0045 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0045_info.json
# [2025-09-23 14:18:44:449] [SmartMeterWorldDiscrete Test] Resetting environment with episode 46. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-16 00:00:05'), Timestamp('2013-08-16 23:59:05'))}
# [2025-09-23 14:18:49:214] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.516196916666667. Mean of rewards: -0.0024435002895529306. Std of rewards: 0.004124130046811682
# [2025-09-23 14:18:49:214] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -322.67163731879555. Mean: -0.22423324344600107. Std: 0.11956348818135491
# [2025-09-23 14:18:49:214] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.516196916666667. Mean: 0.0024435002895529306. Std: 0.004124130046811682
# [2025-09-23 14:18:49:230] [SmartMeterDiscreteEnv Test] Episode 0046 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0046_info.json
# [2025-09-23 14:18:49:234] [SmartMeterWorldDiscrete Test] Resetting environment with episode 47. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-17 00:00:02'), Timestamp('2013-08-17 23:59:02'))}
# [2025-09-23 14:18:54:678] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.3500336500000003. Mean of rewards: -0.00163310191104934. Std of rewards: 0.002152046097747262
# [2025-09-23 14:18:54:678] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -297.0031899334863. Mean: -0.20639554547149846. Std: 0.1118012011943688
# [2025-09-23 14:18:54:678] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.3500336500000003. Mean: 0.00163310191104934. Std: 0.002152046097747262
# [2025-09-23 14:18:54:695] [SmartMeterDiscreteEnv Test] Episode 0047 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0047_info.json
# [2025-09-23 14:18:54:699] [SmartMeterWorldDiscrete Test] Resetting environment with episode 48. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-18 00:00:05'), Timestamp('2013-08-18 23:59:05'))}
# [2025-09-23 14:18:59:534] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.1377411250000002. Mean of rewards: -0.0014855740965948577. Std of rewards: 0.0023140219170119047
# [2025-09-23 14:18:59:534] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -371.96612692973576. Mean: -0.2584893168378984. Std: 0.11535219769272775
# [2025-09-23 14:18:59:534] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.1377411250000002. Mean: 0.0014855740965948577. Std: 0.0023140219170119047
# [2025-09-23 14:18:59:550] [SmartMeterDiscreteEnv Test] Episode 0048 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0048_info.json
# [2025-09-23 14:18:59:554] [SmartMeterWorldDiscrete Test] Resetting environment with episode 49. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-19 00:00:01'), Timestamp('2013-08-19 23:59:01'))}
# [2025-09-23 14:19:04:457] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.191911825. Mean of rewards: -0.0029130728457261988. Std of rewards: 0.004331175516625508
# [2025-09-23 14:19:04:457] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -346.9671419179067. Mean: -0.24111684636407693. Std: 0.13060563857013543
# [2025-09-23 14:19:04:457] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.191911825. Mean: 0.0029130728457261988. Std: 0.004331175516625508
# [2025-09-23 14:19:04:473] [SmartMeterDiscreteEnv Test] Episode 0049 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0049_info.json
# [2025-09-23 14:19:04:473] Episode 50/80 completed.
# [2025-09-23 14:19:04:477] [SmartMeterWorldDiscrete Test] Resetting environment with episode 50. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-20 00:00:02'), Timestamp('2013-08-20 23:59:02'))}
# [2025-09-23 14:19:09:230] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.398267783333333. Mean of rewards: -0.0030564751795228167. Std of rewards: 0.0049992758858750305
# [2025-09-23 14:19:09:230] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -254.51937188976444. Mean: -0.17687239186224074. Std: 0.09959870481029737
# [2025-09-23 14:19:09:230] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.398267783333333. Mean: 0.0030564751795228167. Std: 0.0049992758858750305
# [2025-09-23 14:19:09:246] [SmartMeterDiscreteEnv Test] Episode 0050 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0050_info.json
# [2025-09-23 14:19:09:250] [SmartMeterWorldDiscrete Test] Resetting environment with episode 51. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-08-21 00:00:00'), Timestamp('2013-08-21 23:59:00'))}
# [2025-09-23 14:19:14:032] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.3410715. Mean of rewards: -0.003016727936066713. Std of rewards: 0.004613787926549702
# [2025-09-23 14:19:14:032] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -240.33865478739608. Mean: -0.16701782820527872. Std: 0.10151872327972171
# [2025-09-23 14:19:14:032] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.3410715. Mean: 0.003016727936066713. Std: 0.004613787926549702
# [2025-09-23 14:19:14:049] [SmartMeterDiscreteEnv Test] Episode 0051 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0051_info.json
# [2025-09-23 14:19:14:053] [SmartMeterWorldDiscrete Test] Resetting environment with episode 52. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-09-15 00:00:00'), Timestamp('2013-09-15 23:59:00'))}
# [2025-09-23 14:19:18:879] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.73019075. Mean of rewards: -0.0018972833564975678. Std of rewards: 0.0026498727214702747
# [2025-09-23 14:19:18:880] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -351.01127695292234. Mean: -0.24392722512364304. Std: 0.11642794323362719
# [2025-09-23 14:19:18:880] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.73019075. Mean: 0.0018972833564975678. Std: 0.0026498727214702747
# [2025-09-23 14:19:18:896] [SmartMeterDiscreteEnv Test] Episode 0052 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0052_info.json
# ...
# [2025-09-23 14:20:07:166] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.05316925. Mean: 0.0028166568797776234. Std: 0.003880892065631909
# [2025-09-23 14:20:07:183] [SmartMeterDiscreteEnv Test] Episode 0062 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0062_info.json
# [2025-09-23 14:20:07:186] [SmartMeterWorldDiscrete Test] Resetting environment with episode 63. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-19 00:00:04'), Timestamp('2013-10-19 23:59:04'))}
# [2025-09-23 14:20:12:007] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.2043615500000002. Mean of rewards: -0.0022267974635163308. Std of rewards: 0.003289310803275406
# [2025-09-23 14:20:12:007] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -342.5565560045652. Mean: -0.2380518109830196. Std: 0.11525032822054572
# [2025-09-23 14:20:12:007] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.20436155. Mean: 0.0022267974635163308. Std: 0.003289310803275406
# [2025-09-23 14:20:12:024] [SmartMeterDiscreteEnv Test] Episode 0063 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0063_info.json
# [2025-09-23 14:20:12:029] [SmartMeterWorldDiscrete Test] Resetting environment with episode 64. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-20 00:00:04'), Timestamp('2013-10-20 23:59:04'))}
# [2025-09-23 14:20:16:944] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.52581055. Mean of rewards: -0.0017552540305767893. Std of rewards: 0.0031402435875396394
# [2025-09-23 14:20:16:944] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -330.68424714473076. Mean: -0.22980142261621317. Std: 0.11600154355153518
# [2025-09-23 14:20:16:944] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.5258105499999997. Mean: 0.0017552540305767893. Std: 0.0031402435875396394
# [2025-09-23 14:20:16:960] [SmartMeterDiscreteEnv Test] Episode 0064 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0064_info.json
# [2025-09-23 14:20:16:964] [SmartMeterWorldDiscrete Test] Resetting environment with episode 65. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-10-21 00:00:04'), Timestamp('2013-10-21 23:59:04'))}
# [2025-09-23 14:20:21:893] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.52478385. Mean of rewards: -0.0031443946143154974. Std of rewards: 0.004015420605778053
# [2025-09-23 14:20:21:893] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -243.29157228162512. Mean: -0.16906989039723774. Std: 0.12494611903178417
# [2025-09-23 14:20:21:893] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.52478385. Mean: 0.0031443946143154974. Std: 0.004015420605778053
# [2025-09-23 14:20:21:910] [SmartMeterDiscreteEnv Test] Episode 0065 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0065_info.json
# [2025-09-23 14:20:21:914] [SmartMeterWorldDiscrete Test] Resetting environment with episode 66. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-15 00:00:04'), Timestamp('2013-11-15 23:59:04'))}
# [2025-09-23 14:20:26:864] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.985196816666667. Mean of rewards: -0.0020744939657169332. Std of rewards: 0.002492142212045675
# [2025-09-23 14:20:26:865] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -251.73826131550595. Mean: -0.17493972294336757. Std: 0.10117497144443768
# [2025-09-23 14:20:26:865] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.985196816666667. Mean: 0.0020744939657169332. Std: 0.002492142212045675
# [2025-09-23 14:20:26:881] [SmartMeterDiscreteEnv Test] Episode 0066 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0066_info.json
# [2025-09-23 14:20:26:885] [SmartMeterWorldDiscrete Test] Resetting environment with episode 67. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-16 00:00:03'), Timestamp('2013-11-16 23:59:03'))}
# [2025-09-23 14:20:32:300] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.4379347. Mean of rewards: -0.002389113759555247. Std of rewards: 0.003674809819169655
# [2025-09-23 14:20:32:300] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -253.42891421564855. Mean: -0.17611460334652435. Std: 0.1216261568394556
# [2025-09-23 14:20:32:300] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.4379347. Mean: 0.002389113759555247. Std: 0.003674809819169655
# [2025-09-23 14:20:32:316] [SmartMeterDiscreteEnv Test] Episode 0067 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0067_info.json
# [2025-09-23 14:20:32:320] [SmartMeterWorldDiscrete Test] Resetting environment with episode 68. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-17 00:00:03'), Timestamp('2013-11-17 23:59:03'))}
# [2025-09-23 14:20:37:136] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.3588348. Mean of rewards: -0.0016392180681028491. Std of rewards: 0.003223378922488508
# [2025-09-23 14:20:37:136] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -297.96748970402405. Mean: -0.2070656634496345. Std: 0.11032032395015193
# [2025-09-23 14:20:37:136] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.3588348. Mean: 0.0016392180681028491. Std: 0.003223378922488508
# [2025-09-23 14:20:37:153] [SmartMeterDiscreteEnv Test] Episode 0068 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0068_info.json
# [2025-09-23 14:20:37:157] [SmartMeterWorldDiscrete Test] Resetting environment with episode 69. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-18 00:00:04'), Timestamp('2013-11-18 23:59:04'))}
# [2025-09-23 14:20:42:180] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -4.160867316666667. Mean of rewards: -0.002891499177669678. Std of rewards: 0.0036482478780777423
# [2025-09-23 14:20:42:180] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -213.38623726915102. Mean: -0.14828786467626895. Std: 0.10724156442350828
# [2025-09-23 14:20:42:180] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 4.160867316666667. Mean: 0.002891499177669678. Std: 0.0036482478780777423
# [2025-09-23 14:20:42:197] [SmartMeterDiscreteEnv Test] Episode 0069 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0069_info.json
# [2025-09-23 14:20:42:197] Episode 70/80 completed.
# [2025-09-23 14:20:42:201] [SmartMeterWorldDiscrete Test] Resetting environment with episode 70. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-19 00:00:02'), Timestamp('2013-11-19 23:59:02'))}
# [2025-09-23 14:20:47:312] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.86058555. Mean of rewards: -0.0019878982279360664. Std of rewards: 0.0024223443535689826
# [2025-09-23 14:20:47:312] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -319.05350936972536. Mean: -0.22171890852656384. Std: 0.11807739104101438
# [2025-09-23 14:20:47:312] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.8605855499999997. Mean: 0.0019878982279360664. Std: 0.0024223443535689826
# [2025-09-23 14:20:47:329] [SmartMeterDiscreteEnv Test] Episode 0070 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0070_info.json
# [2025-09-23 14:20:47:332] [SmartMeterWorldDiscrete Test] Resetting environment with episode 71. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-20 00:00:02'), Timestamp('2013-11-20 23:59:02'))}
# [2025-09-23 14:20:52:527] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.5366735333333335. Mean of rewards: -0.0024577300440120453. Std of rewards: 0.0028336502382879194
# [2025-09-23 14:20:52:528] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -233.03230172174517. Mean: -0.16194044594978815. Std: 0.09526144442657662
# [2025-09-23 14:20:52:528] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.5366735333333335. Mean: 0.0024577300440120453. Std: 0.0028336502382879194
# [2025-09-23 14:20:52:544] [SmartMeterDiscreteEnv Test] Episode 0071 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0071_info.json
# [2025-09-23 14:20:52:548] [SmartMeterWorldDiscrete Test] Resetting environment with episode 72. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-11-21 00:00:04'), Timestamp('2013-11-21 23:59:04'))}
# [2025-09-23 14:20:57:646] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.2103900666666667. Mean of rewards: -0.0022309868427148488. Std of rewards: 0.003321679769764588
# [2025-09-23 14:20:57:646] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -200.7418512501754. Mean: -0.13950093902027477. Std: 0.05518135885557868
# [2025-09-23 14:20:57:646] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.210390066666667. Mean: 0.0022309868427148488. Std: 0.003321679769764588
# [2025-09-23 14:20:57:663] [SmartMeterDiscreteEnv Test] Episode 0072 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0072_info.json
# [2025-09-23 14:20:57:668] [SmartMeterWorldDiscrete Test] Resetting environment with episode 73. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-15 00:00:05'), Timestamp('2013-12-15 23:59:05'))}
# [2025-09-23 14:21:02:818] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.7273043333333336. Mean of rewards: -0.0018952775075283764. Std of rewards: 0.00287230015923543
# [2025-09-23 14:21:02:819] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -337.7297929004999. Mean: -0.23469756282175114. Std: 0.10751533785952795
# [2025-09-23 14:21:02:819] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.7273043333333336. Mean: 0.0018952775075283764. Std: 0.00287230015923543
# [2025-09-23 14:21:02:835] [SmartMeterDiscreteEnv Test] Episode 0073 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0073_info.json
# [2025-09-23 14:21:02:839] [SmartMeterWorldDiscrete Test] Resetting environment with episode 74. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-16 00:00:06'), Timestamp('2013-12-16 23:59:06'))}
# [2025-09-23 14:21:08:483] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.5130096. Mean of rewards: -0.002441285337039611. Std of rewards: 0.0030729918368042806
# [2025-09-23 14:21:08:483] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -307.9512186681386. Mean: -0.214003626593564. Std: 0.1272974623165092
# [2025-09-23 14:21:08:483] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.5130096. Mean: 0.002441285337039611. Std: 0.0030729918368042806
# [2025-09-23 14:21:08:500] [SmartMeterDiscreteEnv Test] Episode 0074 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0074_info.json
# [2025-09-23 14:21:08:504] [SmartMeterWorldDiscrete Test] Resetting environment with episode 75. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-17 00:00:00'), Timestamp('2013-12-17 23:59:00'))}
# [2025-09-23 14:21:13:255] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.1958272500000002. Mean of rewards: -0.002220866747741488. Std of rewards: 0.0024019343439960076
# [2025-09-23 14:21:13:255] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -226.60565008642152. Mean: -0.15747439199890306. Std: 0.11361632607090091
# [2025-09-23 14:21:13:255] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.1958272500000007. Mean: 0.002220866747741488. Std: 0.0024019343439960076
# [2025-09-23 14:21:13:271] [SmartMeterDiscreteEnv Test] Episode 0075 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0075_info.json
# [2025-09-23 14:21:13:275] [SmartMeterWorldDiscrete Test] Resetting environment with episode 76. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-18 00:00:01'), Timestamp('2013-12-18 23:59:01'))}
# [2025-09-23 14:21:17:980] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.833102516666667. Mean of rewards: -0.001968799525133194. Std of rewards: 0.001977808335283983
# [2025-09-23 14:21:17:981] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -258.5431032925844. Mean: -0.1796685915862296. Std: 0.11520981503074718
# [2025-09-23 14:21:17:981] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.8331025166666666. Mean: 0.001968799525133194. Std: 0.001977808335283983
# [2025-09-23 14:21:17:997] [SmartMeterDiscreteEnv Test] Episode 0076 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0076_info.json
# [2025-09-23 14:21:18:001] [SmartMeterWorldDiscrete Test] Resetting environment with episode 77. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-19 00:00:05'), Timestamp('2013-12-19 23:59:05'))}
# [2025-09-23 14:21:22:674] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.0044030833333335. Mean of rewards: -0.0020878409196201067. Std of rewards: 0.002319608108281879
# [2025-09-23 14:21:22:674] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -249.85142693459056. Mean: -0.17362851072591423. Std: 0.10491728177415721
# [2025-09-23 14:21:22:674] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.0044030833333335. Mean: 0.0020878409196201067. Std: 0.002319608108281879
# [2025-09-23 14:21:22:691] [SmartMeterDiscreteEnv Test] Episode 0077 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0077_info.json
# [2025-09-23 14:21:22:694] [SmartMeterWorldDiscrete Test] Resetting environment with episode 78. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-20 00:00:02'), Timestamp('2013-12-20 23:59:02'))}
# [2025-09-23 14:21:27:512] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -3.8254435333333334. Mean of rewards: -0.002658404123233727. Std of rewards: 0.0034785380097287124
# [2025-09-23 14:21:27:512] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -273.3258662468288. Mean: -0.18994153318056206. Std: 0.09383300725736422
# [2025-09-23 14:21:27:512] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 3.8254435333333334. Mean: 0.002658404123233727. Std: 0.0034785380097287124
# [2025-09-23 14:21:27:530] [SmartMeterDiscreteEnv Test] Episode 0078 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0078_info.json
# [2025-09-23 14:21:27:534] [SmartMeterWorldDiscrete Test] Resetting environment with episode 79. Episode info: {'length': 1440, 'datetime_range': (Timestamp('2013-12-21 00:00:01'), Timestamp('2013-12-21 23:59:01'))}
# [2025-09-23 14:21:32:252] [SmartMeterDiscreteEnv Test] Episode finished. Sum of rewards: -2.4799650166666667. Mean of rewards: -0.0017233947301366693. Std of rewards: 0.002429642518345644
# [2025-09-23 14:21:32:253] [SmartMeterDiscreteEnv Test] Episode f_signal sum: -295.16104983887635. Mean: -0.20511539252180427. Std: 0.09347795096929404
# [2025-09-23 14:21:32:253] [SmartMeterDiscreteEnv Test] Episode g_signal sum: 2.479965016666667. Mean: 0.0017233947301366693. Std: 0.002429642518345644
# [2025-09-23 14:21:32:269] [SmartMeterDiscreteEnv Test] Episode 0079 info saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/episode_info/episode_0079_info.json
# [2025-09-23 14:21:32:270] Episode 80/80 completed.
# [2025-09-23 14:21:32:272] Validation results saved to experiments/20250814_044619_action_discrete_reward_lambda_1.0/logs_test/episode_0600/test_stats_file.json
